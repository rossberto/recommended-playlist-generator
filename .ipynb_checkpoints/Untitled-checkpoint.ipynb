# %%
from dotenv import load_dotenv
load_dotenv()
import os
import sys
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %% [markdown]
# ## Auth

# %%
scope = 'user-top-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

token = util.prompt_for_user_token(username, scope)
sp = spotipy.Spotify(auth=token)
token
# Out:
# 'BQDXIw_TxYlB17SjOHJdyICM0UGuzhqRRUbyVpMMxU7QP3tnD_oI9JN5zEuXEZxZgQAs6pHTZtC0Wj7SSjK2DwucZyimrs9istaM5SXeGj771zV81pKN3Bslmuyd5fIhZIuoqJdpWDhH4pU26oVPZzFWH5oBpfAM'

# %% [markdown]
# ## User Profile

# %%
sp = spotipy.Spotify(auth=token)
top_artists = sp.current_user_top_artists(time_range='long_term', limit=50)
top_tracks = sp.current_user_top_tracks(time_range='long_term', limit=50)

# %%
artists_ids = [top_artists['items'][i]['id'] for i in range(len(top_artists['items']))]
artists_uris = [top_artists['items'][i]['uri'] for i in range(len(top_artists['items']))]
artists_uris
# Out:
# ['spotify:artist:4Z8W4fKeB5YxbusRsdQVPb',
#  'spotify:artist:09xj0S68Y1OU1vHMCZAIvz',
#  'spotify:artist:6olE6TJLqED3rqDCT0FyPh',
#  'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU',
#  'spotify:artist:2FS22haX3FYbyOsUAkuYqZ',
#  'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD',
#  'spotify:artist:0L8ExT028jH3ddEcZwqJJ5',
#  'spotify:artist:55qSbU11psT1e0HlLaTZPB',
#  'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d',
#  'spotify:artist:2VYQTNDsvvKN9wmU5W7xpj',
#  'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9',
#  'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi',
#  'spotify:artist:6Ghvu1VvMGScGpOUJBAHNH',
#  'spotify:artist:1rCIEwPp5OnXW0ornlSsRl',
#  'spotify:artist:1gR0gsQYfi6joyO1dlp76N',
#  'spotify:artist:7eBQrhxTHcor6gcbcLhqE5',
#  'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy',
#  'spotify:artist:1w5Kfo2jwwIPruYS2UWh56',
#  'spotify:artist:6IdtcAwaNVAggwd6sCKgTI',
#  'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y',
#  'spotify:artist:6MxyNXnnmwQwdW2PD0gXYO',
#  'spotify:artist:4CvTDPKA6W06DRfBnZKrau',
#  'spotify:artist:7An4yvF7hDYDolN4m5zKBp',
#  'spotify:artist:2aaLAng2L2aWD2FClzwiep',
#  'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB',
#  'spotify:artist:3tAICgiSR5PfYY4B8qsoAU',
#  'spotify:artist:3qAPxVwIQRBuz5ImPUxpZT',
#  'spotify:artist:1GImnM7WYVp95431ypofy9',
#  'spotify:artist:3RNrq3jvMZxD9ZyoOZbQOD',
#  'spotify:artist:22WZ7M8sxp5THdruNY3gXt',
#  'spotify:artist:27Owkm4TGlMqb0BqaEt3PW',
#  'spotify:artist:14xs9RNQa8MHRS7YU8Bzfk',
#  'spotify:artist:6RZUqkomCmb8zCRqc9eznB',
#  'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2',
#  'spotify:artist:4rUyBlggM5tZUH5QZn9ZuO',
#  'spotify:artist:12Chz98pHFMPJEknJQMWvI',
#  'spotify:artist:0EmeFodog0BfCgMzAIvKQp',
#  'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj',
#  'spotify:artist:2MRBDr0crHWE5JwPceFncq',
#  'spotify:artist:1RgXxY6uzWo9cjYYwwgVGq',
#  'spotify:artist:36QJpDe2go2KgaRleHCDTp',
#  'spotify:artist:2F9pvj94b52wGKs0OqiNi2',
#  'spotify:artist:6WvDtNFHOWHfiNy8NVHujT',
#  'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS',
#  'spotify:artist:3IYUhFvPQItj6xySrBmZkd',
#  'spotify:artist:3AA28KZvwAUcZuOKwyblJQ',
#  'spotify:artist:4KWTAlx2RvbpseOGMEmROg',
#  'spotify:artist:1G1eDCwDbEX8SQwhq7fPmJ',
#  'spotify:artist:0cQbJU1aAzvbEmTuljWLlF',
#  'spotify:artist:3bUwxJgNakzYKkqAVgZLlh']

# %%
track_ids = [top_tracks['items'][i]['id'] for i in range(len(top_tracks['items']))]
track_ids
# Out:
# ['1uRxyAup7OYrlh2SHJb80N',
#  '0LtsuNRz3IMRrHCYO9fKRk',
#  '07q6QTQXyPRCf7GbLakRPr',
#  '1158ckiB5S4cpsdYHDB9IF',
#  '3pcCifdPTc2BbqmWpEhtUd',
#  '4Uiw0Sl9yskBaC6P4DcdVD',
#  '19EPiiOeqUyU3ey5jJxtYs',
#  '2HbVINmehEbPmjlcueXEJJ',
#  '4xanWVQIzdCf51mg8cd1cQ',
#  '6HNruFQlzQx4ulL4ppRLYI',
#  '1sn6iOK93jnp0Hn5BnNOXy',
#  '0eZN5WsQfmNFICHuw59Zfz',
#  '6txWz9UapYHVxEd7dDIHXT',
#  '10atyYpAMMlqPHVDt6yER8',
#  '0ssWKT6dx54wR6GZfTgYLr',
#  '4CzTgOmc3Sdm4EgKQWzjQl',
#  '6V9PDDZ2pHQCUleRXvRYQ1',
#  '2jkZB94i573H134wKmsw2y',
#  '0oks4FnzhNp5QPTZtoet7c',
#  '5rIhBK9aaVMck0W2YtOwci',
#  '4eruRiSfDY1jdT03hjyi0i',
#  '72hSmnleYTiiOo23q8ZJIS',
#  '3Kw4KEYQg6JaqUD8ZgAwz6',
#  '0cPzGMb1WVMCYn4nUcQrGl',
#  '562C3EC94HrVqmazwHvzej',
#  '6DoXuH326aAYEN8CnlLmhP',
#  '7iiULg8Kmbnh1vWbh9rnBA',
#  '6f6pEjgfTtuRROmJ4a7Gf3',
#  '3s5iP7A8jiEdNmRqNFCrdA',
#  '0xgsyoVvRFSYvV5cdtYhX1',
#  '2O6X9nPVVQSefg3xOQAo5u',
#  '37kUGdEJJ7NaMl5LFW4EA4',
#  '4czY6DucD5rKY1y0uvHLws',
#  '1kBGeOp1CDUHVdbK4ergqo',
#  '3LhtqibvTtjOUrzKs7Vsz1',
#  '5YBEul9sgV4aCImJ44hlnc',
#  '3ESohZocQvwRDzedmk4fYi',
#  '1L94M3KIu7QluZe63g64rv',
#  '5AiNZnMDCWwujIENPj9PV9',
#  '3OZBa6ovunpZ3mqxFRp2pT',
#  '48YkpE5enOln5c7jXSTuHL',
#  '23khhseCLQqVMCIT1WMAns',
#  '2i5K0EdMY5zFs9t7KfYK3k',
#  '2JDC83caNNDzY51IzsPY6G',
#  '0tZ3mElWcr74OOhKEiNz1x',
#  '4Ly7nHWRfTgGoFXJGtrixU',
#  '2ax8gOAjvG2nbztOKKQRsk',
#  '1Msrp5bJ5Y0ReJDS5HpQO6',
#  '12d8CMvcWNBrJ7rMdT1kmt',
#  '552BIJ9kKwwqiGf4YojYbL']

# %%
features = sp.audio_features(track_ids)
features
# Out:
# [{'danceability': 0.299,
#   'energy': 0.263,
#   'key': 9,
#   'loudness': -13.207,
#   'mode': 0,
#   'speechiness': 0.0323,
#   'acousticness': 0.968,
#   'instrumentalness': 0.857,
#   'liveness': 0.126,
#   'valence': 0.113,
#   'tempo': 137.848,
#   'type': 'audio_features',
#   'id': '1uRxyAup7OYrlh2SHJb80N',
#   'uri': 'spotify:track:1uRxyAup7OYrlh2SHJb80N',
#   'track_href': 'https://api.spotify.com/v1/tracks/1uRxyAup7OYrlh2SHJb80N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1uRxyAup7OYrlh2SHJb80N',
#   'duration_ms': 384439,
#   'time_signature': 3},
#  {'danceability': 0.576,
#   'energy': 0.738,
#   'key': 11,
#   'loudness': -8.122,
#   'mode': 1,
#   'speechiness': 0.0353,
#   'acousticness': 0.000387,
#   'instrumentalness': 0.00131,
#   'liveness': 0.13,
#   'valence': 0.675,
#   'tempo': 168.132,
#   'type': 'audio_features',
#   'id': '0LtsuNRz3IMRrHCYO9fKRk',
#   'uri': 'spotify:track:0LtsuNRz3IMRrHCYO9fKRk',
#   'track_href': 'https://api.spotify.com/v1/tracks/0LtsuNRz3IMRrHCYO9fKRk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LtsuNRz3IMRrHCYO9fKRk',
#   'duration_ms': 238400,
#   'time_signature': 4},
#  {'danceability': 0.415,
#   'energy': 0.867,
#   'key': 11,
#   'loudness': -5.497,
#   'mode': 0,
#   'speechiness': 0.0387,
#   'acousticness': 5.69e-05,
#   'instrumentalness': 0.000192,
#   'liveness': 0.0883,
#   'valence': 0.36,
#   'tempo': 157.902,
#   'type': 'audio_features',
#   'id': '07q6QTQXyPRCf7GbLakRPr',
#   'uri': 'spotify:track:07q6QTQXyPRCf7GbLakRPr',
#   'track_href': 'https://api.spotify.com/v1/tracks/07q6QTQXyPRCf7GbLakRPr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07q6QTQXyPRCf7GbLakRPr',
#   'duration_ms': 249987,
#   'time_signature': 4},
#  {'danceability': 0.443,
#   'energy': 0.781,
#   'key': 1,
#   'loudness': -4.277,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 1.33e-05,
#   'instrumentalness': 0.205,
#   'liveness': 0.166,
#   'valence': 0.372,
#   'tempo': 71.841,
#   'type': 'audio_features',
#   'id': '1158ckiB5S4cpsdYHDB9IF',
#   'uri': 'spotify:track:1158ckiB5S4cpsdYHDB9IF',
#   'track_href': 'https://api.spotify.com/v1/tracks/1158ckiB5S4cpsdYHDB9IF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1158ckiB5S4cpsdYHDB9IF',
#   'duration_ms': 214760,
#   'time_signature': 4},
#  {'danceability': 0.541,
#   'energy': 0.847,
#   'key': 11,
#   'loudness': -6.52,
#   'mode': 1,
#   'speechiness': 0.0297,
#   'acousticness': 0.303,
#   'instrumentalness': 0.271,
#   'liveness': 0.109,
#   'valence': 0.62,
#   'tempo': 148.937,
#   'type': 'audio_features',
#   'id': '3pcCifdPTc2BbqmWpEhtUd',
#   'uri': 'spotify:track:3pcCifdPTc2BbqmWpEhtUd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pcCifdPTc2BbqmWpEhtUd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pcCifdPTc2BbqmWpEhtUd',
#   'duration_ms': 220609,
#   'time_signature': 4},
#  {'danceability': 0.206,
#   'energy': 0.965,
#   'key': 1,
#   'loudness': -5.116,
#   'mode': 1,
#   'speechiness': 0.079,
#   'acousticness': 9.91e-06,
#   'instrumentalness': 0.827,
#   'liveness': 0.367,
#   'valence': 0.168,
#   'tempo': 92.615,
#   'type': 'audio_features',
#   'id': '4Uiw0Sl9yskBaC6P4DcdVD',
#   'uri': 'spotify:track:4Uiw0Sl9yskBaC6P4DcdVD',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Uiw0Sl9yskBaC6P4DcdVD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Uiw0Sl9yskBaC6P4DcdVD',
#   'duration_ms': 299867,
#   'time_signature': 4},
#  {'danceability': 0.566,
#   'energy': 0.888,
#   'key': 5,
#   'loudness': -4.552,
#   'mode': 0,
#   'speechiness': 0.0628,
#   'acousticness': 0.00718,
#   'instrumentalness': 0.0032,
#   'liveness': 0.365,
#   'valence': 0.399,
#   'tempo': 118.49,
#   'type': 'audio_features',
#   'id': '19EPiiOeqUyU3ey5jJxtYs',
#   'uri': 'spotify:track:19EPiiOeqUyU3ey5jJxtYs',
#   'track_href': 'https://api.spotify.com/v1/tracks/19EPiiOeqUyU3ey5jJxtYs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19EPiiOeqUyU3ey5jJxtYs',
#   'duration_ms': 285920,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.599,
#   'key': 5,
#   'loudness': -5.704,
#   'mode': 1,
#   'speechiness': 0.0508,
#   'acousticness': 0.000214,
#   'instrumentalness': 0.000871,
#   'liveness': 0.492,
#   'valence': 0.667,
#   'tempo': 167.778,
#   'type': 'audio_features',
#   'id': '2HbVINmehEbPmjlcueXEJJ',
#   'uri': 'spotify:track:2HbVINmehEbPmjlcueXEJJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HbVINmehEbPmjlcueXEJJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HbVINmehEbPmjlcueXEJJ',
#   'duration_ms': 263560,
#   'time_signature': 4},
#  {'danceability': 0.36,
#   'energy': 0.905,
#   'key': 4,
#   'loudness': -3.808,
#   'mode': 0,
#   'speechiness': 0.0812,
#   'acousticness': 1.37e-05,
#   'instrumentalness': 7.51e-06,
#   'liveness': 0.0753,
#   'valence': 0.309,
#   'tempo': 144.544,
#   'type': 'audio_features',
#   'id': '4xanWVQIzdCf51mg8cd1cQ',
#   'uri': 'spotify:track:4xanWVQIzdCf51mg8cd1cQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xanWVQIzdCf51mg8cd1cQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xanWVQIzdCf51mg8cd1cQ',
#   'duration_ms': 267973,
#   'time_signature': 4},
#  {'danceability': 0.43,
#   'energy': 0.955,
#   'key': 9,
#   'loudness': -4.767,
#   'mode': 1,
#   'speechiness': 0.0424,
#   'acousticness': 0.000807,
#   'instrumentalness': 0,
#   'liveness': 0.044,
#   'valence': 0.366,
#   'tempo': 172.975,
#   'type': 'audio_features',
#   'id': '6HNruFQlzQx4ulL4ppRLYI',
#   'uri': 'spotify:track:6HNruFQlzQx4ulL4ppRLYI',
#   'track_href': 'https://api.spotify.com/v1/tracks/6HNruFQlzQx4ulL4ppRLYI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HNruFQlzQx4ulL4ppRLYI',
#   'duration_ms': 267360,
#   'time_signature': 4},
#  {'danceability': 0.377,
#   'energy': 0.942,
#   'key': 1,
#   'loudness': -4.543,
#   'mode': 0,
#   'speechiness': 0.07,
#   'acousticness': 0.00092,
#   'instrumentalness': 8.88e-05,
#   'liveness': 0.126,
#   'valence': 0.348,
#   'tempo': 129.955,
#   'type': 'audio_features',
#   'id': '1sn6iOK93jnp0Hn5BnNOXy',
#   'uri': 'spotify:track:1sn6iOK93jnp0Hn5BnNOXy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1sn6iOK93jnp0Hn5BnNOXy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sn6iOK93jnp0Hn5BnNOXy',
#   'duration_ms': 254973,
#   'time_signature': 4},
#  {'danceability': 0.218,
#   'energy': 0.11,
#   'key': 8,
#   'loudness': -15.721,
#   'mode': 1,
#   'speechiness': 0.0344,
#   'acousticness': 0.955,
#   'instrumentalness': 0.557,
#   'liveness': 0.138,
#   'valence': 0.0616,
#   'tempo': 105.113,
#   'type': 'audio_features',
#   'id': '0eZN5WsQfmNFICHuw59Zfz',
#   'uri': 'spotify:track:0eZN5WsQfmNFICHuw59Zfz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0eZN5WsQfmNFICHuw59Zfz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eZN5WsQfmNFICHuw59Zfz',
#   'duration_ms': 172936,
#   'time_signature': 4},
#  {'danceability': 0.389,
#   'energy': 0.476,
#   'key': 9,
#   'loudness': -9.342,
#   'mode': 1,
#   'speechiness': 0.0316,
#   'acousticness': 0.619,
#   'instrumentalness': 5.09e-05,
#   'liveness': 0.255,
#   'valence': 0.566,
#   'tempo': 148.117,
#   'type': 'audio_features',
#   'id': '6txWz9UapYHVxEd7dDIHXT',
#   'uri': 'spotify:track:6txWz9UapYHVxEd7dDIHXT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6txWz9UapYHVxEd7dDIHXT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6txWz9UapYHVxEd7dDIHXT',
#   'duration_ms': 217107,
#   'time_signature': 4},
#  {'danceability': 0.517,
#   'energy': 0.506,
#   'key': 2,
#   'loudness': -7.92,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.0928,
#   'instrumentalness': 4.28e-06,
#   'liveness': 0.129,
#   'valence': 0.366,
#   'tempo': 162.083,
#   'type': 'audio_features',
#   'id': '10atyYpAMMlqPHVDt6yER8',
#   'uri': 'spotify:track:10atyYpAMMlqPHVDt6yER8',
#   'track_href': 'https://api.spotify.com/v1/tracks/10atyYpAMMlqPHVDt6yER8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10atyYpAMMlqPHVDt6yER8',
#   'duration_ms': 325001,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.993,
#   'key': 0,
#   'loudness': -3.859,
#   'mode': 1,
#   'speechiness': 0.471,
#   'acousticness': 0.0336,
#   'instrumentalness': 0.955,
#   'liveness': 0.946,
#   'valence': 0.218,
#   'tempo': 177.22,
#   'type': 'audio_features',
#   'id': '0ssWKT6dx54wR6GZfTgYLr',
#   'uri': 'spotify:track:0ssWKT6dx54wR6GZfTgYLr',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ssWKT6dx54wR6GZfTgYLr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ssWKT6dx54wR6GZfTgYLr',
#   'duration_ms': 85053,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.661,
#   'key': 0,
#   'loudness': -9.877,
#   'mode': 1,
#   'speechiness': 0.0503,
#   'acousticness': 0.353,
#   'instrumentalness': 0.94,
#   'liveness': 0.619,
#   'valence': 0.178,
#   'tempo': 151.191,
#   'type': 'audio_features',
#   'id': '4CzTgOmc3Sdm4EgKQWzjQl',
#   'uri': 'spotify:track:4CzTgOmc3Sdm4EgKQWzjQl',
#   'track_href': 'https://api.spotify.com/v1/tracks/4CzTgOmc3Sdm4EgKQWzjQl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CzTgOmc3Sdm4EgKQWzjQl',
#   'duration_ms': 367349,
#   'time_signature': 3},
#  {'danceability': 0.441,
#   'energy': 0.435,
#   'key': 11,
#   'loudness': -8.457,
#   'mode': 0,
#   'speechiness': 0.0261,
#   'acousticness': 0.389,
#   'instrumentalness': 0.0974,
#   'liveness': 0.0982,
#   'valence': 0.487,
#   'tempo': 155.19,
#   'type': 'audio_features',
#   'id': '6V9PDDZ2pHQCUleRXvRYQ1',
#   'uri': 'spotify:track:6V9PDDZ2pHQCUleRXvRYQ1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6V9PDDZ2pHQCUleRXvRYQ1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6V9PDDZ2pHQCUleRXvRYQ1',
#   'duration_ms': 239227,
#   'time_signature': 3},
#  {'danceability': 0.27,
#   'energy': 0.837,
#   'key': 0,
#   'loudness': -7.812,
#   'mode': 1,
#   'speechiness': 0.0518,
#   'acousticness': 0.000454,
#   'instrumentalness': 0.00384,
#   'liveness': 0.386,
#   'valence': 0.549,
#   'tempo': 91.303,
#   'type': 'audio_features',
#   'id': '2jkZB94i573H134wKmsw2y',
#   'uri': 'spotify:track:2jkZB94i573H134wKmsw2y',
#   'track_href': 'https://api.spotify.com/v1/tracks/2jkZB94i573H134wKmsw2y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jkZB94i573H134wKmsw2y',
#   'duration_ms': 220827,
#   'time_signature': 4},
#  {'danceability': 0.74,
#   'energy': 0.682,
#   'key': 9,
#   'loudness': -10.42,
#   'mode': 0,
#   'speechiness': 0.0504,
#   'acousticness': 0.0692,
#   'instrumentalness': 0.53,
#   'liveness': 0.381,
#   'valence': 0.41,
#   'tempo': 113.201,
#   'type': 'audio_features',
#   'id': '0oks4FnzhNp5QPTZtoet7c',
#   'uri': 'spotify:track:0oks4FnzhNp5QPTZtoet7c',
#   'track_href': 'https://api.spotify.com/v1/tracks/0oks4FnzhNp5QPTZtoet7c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oks4FnzhNp5QPTZtoet7c',
#   'duration_ms': 544627,
#   'time_signature': 4},
#  {'danceability': 0.56,
#   'energy': 0.5,
#   'key': 2,
#   'loudness': -10.829,
#   'mode': 0,
#   'speechiness': 0.0272,
#   'acousticness': 0.668,
#   'instrumentalness': 0.833,
#   'liveness': 0.117,
#   'valence': 0.249,
#   'tempo': 139.174,
#   'type': 'audio_features',
#   'id': '5rIhBK9aaVMck0W2YtOwci',
#   'uri': 'spotify:track:5rIhBK9aaVMck0W2YtOwci',
#   'track_href': 'https://api.spotify.com/v1/tracks/5rIhBK9aaVMck0W2YtOwci',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5rIhBK9aaVMck0W2YtOwci',
#   'duration_ms': 281011,
#   'time_signature': 4},
#  {'danceability': 0.479,
#   'energy': 0.407,
#   'key': 1,
#   'loudness': -12.428,
#   'mode': 0,
#   'speechiness': 0.0346,
#   'acousticness': 0.912,
#   'instrumentalness': 0.401,
#   'liveness': 0.11,
#   'valence': 0.338,
#   'tempo': 91.91,
#   'type': 'audio_features',
#   'id': '4eruRiSfDY1jdT03hjyi0i',
#   'uri': 'spotify:track:4eruRiSfDY1jdT03hjyi0i',
#   'track_href': 'https://api.spotify.com/v1/tracks/4eruRiSfDY1jdT03hjyi0i',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eruRiSfDY1jdT03hjyi0i',
#   'duration_ms': 306581,
#   'time_signature': 4},
#  {'danceability': 0.509,
#   'energy': 0.646,
#   'key': 11,
#   'loudness': -6.285,
#   'mode': 0,
#   'speechiness': 0.0365,
#   'acousticness': 0.00028,
#   'instrumentalness': 0.00468,
#   'liveness': 0.0973,
#   'valence': 0.142,
#   'tempo': 124.014,
#   'type': 'audio_features',
#   'id': '72hSmnleYTiiOo23q8ZJIS',
#   'uri': 'spotify:track:72hSmnleYTiiOo23q8ZJIS',
#   'track_href': 'https://api.spotify.com/v1/tracks/72hSmnleYTiiOo23q8ZJIS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72hSmnleYTiiOo23q8ZJIS',
#   'duration_ms': 297460,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.95,
#   'key': 9,
#   'loudness': -4.898,
#   'mode': 1,
#   'speechiness': 0.116,
#   'acousticness': 0.00423,
#   'instrumentalness': 0.06,
#   'liveness': 0.0433,
#   'valence': 0.771,
#   'tempo': 144.017,
#   'type': 'audio_features',
#   'id': '3Kw4KEYQg6JaqUD8ZgAwz6',
#   'uri': 'spotify:track:3Kw4KEYQg6JaqUD8ZgAwz6',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Kw4KEYQg6JaqUD8ZgAwz6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Kw4KEYQg6JaqUD8ZgAwz6',
#   'duration_ms': 222773,
#   'time_signature': 4},
#  {'danceability': 0.475,
#   'energy': 0.606,
#   'key': 4,
#   'loudness': -7.024,
#   'mode': 0,
#   'speechiness': 0.0299,
#   'acousticness': 0.174,
#   'instrumentalness': 0.0418,
#   'liveness': 0.0738,
#   'valence': 0.262,
#   'tempo': 139.838,
#   'type': 'audio_features',
#   'id': '0cPzGMb1WVMCYn4nUcQrGl',
#   'uri': 'spotify:track:0cPzGMb1WVMCYn4nUcQrGl',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cPzGMb1WVMCYn4nUcQrGl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cPzGMb1WVMCYn4nUcQrGl',
#   'duration_ms': 269427,
#   'time_signature': 4},
#  {'danceability': 0.716,
#   'energy': 0.474,
#   'key': 1,
#   'loudness': -9.916,
#   'mode': 0,
#   'speechiness': 0.0298,
#   'acousticness': 0.301,
#   'instrumentalness': 0.00986,
#   'liveness': 0.0992,
#   'valence': 0.528,
#   'tempo': 104.994,
#   'type': 'audio_features',
#   'id': '562C3EC94HrVqmazwHvzej',
#   'uri': 'spotify:track:562C3EC94HrVqmazwHvzej',
#   'track_href': 'https://api.spotify.com/v1/tracks/562C3EC94HrVqmazwHvzej',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/562C3EC94HrVqmazwHvzej',
#   'duration_ms': 232252,
#   'time_signature': 4},
#  {'danceability': 0.431,
#   'energy': 0.906,
#   'key': 9,
#   'loudness': -6.13,
#   'mode': 1,
#   'speechiness': 0.0945,
#   'acousticness': 0.0001,
#   'instrumentalness': 0.0001,
#   'liveness': 0.123,
#   'valence': 0.53,
#   'tempo': 125.459,
#   'type': 'audio_features',
#   'id': '6DoXuH326aAYEN8CnlLmhP',
#   'uri': 'spotify:track:6DoXuH326aAYEN8CnlLmhP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6DoXuH326aAYEN8CnlLmhP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6DoXuH326aAYEN8CnlLmhP',
#   'duration_ms': 223893,
#   'time_signature': 4},
#  {'danceability': 0.382,
#   'energy': 0.985,
#   'key': 1,
#   'loudness': -4.002,
#   'mode': 1,
#   'speechiness': 0.206,
#   'acousticness': 8.49e-06,
#   'instrumentalness': 0.0061,
#   'liveness': 0.362,
#   'valence': 0.206,
#   'tempo': 103.119,
#   'type': 'audio_features',
#   'id': '7iiULg8Kmbnh1vWbh9rnBA',
#   'uri': 'spotify:track:7iiULg8Kmbnh1vWbh9rnBA',
#   'track_href': 'https://api.spotify.com/v1/tracks/7iiULg8Kmbnh1vWbh9rnBA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iiULg8Kmbnh1vWbh9rnBA',
#   'duration_ms': 237733,
#   'time_signature': 4},
#  {'danceability': 0.282,
#   'energy': 0.372,
#   'key': 5,
#   'loudness': -9.771,
#   'mode': 1,
#   'speechiness': 0.0316,
#   'acousticness': 0.652,
#   'instrumentalness': 0.416,
#   'liveness': 0.0754,
#   'valence': 0.0552,
#   'tempo': 105.215,
#   'type': 'audio_features',
#   'id': '6f6pEjgfTtuRROmJ4a7Gf3',
#   'uri': 'spotify:track:6f6pEjgfTtuRROmJ4a7Gf3',
#   'track_href': 'https://api.spotify.com/v1/tracks/6f6pEjgfTtuRROmJ4a7Gf3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6f6pEjgfTtuRROmJ4a7Gf3',
#   'duration_ms': 345887,
#   'time_signature': 3},
#  {'danceability': 0.483,
#   'energy': 0.953,
#   'key': 9,
#   'loudness': -5.051,
#   'mode': 1,
#   'speechiness': 0.178,
#   'acousticness': 0.000122,
#   'instrumentalness': 0.754,
#   'liveness': 0.462,
#   'valence': 0.251,
#   'tempo': 170.023,
#   'type': 'audio_features',
#   'id': '3s5iP7A8jiEdNmRqNFCrdA',
#   'uri': 'spotify:track:3s5iP7A8jiEdNmRqNFCrdA',
#   'track_href': 'https://api.spotify.com/v1/tracks/3s5iP7A8jiEdNmRqNFCrdA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3s5iP7A8jiEdNmRqNFCrdA',
#   'duration_ms': 336493,
#   'time_signature': 4},
#  {'danceability': 0.334,
#   'energy': 0.898,
#   'key': 11,
#   'loudness': -6.821,
#   'mode': 0,
#   'speechiness': 0.196,
#   'acousticness': 0.00406,
#   'instrumentalness': 0.0202,
#   'liveness': 0.162,
#   'valence': 0.226,
#   'tempo': 110.364,
#   'type': 'audio_features',
#   'id': '0xgsyoVvRFSYvV5cdtYhX1',
#   'uri': 'spotify:track:0xgsyoVvRFSYvV5cdtYhX1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xgsyoVvRFSYvV5cdtYhX1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xgsyoVvRFSYvV5cdtYhX1',
#   'duration_ms': 153600,
#   'time_signature': 4},
#  {'danceability': 0.657,
#   'energy': 0.498,
#   'key': 11,
#   'loudness': -11.529,
#   'mode': 1,
#   'speechiness': 0.262,
#   'acousticness': 0.405,
#   'instrumentalness': 0.000479,
#   'liveness': 0.107,
#   'valence': 0.46,
#   'tempo': 164.25,
#   'type': 'audio_features',
#   'id': '2O6X9nPVVQSefg3xOQAo5u',
#   'uri': 'spotify:track:2O6X9nPVVQSefg3xOQAo5u',
#   'track_href': 'https://api.spotify.com/v1/tracks/2O6X9nPVVQSefg3xOQAo5u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O6X9nPVVQSefg3xOQAo5u',
#   'duration_ms': 305240,
#   'time_signature': 4},
#  {'danceability': 0.443,
#   'energy': 0.717,
#   'key': 5,
#   'loudness': -5.498,
#   'mode': 0,
#   'speechiness': 0.0504,
#   'acousticness': 0.182,
#   'instrumentalness': 5.1e-05,
#   'liveness': 0.345,
#   'valence': 0.386,
#   'tempo': 149.582,
#   'type': 'audio_features',
#   'id': '37kUGdEJJ7NaMl5LFW4EA4',
#   'uri': 'spotify:track:37kUGdEJJ7NaMl5LFW4EA4',
#   'track_href': 'https://api.spotify.com/v1/tracks/37kUGdEJJ7NaMl5LFW4EA4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37kUGdEJJ7NaMl5LFW4EA4',
#   'duration_ms': 199360,
#   'time_signature': 4},
#  {'danceability': 0.702,
#   'energy': 0.613,
#   'key': 7,
#   'loudness': -7.852,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.0107,
#   'instrumentalness': 8.44e-06,
#   'liveness': 0.163,
#   'valence': 0.692,
#   'tempo': 147.013,
#   'type': 'audio_features',
#   'id': '4czY6DucD5rKY1y0uvHLws',
#   'uri': 'spotify:track:4czY6DucD5rKY1y0uvHLws',
#   'track_href': 'https://api.spotify.com/v1/tracks/4czY6DucD5rKY1y0uvHLws',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4czY6DucD5rKY1y0uvHLws',
#   'duration_ms': 188877,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.282,
#   'key': 0,
#   'loudness': -13.241,
#   'mode': 1,
#   'speechiness': 0.0286,
#   'acousticness': 0.868,
#   'instrumentalness': 0.529,
#   'liveness': 0.11,
#   'valence': 0.158,
#   'tempo': 112.011,
#   'type': 'audio_features',
#   'id': '1kBGeOp1CDUHVdbK4ergqo',
#   'uri': 'spotify:track:1kBGeOp1CDUHVdbK4ergqo',
#   'track_href': 'https://api.spotify.com/v1/tracks/1kBGeOp1CDUHVdbK4ergqo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1kBGeOp1CDUHVdbK4ergqo',
#   'duration_ms': 224698,
#   'time_signature': 1},
#  {'danceability': 0.692,
#   'energy': 0.458,
#   'key': 11,
#   'loudness': -9.461,
#   'mode': 0,
#   'speechiness': 0.0403,
#   'acousticness': 0.0635,
#   'instrumentalness': 0.516,
#   'liveness': 0.136,
#   'valence': 0.35,
#   'tempo': 150.695,
#   'type': 'audio_features',
#   'id': '3LhtqibvTtjOUrzKs7Vsz1',
#   'uri': 'spotify:track:3LhtqibvTtjOUrzKs7Vsz1',
#   'track_href': 'https://api.spotify.com/v1/tracks/3LhtqibvTtjOUrzKs7Vsz1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3LhtqibvTtjOUrzKs7Vsz1',
#   'duration_ms': 266644,
#   'time_signature': 4},
#  {'danceability': 0.549,
#   'energy': 0.279,
#   'key': 6,
#   'loudness': -13.584,
#   'mode': 0,
#   'speechiness': 0.0266,
#   'acousticness': 0.581,
#   'instrumentalness': 0.00373,
#   'liveness': 0.121,
#   'valence': 0.0752,
#   'tempo': 128.054,
#   'type': 'audio_features',
#   'id': '5YBEul9sgV4aCImJ44hlnc',
#   'uri': 'spotify:track:5YBEul9sgV4aCImJ44hlnc',
#   'track_href': 'https://api.spotify.com/v1/tracks/5YBEul9sgV4aCImJ44hlnc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YBEul9sgV4aCImJ44hlnc',
#   'duration_ms': 356818,
#   'time_signature': 3},
#  {'danceability': 0.244,
#   'energy': 0.928,
#   'key': 4,
#   'loudness': -4.804,
#   'mode': 0,
#   'speechiness': 0.152,
#   'acousticness': 0.000856,
#   'instrumentalness': 0.108,
#   'liveness': 0.915,
#   'valence': 0.38,
#   'tempo': 95.235,
#   'type': 'audio_features',
#   'id': '3ESohZocQvwRDzedmk4fYi',
#   'uri': 'spotify:track:3ESohZocQvwRDzedmk4fYi',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ESohZocQvwRDzedmk4fYi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ESohZocQvwRDzedmk4fYi',
#   'duration_ms': 252400,
#   'time_signature': 4},
#  {'danceability': 0.284,
#   'energy': 0.875,
#   'key': 11,
#   'loudness': -6.069,
#   'mode': 0,
#   'speechiness': 0.0422,
#   'acousticness': 0.00752,
#   'instrumentalness': 0.000461,
#   'liveness': 0.402,
#   'valence': 0.595,
#   'tempo': 75.009,
#   'type': 'audio_features',
#   'id': '1L94M3KIu7QluZe63g64rv',
#   'uri': 'spotify:track:1L94M3KIu7QluZe63g64rv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1L94M3KIu7QluZe63g64rv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1L94M3KIu7QluZe63g64rv',
#   'duration_ms': 340907,
#   'time_signature': 4},
#  {'danceability': 0.293,
#   'energy': 0.462,
#   'key': 5,
#   'loudness': -11.412,
#   'mode': 0,
#   'speechiness': 0.0453,
#   'acousticness': 0.699,
#   'instrumentalness': 0.0444,
#   'liveness': 0.0954,
#   'valence': 0.0623,
#   'tempo': 124.004,
#   'type': 'audio_features',
#   'id': '5AiNZnMDCWwujIENPj9PV9',
#   'uri': 'spotify:track:5AiNZnMDCWwujIENPj9PV9',
#   'track_href': 'https://api.spotify.com/v1/tracks/5AiNZnMDCWwujIENPj9PV9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AiNZnMDCWwujIENPj9PV9',
#   'duration_ms': 251427,
#   'time_signature': 5},
#  {'danceability': 0.271,
#   'energy': 0.737,
#   'key': 1,
#   'loudness': -5.683,
#   'mode': 0,
#   'speechiness': 0.0528,
#   'acousticness': 0.0583,
#   'instrumentalness': 0.00157,
#   'liveness': 0.0498,
#   'valence': 0.402,
#   'tempo': 97.408,
#   'type': 'audio_features',
#   'id': '3OZBa6ovunpZ3mqxFRp2pT',
#   'uri': 'spotify:track:3OZBa6ovunpZ3mqxFRp2pT',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OZBa6ovunpZ3mqxFRp2pT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OZBa6ovunpZ3mqxFRp2pT',
#   'duration_ms': 273347,
#   'time_signature': 3},
#  {'danceability': 0.606,
#   'energy': 0.769,
#   'key': 3,
#   'loudness': -9.215,
#   'mode': 0,
#   'speechiness': 0.0713,
#   'acousticness': 0.14,
#   'instrumentalness': 1.64e-05,
#   'liveness': 0.841,
#   'valence': 0.593,
#   'tempo': 121.042,
#   'type': 'audio_features',
#   'id': '48YkpE5enOln5c7jXSTuHL',
#   'uri': 'spotify:track:48YkpE5enOln5c7jXSTuHL',
#   'track_href': 'https://api.spotify.com/v1/tracks/48YkpE5enOln5c7jXSTuHL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/48YkpE5enOln5c7jXSTuHL',
#   'duration_ms': 218000,
#   'time_signature': 4},
#  {'danceability': 0.738,
#   'energy': 0.483,
#   'key': 6,
#   'loudness': -8.915,
#   'mode': 0,
#   'speechiness': 0.0403,
#   'acousticness': 0.0262,
#   'instrumentalness': 0.616,
#   'liveness': 0.106,
#   'valence': 0.355,
#   'tempo': 93.458,
#   'type': 'audio_features',
#   'id': '23khhseCLQqVMCIT1WMAns',
#   'uri': 'spotify:track:23khhseCLQqVMCIT1WMAns',
#   'track_href': 'https://api.spotify.com/v1/tracks/23khhseCLQqVMCIT1WMAns',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23khhseCLQqVMCIT1WMAns',
#   'duration_ms': 285014,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.746,
#   'key': 8,
#   'loudness': -10.628,
#   'mode': 1,
#   'speechiness': 0.0467,
#   'acousticness': 0.0141,
#   'instrumentalness': 0,
#   'liveness': 0.0661,
#   'valence': 0.229,
#   'tempo': 111.886,
#   'type': 'audio_features',
#   'id': '2i5K0EdMY5zFs9t7KfYK3k',
#   'uri': 'spotify:track:2i5K0EdMY5zFs9t7KfYK3k',
#   'track_href': 'https://api.spotify.com/v1/tracks/2i5K0EdMY5zFs9t7KfYK3k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2i5K0EdMY5zFs9t7KfYK3k',
#   'duration_ms': 170000,
#   'time_signature': 4},
#  {'danceability': 0.323,
#   'energy': 0.883,
#   'key': 6,
#   'loudness': -3.308,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'acousticness': 0.34,
#   'instrumentalness': 0,
#   'liveness': 0.97,
#   'valence': 0.46,
#   'tempo': 100.022,
#   'type': 'audio_features',
#   'id': '2JDC83caNNDzY51IzsPY6G',
#   'uri': 'spotify:track:2JDC83caNNDzY51IzsPY6G',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JDC83caNNDzY51IzsPY6G',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JDC83caNNDzY51IzsPY6G',
#   'duration_ms': 296520,
#   'time_signature': 4},
#  {'danceability': 0.412,
#   'energy': 0.919,
#   'key': 5,
#   'loudness': -7.291,
#   'mode': 1,
#   'speechiness': 0.184,
#   'acousticness': 0.0124,
#   'instrumentalness': 0.0601,
#   'liveness': 0.424,
#   'valence': 0.572,
#   'tempo': 166.367,
#   'type': 'audio_features',
#   'id': '0tZ3mElWcr74OOhKEiNz1x',
#   'uri': 'spotify:track:0tZ3mElWcr74OOhKEiNz1x',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tZ3mElWcr74OOhKEiNz1x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tZ3mElWcr74OOhKEiNz1x',
#   'duration_ms': 229467,
#   'time_signature': 4},
#  {'danceability': 0.295,
#   'energy': 0.929,
#   'key': 9,
#   'loudness': -5.663,
#   'mode': 1,
#   'speechiness': 0.352,
#   'acousticness': 0.192,
#   'instrumentalness': 0,
#   'liveness': 0.922,
#   'valence': 0.543,
#   'tempo': 166.864,
#   'type': 'audio_features',
#   'id': '4Ly7nHWRfTgGoFXJGtrixU',
#   'uri': 'spotify:track:4Ly7nHWRfTgGoFXJGtrixU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Ly7nHWRfTgGoFXJGtrixU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ly7nHWRfTgGoFXJGtrixU',
#   'duration_ms': 238013,
#   'time_signature': 4},
#  {'danceability': 0.378,
#   'energy': 0.0541,
#   'key': 8,
#   'loudness': -19.237,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'acousticness': 0.93,
#   'instrumentalness': 0.00219,
#   'liveness': 0.117,
#   'valence': 0.175,
#   'tempo': 115.366,
#   'type': 'audio_features',
#   'id': '2ax8gOAjvG2nbztOKKQRsk',
#   'uri': 'spotify:track:2ax8gOAjvG2nbztOKKQRsk',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ax8gOAjvG2nbztOKKQRsk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ax8gOAjvG2nbztOKKQRsk',
#   'duration_ms': 308622,
#   'time_signature': 5},
#  {'danceability': 0.454,
#   'energy': 0.881,
#   'key': 9,
#   'loudness': -6.181,
#   'mode': 1,
#   'speechiness': 0.0826,
#   'acousticness': 0.00764,
#   'instrumentalness': 0.00249,
#   'liveness': 0.11,
#   'valence': 0.151,
#   'tempo': 139.032,
#   'type': 'audio_features',
#   'id': '1Msrp5bJ5Y0ReJDS5HpQO6',
#   'uri': 'spotify:track:1Msrp5bJ5Y0ReJDS5HpQO6',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Msrp5bJ5Y0ReJDS5HpQO6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Msrp5bJ5Y0ReJDS5HpQO6',
#   'duration_ms': 234600,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.967,
#   'key': 10,
#   'loudness': -6.103,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.000161,
#   'instrumentalness': 0.00811,
#   'liveness': 0.206,
#   'valence': 0.433,
#   'tempo': 140.467,
#   'type': 'audio_features',
#   'id': '12d8CMvcWNBrJ7rMdT1kmt',
#   'uri': 'spotify:track:12d8CMvcWNBrJ7rMdT1kmt',
#   'track_href': 'https://api.spotify.com/v1/tracks/12d8CMvcWNBrJ7rMdT1kmt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12d8CMvcWNBrJ7rMdT1kmt',
#   'duration_ms': 234093,
#   'time_signature': 4},
#  {'danceability': 0.274,
#   'energy': 0.472,
#   'key': 9,
#   'loudness': -7.614,
#   'mode': 0,
#   'speechiness': 0.0263,
#   'acousticness': 0.0131,
#   'instrumentalness': 0.069,
#   'liveness': 0.0802,
#   'valence': 0.14,
#   'tempo': 148.996,
#   'type': 'audio_features',
#   'id': '552BIJ9kKwwqiGf4YojYbL',
#   'uri': 'spotify:track:552BIJ9kKwwqiGf4YojYbL',
#   'track_href': 'https://api.spotify.com/v1/tracks/552BIJ9kKwwqiGf4YojYbL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/552BIJ9kKwwqiGf4YojYbL',
#   'duration_ms': 269093,
#   'time_signature': 4}]

# %%
ftrs = pd.DataFrame(features)
ftrs.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.299   0.263    9   -13.207     0       0.0323      0.968000
# 1         0.576   0.738   11    -8.122     1       0.0353      0.000387
# 2         0.415   0.867   11    -5.497     0       0.0387      0.000057
# 3         0.443   0.781    1    -4.277     1       0.0377      0.000013
# 4         0.541   0.847   11    -6.520     1       0.0297      0.303000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.857000    0.1260    0.113  137.848  audio_features
# 1          0.001310    0.1300    0.675  168.132  audio_features
# 2          0.000192    0.0883    0.360  157.902  audio_features
# 3          0.205000    0.1660    0.372   71.841  audio_features
# 4          0.271000    0.1090    0.620  148.937  audio_features
#
#                        id                                   uri  \
# 0  1uRxyAup7OYrlh2SHJb80N  spotify:track:1uRxyAup7OYrlh2SHJb80N
# 1  0LtsuNRz3IMRrHCYO9fKRk  spotify:track:0LtsuNRz3IMRrHCYO9fKRk
# 2  07q6QTQXyPRCf7GbLakRPr  spotify:track:07q6QTQXyPRCf7GbLakRPr
# 3  1158ckiB5S4cpsdYHDB9IF  spotify:track:1158ckiB5S4cpsdYHDB9IF
# 4  3pcCifdPTc2BbqmWpEhtUd  spotify:track:3pcCifdPTc2BbqmWpEhtUd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1uRxyAup7OYr...
# 1  https://api.spotify.com/v1/tracks/0LtsuNRz3IMR...
# 2  https://api.spotify.com/v1/tracks/07q6QTQXyPRC...
# 3  https://api.spotify.com/v1/tracks/1158ckiB5S4c...
# 4  https://api.spotify.com/v1/tracks/3pcCifdPTc2B...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1uRx...       384439
# 1  https://api.spotify.com/v1/audio-analysis/0Lts...       238400
# 2  https://api.spotify.com/v1/audio-analysis/07q6...       249987
# 3  https://api.spotify.com/v1/audio-analysis/1158...       214760
# 4  https://api.spotify.com/v1/audio-analysis/3pcC...       220609
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4

# %%
ftrs.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     50.000000  50.000000  50.000000  50.000000  50.000000    50.000000
# mean       0.448440   0.681982   6.080000  -7.919280   0.520000     0.079048
# std        0.143837   0.250418   3.837729   3.384432   0.504672     0.087970
# min        0.206000   0.054100   0.000000 -19.237000   0.000000     0.026100
# 25%        0.325750   0.477750   2.250000  -9.850500   0.000000     0.032825
# 50%        0.436000   0.737500   6.000000  -7.157500   1.000000     0.043850
# 75%        0.557250   0.903250   9.000000  -5.497250   1.000000     0.077075
# max        0.740000   0.993000  11.000000  -3.308000   1.000000     0.471000
#
#        acousticness  instrumentalness   liveness    valence       tempo  \
# count     50.000000         50.000000  50.000000  50.000000   50.000000
# mean       0.221199          0.195146   0.261046   0.360046  130.386460
# std        0.313461          0.305589   0.260054   0.187652   27.837032
# min        0.000008          0.000000   0.043300   0.055200   71.841000
# 25%        0.000819          0.000259   0.100900   0.209000  106.502250
# 50%        0.029900          0.007105   0.127500   0.363000  133.901500
# 75%        0.349750          0.368500   0.366500   0.517750  150.416750
# max        0.968000          0.955000   0.970000   0.771000  177.220000
#
#          duration_ms  time_signature
# count      50.000000       50.000000
# mean   263404.500000        3.860000
# std     69715.589693        0.571786
# min     85053.000000        1.000000
# 25%    224094.250000        4.000000
# 50%    253686.500000        4.000000
# 75%    297225.000000        4.000000
# max    544627.000000        5.000000

# %%
user_profile = ftrs.describe().loc['mean']
user_profile
# Out:
# danceability             0.448440
# energy                   0.681982
# key                      6.080000
# loudness                -7.919280
# mode                     0.520000
# speechiness              0.079048
# acousticness             0.221199
# instrumentalness         0.195146
# liveness                 0.261046
# valence                  0.360046
# tempo                  130.386460
# duration_ms         263404.500000
# time_signature           3.860000
# Name: mean, dtype: float64

# %% [markdown]
# ## Looking for artists to recommend

# %%
top_artists
# Out:
# {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#    'followers': {'href': None, 'total': 4881671},
#    'genres': ['alternative rock',
#     'art rock',
#     'melancholia',
#     'oxford indie',
#     'permanent wave',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#    'id': '4Z8W4fKeB5YxbusRsdQVPb',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/afcd616e1ef2d2786f47b3b4a8a6aeea24a72adc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/563754af10b3d9f9f62a3458e699f58c4a02870f',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/4067ea225d8b42fa6951857d3af27dd07d60f3c6',
#      'width': 160}],
#    'name': 'Radiohead',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/09xj0S68Y1OU1vHMCZAIvz'},
#    'followers': {'href': None, 'total': 1812372},
#    'genres': ['latin',
#     'latin alternative',
#     'latin rock',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/09xj0S68Y1OU1vHMCZAIvz',
#    'id': '09xj0S68Y1OU1vHMCZAIvz',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/c73784c94d239a1f3fdcaa30305b3c38b69f0ad5',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/f64dc3078513ede005f474472d7f816ea497b708',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/1bb15ac091152fd94cafad1edc7b35b7e1d6d8ec',
#      'width': 160}],
#    'name': 'Café Tacvba',
#    'popularity': 75,
#    'type': 'artist',
#    'uri': 'spotify:artist:09xj0S68Y1OU1vHMCZAIvz'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6olE6TJLqED3rqDCT0FyPh'},
#    'followers': {'href': None, 'total': 10247841},
#    'genres': ['alternative rock',
#     'grunge',
#     'permanent wave',
#     'post-grunge',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/6olE6TJLqED3rqDCT0FyPh',
#    'id': '6olE6TJLqED3rqDCT0FyPh',
#    'images': [{'height': 1057,
#      'url': 'https://i.scdn.co/image/84282c28d851a700132356381fcfbadc67ff498b',
#      'width': 1000},
#     {'height': 677,
#      'url': 'https://i.scdn.co/image/a4e10b79a642e9891383448cbf37d7266a6883d6',
#      'width': 640},
#     {'height': 211,
#      'url': 'https://i.scdn.co/image/42ae0f180f16e2f21c1f2212717fc436f5b95451',
#      'width': 200},
#     {'height': 68,
#      'url': 'https://i.scdn.co/image/e797ad36d56c3fc8fa06c6fe91263a15bf8391b8',
#      'width': 64}],
#    'name': 'Nirvana',
#    'popularity': 84,
#    'type': 'artist',
#    'uri': 'spotify:artist:6olE6TJLqED3rqDCT0FyPh'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#    'followers': {'href': None, 'total': 24370297},
#    'genres': ['permanent wave', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#    'id': '4gzpq5DPGxSnKTe4SA8HAU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/c942640d486338e4ae144a497f0cfd3f35ceb7af',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/abaac5ab46ccff97dc036627045c04025605506d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/e3fe81cd5df736c1ceec6b59d7d801cf50e6a03a',
#      'width': 160}],
#    'name': 'Coldplay',
#    'popularity': 91,
#    'type': 'artist',
#    'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2FS22haX3FYbyOsUAkuYqZ'},
#    'followers': {'href': None, 'total': 1684154},
#    'genres': ['argentine rock',
#     'latin alternative',
#     'latin rock',
#     'rock en espanol',
#     'ska argentino'],
#    'href': 'https://api.spotify.com/v1/artists/2FS22haX3FYbyOsUAkuYqZ',
#    'id': '2FS22haX3FYbyOsUAkuYqZ',
#    'images': [{'height': 751,
#      'url': 'https://i.scdn.co/image/fa61694bc1b21f212fef31d4f6b89e1d0b9ff7fa',
#      'width': 1000},
#     {'height': 480,
#      'url': 'https://i.scdn.co/image/356b77649f85211b2f9f1da048a98122cfe7f007',
#      'width': 639},
#     {'height': 150,
#      'url': 'https://i.scdn.co/image/b256571c95995b91e6881e80de553abfe3cac74b',
#      'width': 200},
#     {'height': 48,
#      'url': 'https://i.scdn.co/image/c49b77f926f128d2b6ed9e9b146f49df3c8deee2',
#      'width': 64}],
#    'name': 'Los Fabulosos Cadillacs',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:2FS22haX3FYbyOsUAkuYqZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7jy3rLJdDQY21OgRLCZ9sD'},
#    'followers': {'href': None, 'total': 7259097},
#    'genres': ['alternative metal',
#     'alternative rock',
#     'modern rock',
#     'permanent wave',
#     'post-grunge',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/7jy3rLJdDQY21OgRLCZ9sD',
#    'id': '7jy3rLJdDQY21OgRLCZ9sD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/4357f7b293c92d3a70a087552a27f69f431e16ae',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/c508060cb93f3d2f43ad0dc38602eebcbe39d16d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/086a436ec6830acef5db63d526cb86e066e652de',
#      'width': 160}],
#    'name': 'Foo Fighters',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:7jy3rLJdDQY21OgRLCZ9sD'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'},
#    'followers': {'href': None, 'total': 12635308},
#    'genres': ['alternative rock',
#     'funk metal',
#     'funk rock',
#     'permanent wave',
#     'post-grunge',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5',
#    'id': '0L8ExT028jH3ddEcZwqJJ5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/89bc3c14aa2b4f250033ffcf5f322b2a553d9331',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/7251ac7f3c0262cfcfad32e214deda639a2b4b46',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/8def8c4db6061deb04daca08e43bcde57181ec8b',
#      'width': 160}],
#    'name': 'Red Hot Chili Peppers',
#    'popularity': 87,
#    'type': 'artist',
#    'uri': 'spotify:artist:0L8ExT028jH3ddEcZwqJJ5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/55qSbU11psT1e0HlLaTZPB'},
#    'followers': {'href': None, 'total': 167083},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican indie',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/55qSbU11psT1e0HlLaTZPB',
#    'id': '55qSbU11psT1e0HlLaTZPB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/34a619c202d0b32c4ade2563f3c1184135a80b56',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/6c898c216698b78035cb467d1a372e81ed4df16e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/1f28a338a99e1d41d30aa5cc7b92d095150c7ff9',
#      'width': 160}],
#    'name': 'Jumbo',
#    'popularity': 55,
#    'type': 'artist',
#    'uri': 'spotify:artist:55qSbU11psT1e0HlLaTZPB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#    'followers': {'href': None, 'total': 23430454},
#    'genres': ['glam rock', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#    'id': '1dfeR4HaWDbWqFHLkxsg1d',
#    'images': [{'height': 806,
#      'url': 'https://i.scdn.co/image/b040846ceba13c3e9c125d68389491094e7f2982',
#      'width': 999},
#     {'height': 516,
#      'url': 'https://i.scdn.co/image/af2b8e57f6d7b5d43a616bd1e27ba552cd8bfd42',
#      'width': 640},
#     {'height': 161,
#      'url': 'https://i.scdn.co/image/c06971e9ff81696699b829484e3be165f4e64368',
#      'width': 200},
#     {'height': 52,
#      'url': 'https://i.scdn.co/image/6dd0ffd270903d1884edf9058c49f58b03db893d',
#      'width': 64}],
#    'name': 'Queen',
#    'popularity': 92,
#    'type': 'artist',
#    'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2VYQTNDsvvKN9wmU5W7xpj'},
#    'followers': {'href': None, 'total': 2436485},
#    'genres': ['alternative metal',
#     'industrial',
#     'industrial metal',
#     'industrial rock',
#     'nu metal',
#     'wrestling'],
#    'href': 'https://api.spotify.com/v1/artists/2VYQTNDsvvKN9wmU5W7xpj',
#    'id': '2VYQTNDsvvKN9wmU5W7xpj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/42436559ae029809674c8498f2c998e138a7a757',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/894fc33a5d7df99c5464ec6aacb2957b42b169fd',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/17e5a4d7060361f729658499e223fcb7b76967b1',
#      'width': 160}],
#    'name': 'Marilyn Manson',
#    'popularity': 76,
#    'type': 'artist',
#    'uri': 'spotify:artist:2VYQTNDsvvKN9wmU5W7xpj'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0k17h0D3J5VfsdmQ1iZtE9'},
#    'followers': {'href': None, 'total': 11434268},
#    'genres': ['album rock',
#     'art rock',
#     'classic rock',
#     'progressive rock',
#     'psychedelic rock',
#     'rock',
#     'symphonic rock'],
#    'href': 'https://api.spotify.com/v1/artists/0k17h0D3J5VfsdmQ1iZtE9',
#    'id': '0k17h0D3J5VfsdmQ1iZtE9',
#    'images': [{'height': 977,
#      'url': 'https://i.scdn.co/image/e69f71e2be4b67b82af90fb8e9d805715e0684fa',
#      'width': 1000},
#     {'height': 625,
#      'url': 'https://i.scdn.co/image/d011c95081cd9a329e506abd7ded47535d524a07',
#      'width': 640},
#     {'height': 195,
#      'url': 'https://i.scdn.co/image/f0a39a8a196a87a7236bdcf8a8708f6d5d3547cc',
#      'width': 200},
#     {'height': 63,
#      'url': 'https://i.scdn.co/image/ec1fb7127168dbaa962404031409c5a293b95ec6',
#      'width': 64}],
#    'name': 'Pink Floyd',
#    'popularity': 85,
#    'type': 'artist',
#    'uri': 'spotify:artist:0k17h0D3J5VfsdmQ1iZtE9'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4tZwfgrHOc3mvqYlEYSvVi'},
#    'followers': {'href': None, 'total': 5976483},
#    'genres': ['electro', 'filter house'],
#    'href': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi',
#    'id': '4tZwfgrHOc3mvqYlEYSvVi',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/b8aaf4b179bb0a52f29a810fdb0f9d5c16ec2c75',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/8e189c820ba32ffd332393eb60cb1def63bed070',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/70bedd072be9725a0b05e07e3338959e826e7dd7',
#      'width': 160}],
#    'name': 'Daft Punk',
#    'popularity': 84,
#    'type': 'artist',
#    'uri': 'spotify:artist:4tZwfgrHOc3mvqYlEYSvVi'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ghvu1VvMGScGpOUJBAHNH'},
#    'followers': {'href': None, 'total': 1504725},
#    'genres': ['alternative metal',
#     'alternative rock',
#     'modern rock',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rock',
#     'sacramento indie'],
#    'href': 'https://api.spotify.com/v1/artists/6Ghvu1VvMGScGpOUJBAHNH',
#    'id': '6Ghvu1VvMGScGpOUJBAHNH',
#    'images': [{'height': 667,
#      'url': 'https://i.scdn.co/image/662520c52f6295e66124f7fd346204a2c08f4e4f',
#      'width': 1000},
#     {'height': 427,
#      'url': 'https://i.scdn.co/image/f4d4a179651bea17d1e34765dc4f0a16eb674ea1',
#      'width': 640},
#     {'height': 133,
#      'url': 'https://i.scdn.co/image/43eb33149dfd546dd528b0da3c08d699ae93d1d5',
#      'width': 200},
#     {'height': 43,
#      'url': 'https://i.scdn.co/image/e61e4b9f5980bfdf70a159a1ebd8d530135bcaf5',
#      'width': 64}],
#    'name': 'Deftones',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:6Ghvu1VvMGScGpOUJBAHNH'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1rCIEwPp5OnXW0ornlSsRl'},
#    'followers': {'href': None, 'total': 522740},
#    'genres': ['alternative dance',
#     'canadian indie',
#     'canadian rock',
#     'dance-punk',
#     'electropop',
#     'garage rock',
#     'indie pop',
#     'indie rock',
#     'indietronica',
#     'lilith',
#     'metropopolis',
#     'modern rock',
#     'neo-synthpop',
#     'new rave',
#     'shimmer pop'],
#    'href': 'https://api.spotify.com/v1/artists/1rCIEwPp5OnXW0ornlSsRl',
#    'id': '1rCIEwPp5OnXW0ornlSsRl',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/e59862715ef4e242a8d835b8d41a7fe60249e151',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/06a31fece9046e3b50113cd2f3ab467a9ddfa601',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/6f757fb618d3cc34f9174a2e998162c6d38edd0d',
#      'width': 160}],
#    'name': 'Metric',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:1rCIEwPp5OnXW0ornlSsRl'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1gR0gsQYfi6joyO1dlp76N'},
#    'followers': {'href': None, 'total': 857113},
#    'genres': ['alternative dance',
#     'dance-punk',
#     'disco house',
#     'electro house',
#     'electronica',
#     'filter house',
#     'new rave'],
#    'href': 'https://api.spotify.com/v1/artists/1gR0gsQYfi6joyO1dlp76N',
#    'id': '1gR0gsQYfi6joyO1dlp76N',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/58d9c87c082d3af6f8ea8dc7ac44dd3823280b45',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/01a786afab31738885eaf683872cf9b7ea9ee150',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/218299a94e8af3a5b324af8fe14055076f7371b7',
#      'width': 160}],
#    'name': 'Justice',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:1gR0gsQYfi6joyO1dlp76N'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7eBQrhxTHcor6gcbcLhqE5'},
#    'followers': {'href': None, 'total': 206199},
#    'genres': ['guadalajara indie',
#     'latin alternative',
#     'latin rock',
#     'mexican indie',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/7eBQrhxTHcor6gcbcLhqE5',
#    'id': '7eBQrhxTHcor6gcbcLhqE5',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/33b8a41ab40b2b27f731583f2254b9c68f0d5970',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/350b324b2b9fbaf6e229b0939e168dfb9a041575',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/3f95fae701e6d35e208a9c53f5367d3c1de10cb3',
#      'width': 160}],
#    'name': 'Porter',
#    'popularity': 61,
#    'type': 'artist',
#    'uri': 'spotify:artist:7eBQrhxTHcor6gcbcLhqE5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6UUrUCIZtQeOf8tC0WuzRy'},
#    'followers': {'href': None, 'total': 900810},
#    'genres': ['bow pop',
#     'chamber pop',
#     'compositional ambient',
#     'dream pop',
#     'ethereal wave',
#     'icelandic pop',
#     'icelandic rock',
#     'melancholia',
#     'nordic post-rock',
#     'post-rock'],
#    'href': 'https://api.spotify.com/v1/artists/6UUrUCIZtQeOf8tC0WuzRy',
#    'id': '6UUrUCIZtQeOf8tC0WuzRy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a59d8eccbfa73e26b6be484cc4b02951bbb40bb3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/441de7b454cc99883de5dff6dc114df9e6d57d31',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/c4499526cbe66d40aecd053450cd06e7f9c7afca',
#      'width': 160}],
#    'name': 'Sigur Rós',
#    'popularity': 64,
#    'type': 'artist',
#    'uri': 'spotify:artist:6UUrUCIZtQeOf8tC0WuzRy'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#    'followers': {'href': None, 'total': 5427080},
#    'genres': ['alternative rock',
#     'grunge',
#     'permanent wave',
#     'post-grunge',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#    'id': '1w5Kfo2jwwIPruYS2UWh56',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/8a7775f16a99af5d353d4eb31ec0ccf908a6a6d1',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/7d40296db84567ff1f76c6bb3a561de53bccadb3',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/4733adb065f2e5c637bf7362413e9d2a9e330310',
#      'width': 160}],
#    'name': 'Pearl Jam',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6IdtcAwaNVAggwd6sCKgTI'},
#    'followers': {'href': None, 'total': 2815533},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/6IdtcAwaNVAggwd6sCKgTI',
#    'id': '6IdtcAwaNVAggwd6sCKgTI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/41c021a7c530aedfba2ef7a132b77af6b93bfce3',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/e260dec8d495360763b35ac1c9e34606dab1025d',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ce81c33d79a9a1fbcbe4e52de2343b531851a757',
#      'width': 160}],
#    'name': 'Zoé',
#    'popularity': 76,
#    'type': 'artist',
#    'uri': 'spotify:artist:6IdtcAwaNVAggwd6sCKgTI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6liAMWkVf5LH7YR9yfFy1Y'},
#    'followers': {'href': None, 'total': 1081320},
#    'genres': ['art pop', 'electronica', 'laboratorio', 'trip hop'],
#    'href': 'https://api.spotify.com/v1/artists/6liAMWkVf5LH7YR9yfFy1Y',
#    'id': '6liAMWkVf5LH7YR9yfFy1Y',
#    'images': [{'height': 680,
#      'url': 'https://i.scdn.co/image/05d3721739aee511a898081ab140daa7890a0120',
#      'width': 1000},
#     {'height': 435,
#      'url': 'https://i.scdn.co/image/27802710b01453435de93d71bab2c9988a841ace',
#      'width': 640},
#     {'height': 136,
#      'url': 'https://i.scdn.co/image/333ac38e3c8ab5fcdc238cc46535a4abb802eccc',
#      'width': 200},
#     {'height': 44,
#      'url': 'https://i.scdn.co/image/10052054c06626f6a900e687b20886e462f75568',
#      'width': 64}],
#    'name': 'Portishead',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6MxyNXnnmwQwdW2PD0gXYO'},
#    'followers': {'href': None, 'total': 452041},
#    'genres': ['argentine rock',
#     'latin alternative',
#     'latin rock',
#     'rock en espanol',
#     'rock nacional',
#     'ska argentino'],
#    'href': 'https://api.spotify.com/v1/artists/6MxyNXnnmwQwdW2PD0gXYO',
#    'id': '6MxyNXnnmwQwdW2PD0gXYO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/4ae353b44c07546c12da35cf4bd58b0f976588e8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ffff566e2a24f686977b88e3c19cd275320fc131',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/7d2e23958ac1d330fee78549cca71e438a412b72',
#      'width': 160}],
#    'name': 'Bersuit Vergarabat',
#    'popularity': 67,
#    'type': 'artist',
#    'uri': 'spotify:artist:6MxyNXnnmwQwdW2PD0gXYO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#    'followers': {'href': None, 'total': 502554},
#    'genres': ['art pop',
#     'chamber pop',
#     'electronica',
#     'indie rock',
#     'new rave',
#     'oxford indie'],
#    'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#    'id': '4CvTDPKA6W06DRfBnZKrau',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/b4f83f1c59467d4e7f3abb7a115222d71c4d884c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/df9c1e00bd8cbab3c34af5ac8b2964c6a4f821c5',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/8f6ec788c2c69105ae06732ff2e2611b4810b698',
#      'width': 160}],
#    'name': 'Thom Yorke',
#    'popularity': 66,
#    'type': 'artist',
#    'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7An4yvF7hDYDolN4m5zKBp'},
#    'followers': {'href': None, 'total': 4381251},
#    'genres': ['argentine rock',
#     'latin alternative',
#     'latin rock',
#     'rock en espanol',
#     'ska argentino'],
#    'href': 'https://api.spotify.com/v1/artists/7An4yvF7hDYDolN4m5zKBp',
#    'id': '7An4yvF7hDYDolN4m5zKBp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/24cf887715b0f35ef56b01b3127bc85486485155',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/f6de30df794fbfc3ede641c04a70b8b30b178035',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/27109e0a177218b636bfef81e6dc455cbe34ccac',
#      'width': 160}],
#    'name': 'Soda Stereo',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:7An4yvF7hDYDolN4m5zKBp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2aaLAng2L2aWD2FClzwiep'},
#    'followers': {'href': None, 'total': 977052},
#    'genres': ['metal', 'progressive metal', 'progressive rock', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/2aaLAng2L2aWD2FClzwiep',
#    'id': '2aaLAng2L2aWD2FClzwiep',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/7a45b5792bde17098a0037509018f7f5bbfc6a99',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/4dd1dfaf7eb5d9140d92ebd9e087a98513a2ce71',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/d51a2bb99d8f4b4f9ef55a0d00ddaed92cf35680',
#      'width': 160}],
#    'name': 'Dream Theater',
#    'popularity': 69,
#    'type': 'artist',
#    'uri': 'spotify:artist:2aaLAng2L2aWD2FClzwiep'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ye2Wgw4gimLv2eAKyk1NB'},
#    'followers': {'href': None, 'total': 13084584},
#    'genres': ['hard rock',
#     'metal',
#     'old school thrash',
#     'rock',
#     'speed metal',
#     'thrash metal'],
#    'href': 'https://api.spotify.com/v1/artists/2ye2Wgw4gimLv2eAKyk1NB',
#    'id': '2ye2Wgw4gimLv2eAKyk1NB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/5a06711d7fc48d5e0e3f9a3274ffed3f0af1bd91',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/0c22030833eb55c14013bb36eb6a429328868c29',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/c1fb4d88de092b5617e649bd4c406b5cab7d3ddd',
#      'width': 160}],
#    'name': 'Metallica',
#    'popularity': 86,
#    'type': 'artist',
#    'uri': 'spotify:artist:2ye2Wgw4gimLv2eAKyk1NB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tAICgiSR5PfYY4B8qsoAU'},
#    'followers': {'href': None, 'total': 1281226},
#    'genres': ['argentine rock',
#     'cantautor',
#     'latin alternative',
#     'latin rock',
#     'pop argentino',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/3tAICgiSR5PfYY4B8qsoAU',
#    'id': '3tAICgiSR5PfYY4B8qsoAU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a2b50e26dbbc13c04ad05907b58c2e3a0bb52926',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/97d12af7deccffef5cda3521e829f4e09cf74294',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/18cd4b5775ed98d098edfbd65d8582eeb788280c',
#      'width': 160}],
#    'name': 'Andrés Calamaro',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:3tAICgiSR5PfYY4B8qsoAU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qAPxVwIQRBuz5ImPUxpZT'},
#    'followers': {'href': None, 'total': 1283034},
#    'genres': ['latin alternative',
#     'latin rock',
#     'rock en espanol',
#     'spanish rock'],
#    'href': 'https://api.spotify.com/v1/artists/3qAPxVwIQRBuz5ImPUxpZT',
#    'id': '3qAPxVwIQRBuz5ImPUxpZT',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/9ffe8fc45b8bad986946367201a3e547d9a6dc6a',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/d5008e5652d595a9c678b5791cc2febe52f2991a',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/5bc475c4723f1e45ca2be335f2a824f981989f91',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/20b68b7f3e35f2c35d36462298da0c3d33a314f0',
#      'width': 64}],
#    'name': 'Heroes Del Silencio',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:3qAPxVwIQRBuz5ImPUxpZT'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GImnM7WYVp95431ypofy9'},
#    'followers': {'href': None, 'total': 1767505},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican rock',
#     'nu-cumbia',
#     'rock en espanol',
#     'rock urbano mexicano'],
#    'href': 'https://api.spotify.com/v1/artists/1GImnM7WYVp95431ypofy9',
#    'id': '1GImnM7WYVp95431ypofy9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/b098fa8cf927f46e7a31ff8305379de102462ab1',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/907043dd1aa5fd94581322a80269e6bf8547b0aa',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/60be0837c8b4038a6487bcb0602a1954c5858352',
#      'width': 160}],
#    'name': 'Caifanes',
#    'popularity': 73,
#    'type': 'artist',
#    'uri': 'spotify:artist:1GImnM7WYVp95431ypofy9'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3RNrq3jvMZxD9ZyoOZbQOD'},
#    'followers': {'href': None, 'total': 3549479},
#    'genres': ['alternative metal',
#     'funk metal',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/3RNrq3jvMZxD9ZyoOZbQOD',
#    'id': '3RNrq3jvMZxD9ZyoOZbQOD',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/2277b8f0ae9316fd9572830763df39531fd224b8',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/45d35e47fca2db9992f5ca4c05c73a14f9f933f2',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/5a8552a0b7c2d26a0adf6150ae7b61b2a4936f88',
#      'width': 160}],
#    'name': 'Korn',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:3RNrq3jvMZxD9ZyoOZbQOD'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#    'followers': {'href': None, 'total': 4643973},
#    'genres': ['album rock',
#     'classic rock',
#     'piano rock',
#     'psychedelic rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#    'id': '22WZ7M8sxp5THdruNY3gXt',
#    'images': [{'height': 1253,
#      'url': 'https://i.scdn.co/image/b8c3d75acf2d800defb05b8515445e6d064c97d5',
#      'width': 919},
#     {'height': 873,
#      'url': 'https://i.scdn.co/image/fdca4a508d930f9add0c73c33883a691cc3d8eaa',
#      'width': 640},
#     {'height': 273,
#      'url': 'https://i.scdn.co/image/9c97e2cbfe6d056026c2904a3f0e2c286f4b4061',
#      'width': 200},
#     {'height': 87,
#      'url': 'https://i.scdn.co/image/3da16e239906bb95e5c4858596b695deebf87260',
#      'width': 64}],
#    'name': 'The Doors',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/27Owkm4TGlMqb0BqaEt3PW'},
#    'followers': {'href': None, 'total': 1545409},
#    'genres': ['latin alternative',
#     'latin hip hop',
#     'latin rock',
#     'mexican hip hop',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/27Owkm4TGlMqb0BqaEt3PW',
#    'id': '27Owkm4TGlMqb0BqaEt3PW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/fe102c7c001165c42f2bbe5074ddec904460cda6',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/b194053d2e5f44382bc66576c17b817c08714918',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/433dcb1558212ff2d97002ef1d4404215566b006',
#      'width': 160}],
#    'name': 'Molotov',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:27Owkm4TGlMqb0BqaEt3PW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/14xs9RNQa8MHRS7YU8Bzfk'},
#    'followers': {'href': None, 'total': 321978},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican rock',
#     'rock en espanol',
#     'rock urbano mexicano'],
#    'href': 'https://api.spotify.com/v1/artists/14xs9RNQa8MHRS7YU8Bzfk',
#    'id': '14xs9RNQa8MHRS7YU8Bzfk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/5ab37d4f2ed87308da61a6dba664e1e9c2a66714',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/24b429032d795fd0ba79917f8c337b35dd6e112c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/04b9ea9ed100c05407ec33bd14d0a4e96baae43c',
#      'width': 160}],
#    'name': 'Cuca',
#    'popularity': 58,
#    'type': 'artist',
#    'uri': 'spotify:artist:14xs9RNQa8MHRS7YU8Bzfk'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#    'followers': {'href': None, 'total': 1129672},
#    'genres': ['alternative rock',
#     'britpop',
#     'modern rock',
#     'permanent wave',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#    'id': '6RZUqkomCmb8zCRqc9eznB',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a4734e2013188e90ace93d208b0d916e59040a1c',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/3b0a2fa5a39b6b08dc9aac023364e5ddd5064392',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/d18d2568ce8c1e3018bb41a4df4dd340492c234b',
#      'width': 160}],
#    'name': 'Placebo',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#    'followers': {'href': None, 'total': 15132599},
#    'genres': ['british invasion',
#     'classic rock',
#     'merseybeat',
#     'psychedelic rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#    'id': '3WrFJ7ztbogyGnTHbHJFl2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/6b2a709752ef9c7aaf0d270344157f6cd2e0f1a7',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/1047bf172446f2a815a99ab0a0395099d621be51',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/0561b59a91a5e904ad2d192747715688d5f05012',
#      'width': 160}],
#    'name': 'The Beatles',
#    'popularity': 91,
#    'type': 'artist',
#    'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4rUyBlggM5tZUH5QZn9ZuO'},
#    'followers': {'href': None, 'total': 725392},
#    'genres': ['cantautor',
#     'latin alternative',
#     'nica',
#     'nueva cancion',
#     'rock en espanol',
#     'trova'],
#    'href': 'https://api.spotify.com/v1/artists/4rUyBlggM5tZUH5QZn9ZuO',
#    'id': '4rUyBlggM5tZUH5QZn9ZuO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/8d4a2e075a303834da92e6d669ac2d44cc9b649f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/b67ff954cca5f544f034e7175ec98e40e43a6b30',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/b7fbfe9b8f010a97b6cc9cc7806869bbdcba6aff',
#      'width': 160}],
#    'name': 'Silvio Rodríguez',
#    'popularity': 70,
#    'type': 'artist',
#    'uri': 'spotify:artist:4rUyBlggM5tZUH5QZn9ZuO'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#    'followers': {'href': None, 'total': 5576177},
#    'genres': ['modern rock',
#     'permanent wave',
#     'piano rock',
#     'post-grunge',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#    'id': '12Chz98pHFMPJEknJQMWvI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/12450535621500d6e519275f2c52d49c00a0168f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/17f00ec7613d733f2dd88de8f2c1628ea5f9adde',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/2da69b7920c065afc835124c4786025820adab8c',
#      'width': 160}],
#    'name': 'Muse',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#    'followers': {'href': None, 'total': 18103537},
#    'genres': ['colombian pop',
#     'dance pop',
#     'latin',
#     'latin pop',
#     'mexican pop',
#     'pop'],
#    'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#    'id': '0EmeFodog0BfCgMzAIvKQp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/234f86923486e8ba3860def8518c01d5054aac1f',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/2577d225adf779981103c8b0dc75f198e4a55f31',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/caa3eae0ede56110b7c4b7694cfb20e754052f9d',
#      'width': 160}],
#    'name': 'Shakira',
#    'popularity': 88,
#    'type': 'artist',
#    'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#    'followers': {'href': None, 'total': 3275355},
#    'genres': ['alternative metal',
#     'alternative rock',
#     'conscious hip hop',
#     'funk metal',
#     'nu metal',
#     'post-grunge',
#     'rap metal',
#     'rap rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#    'id': '2d0hyoQ5ynDBnkvAbJKORj',
#    'images': [{'height': 673,
#      'url': 'https://i.scdn.co/image/ddb4a2ad4585d914d9e6993f6ddf50d33e48089e',
#      'width': 1000},
#     {'height': 431,
#      'url': 'https://i.scdn.co/image/679859f2e86b8b6b5b6d2a728e410dd4fe4b4af6',
#      'width': 640},
#     {'height': 135,
#      'url': 'https://i.scdn.co/image/b0a54ab481fc75c2800973e78acf2738834b5c10',
#      'width': 200},
#     {'height': 43,
#      'url': 'https://i.scdn.co/image/999425df5db60e404c5d4a84ec32e8405431ec02',
#      'width': 64}],
#    'name': 'Rage Against The Machine',
#    'popularity': 77,
#    'type': 'artist',
#    'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MRBDr0crHWE5JwPceFncq'},
#    'followers': {'href': None, 'total': 3985146},
#    'genres': ['cancion melodica', 'grupera', 'latin', 'latin pop'],
#    'href': 'https://api.spotify.com/v1/artists/2MRBDr0crHWE5JwPceFncq',
#    'id': '2MRBDr0crHWE5JwPceFncq',
#    'images': [{'height': 1066,
#      'url': 'https://i.scdn.co/image/022102638a204d6cb0bb6276ba2656f9c92bf2c3',
#      'width': 1000},
#     {'height': 682,
#      'url': 'https://i.scdn.co/image/d82a0dee228b5a991f8c7207a3fe65117e23f3eb',
#      'width': 640},
#     {'height': 213,
#      'url': 'https://i.scdn.co/image/a6e023b30c5d500cda3da892a01ed521d58b14eb',
#      'width': 200},
#     {'height': 68,
#      'url': 'https://i.scdn.co/image/3661070b60de6828f49bf12541571ad930c79a02',
#      'width': 64}],
#    'name': 'Juan Gabriel',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:2MRBDr0crHWE5JwPceFncq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1RgXxY6uzWo9cjYYwwgVGq'},
#    'followers': {'href': None, 'total': 729455},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/1RgXxY6uzWo9cjYYwwgVGq',
#    'id': '1RgXxY6uzWo9cjYYwwgVGq',
#    'images': [{'height': 589,
#      'url': 'https://i.scdn.co/image/7dd7d32e6724f57d4a943a70ee6545f3d0ac565e',
#      'width': 1000},
#     {'height': 377,
#      'url': 'https://i.scdn.co/image/93fa4f6defe0a0ffbacfb19c2fb3eb7a12b0d419',
#      'width': 640},
#     {'height': 118,
#      'url': 'https://i.scdn.co/image/36c27627e388c9bf082ae76109ac178ef5e9492b',
#      'width': 200},
#     {'height': 38,
#      'url': 'https://i.scdn.co/image/a8f2859be627be75ea9b3d86640624c78159dddb',
#      'width': 64}],
#    'name': 'Jaguares',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:1RgXxY6uzWo9cjYYwwgVGq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#    'followers': {'href': None, 'total': 8527058},
#    'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#    'id': '36QJpDe2go2KgaRleHCDTp',
#    'images': [{'height': 600,
#      'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#      'width': 600},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#      'width': 64}],
#    'name': 'Led Zeppelin',
#    'popularity': 83,
#    'type': 'artist',
#    'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2F9pvj94b52wGKs0OqiNi2'},
#    'followers': {'href': None, 'total': 752854},
#    'genres': ['argentine rock',
#     'latin alternative',
#     'latin rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/2F9pvj94b52wGKs0OqiNi2',
#    'id': '2F9pvj94b52wGKs0OqiNi2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/fdbd40807512c0d2dbd147a24c468549cb9495cc',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/a41ac50417392a9b5474e280a2629738e434d749',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/5eb43c334ed4471fbc2cc3513f1204b53b61fe98',
#      'width': 160}],
#    'name': 'Babasónicos',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:2F9pvj94b52wGKs0OqiNi2'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WvDtNFHOWHfiNy8NVHujT'},
#    'followers': {'href': None, 'total': 546238},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican pop',
#     'mexican rock',
#     'rock en espanol',
#     'ska mexicano'],
#    'href': 'https://api.spotify.com/v1/artists/6WvDtNFHOWHfiNy8NVHujT',
#    'id': '6WvDtNFHOWHfiNy8NVHujT',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/cf5f0007c863415db0ec1b6042453e7664a5f6be',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/58db808c0c8f04d029d91f50e941a1197f24d8cb',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/54d75dfb94d8387357ddcde0576a3fb5b8c12ad7',
#      'width': 160}],
#    'name': 'Maldita Vecindad Y Los Hijos Del 5to. Patio',
#    'popularity': 63,
#    'type': 'artist',
#    'uri': 'spotify:artist:6WvDtNFHOWHfiNy8NVHujT'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#    'followers': {'href': None, 'total': 609010},
#    'genres': ['latin alternative',
#     'latin rock',
#     'mexican indie',
#     'mexican rock',
#     'rock en espanol'],
#    'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#    'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/f436c99d04533a4c47306d9514749b7bac15a94a',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/7251771db46b126a3c385a9aeabd539f141ea115',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/cf5aeb76156e078ed7516fd991ef3307ae72eb73',
#      'width': 160}],
#    'name': 'Fobia',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3IYUhFvPQItj6xySrBmZkd'},
#    'followers': {'href': None, 'total': 3229553},
#    'genres': ['album rock',
#     'classic rock',
#     'country rock',
#     'rock',
#     'roots rock',
#     'southern rock'],
#    'href': 'https://api.spotify.com/v1/artists/3IYUhFvPQItj6xySrBmZkd',
#    'id': '3IYUhFvPQItj6xySrBmZkd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/a02c89d6abef58ad10832020c06f6a8a38dd9a32',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/749a67d2dd3ab8413d4119c63dd69afa6c43bb47',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/541309c5984f2a527f337a2b5759eab31774190d',
#      'width': 160}],
#    'name': 'Creedence Clearwater Revival',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:3IYUhFvPQItj6xySrBmZkd'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'},
#    'followers': {'href': None, 'total': 5163755},
#    'genres': ['alternative hip hop', 'art pop'],
#    'href': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ',
#    'id': '3AA28KZvwAUcZuOKwyblJQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/6db4b03387bbf74d61d8f3eedda973ab6c2ae331',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/fe485323610c043c5071309263b1c6f139741a2e',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/99f7508a2b0a8955f8c42175a456f5854c3446ca',
#      'width': 160}],
#    'name': 'Gorillaz',
#    'popularity': 83,
#    'type': 'artist',
#    'uri': 'spotify:artist:3AA28KZvwAUcZuOKwyblJQ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4KWTAlx2RvbpseOGMEmROg'},
#    'followers': {'href': None, 'total': 2265316},
#    'genres': ['alternative rock',
#     'dance rock',
#     'permanent wave',
#     'pop rock',
#     'rock'],
#    'href': 'https://api.spotify.com/v1/artists/4KWTAlx2RvbpseOGMEmROg',
#    'id': '4KWTAlx2RvbpseOGMEmROg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/d24ff8fbfd6688b345a5d53acff032d2ac1ff387',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/6e34c969a4261f44186432a0a7a17980d4387777',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/6a154cebeda4daca18d18958e05de21a8e6f9a8c',
#      'width': 160}],
#    'name': 'R.E.M.',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:4KWTAlx2RvbpseOGMEmROg'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1G1eDCwDbEX8SQwhq7fPmJ'},
#    'followers': {'href': None, 'total': 15952},
#    'genres': ['musica para ninos'],
#    'href': 'https://api.spotify.com/v1/artists/1G1eDCwDbEX8SQwhq7fPmJ',
#    'id': '1G1eDCwDbEX8SQwhq7fPmJ',
#    'images': [{'height': 1000,
#      'url': 'https://i.scdn.co/image/2914950e97789592f27bcb7310786a3db275a2bd',
#      'width': 1000},
#     {'height': 640,
#      'url': 'https://i.scdn.co/image/fea4cb43b0ab7f536b301b2c6a89d7fc525a91c8',
#      'width': 640},
#     {'height': 200,
#      'url': 'https://i.scdn.co/image/a2b2f0853899011fb300dc653246536627442e31',
#      'width': 200},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/f49abcc9fd44da8250be767328ca82a126bf07eb',
#      'width': 64}],
#    'name': 'Luis Pescetti',
#    'popularity': 43,
#    'type': 'artist',
#    'uri': 'spotify:artist:1G1eDCwDbEX8SQwhq7fPmJ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0cQbJU1aAzvbEmTuljWLlF'},
#    'followers': {'href': None, 'total': 1466458},
#    'genres': ['alternative rock',
#     'dance pop',
#     'permanent wave',
#     'pop rock',
#     'post-grunge'],
#    'href': 'https://api.spotify.com/v1/artists/0cQbJU1aAzvbEmTuljWLlF',
#    'id': '0cQbJU1aAzvbEmTuljWLlF',
#    'images': [{'height': 667,
#      'url': 'https://i.scdn.co/image/f7e39e0ca7a4ba897150247190fb27b6ae6e0318',
#      'width': 1000},
#     {'height': 427,
#      'url': 'https://i.scdn.co/image/062f558dbf9cd7d8f820a094b84d7c6513c1ef8f',
#      'width': 640},
#     {'height': 133,
#      'url': 'https://i.scdn.co/image/6d74978edc9ec01cec160888e62d986b80aaea51',
#      'width': 200},
#     {'height': 43,
#      'url': 'https://i.scdn.co/image/3877d00cef020004a2b8fcb9d69d85981f0b1f38',
#      'width': 64}],
#    'name': 'No Doubt',
#    'popularity': 72,
#    'type': 'artist',
#    'uri': 'spotify:artist:0cQbJU1aAzvbEmTuljWLlF'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3bUwxJgNakzYKkqAVgZLlh'},
#    'followers': {'href': None, 'total': 670590},
#    'genres': ['britpop', 'modern rock', 'neo mellow', 'pop rock', 'rock'],
#    'href': 'https://api.spotify.com/v1/artists/3bUwxJgNakzYKkqAVgZLlh',
#    'id': '3bUwxJgNakzYKkqAVgZLlh',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ad8b81b5c5a1fa8ef72783b47857b6f137b13208',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/d2ab9a22c3c1e1e536f89f2abd66a632940c675c',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/e8c11f79f42bb73398ead4fe633dbe9def6ba573',
#      'width': 160}],
#    'name': 'Travis',
#    'popularity': 65,
#    'type': 'artist',
#    'uri': 'spotify:artist:3bUwxJgNakzYKkqAVgZLlh'}],
#  'total': 50,
#  'limit': 50,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/artists?limit=50&offset=0&time_range=long_term',
#  'previous': None,
#  'next': None}

# %%
def getRelatedArtistsUris(top_artists):
    for i in range(len(top_artists['items'])):
        uri = top_artists['items'][i]['uri']
        related_artists = sp.artist_related_artists(uri)
        related_artists_uris = [related_artists['artists'][i]['uri'] for i in range(len(related_artists['artists']))]
        return related_artists_uris

# %%
uris = getRelatedArtistsUris(top_artists)

# %%
uris
# Out:
# ['spotify:artist:7MhMgCo0Bl0Kukl93PZbYS',
#  'spotify:artist:4CvTDPKA6W06DRfBnZKrau',
#  'spotify:artist:6zvul52xwTWzilBZl6BUbT',
#  'spotify:artist:3WaJSfKnzc65VDgmj2zU8B',
#  'spotify:artist:6liAMWkVf5LH7YR9yfFy1Y',
#  'spotify:artist:16eRpMNXSQ15wuJoeqguaB',
#  'spotify:artist:3nnQpaTvKb5jCQabZefACI',
#  'spotify:artist:3kjuyTCjPG1WMFCiyc5IuB',
#  'spotify:artist:36E7oYfz3LLRto6l2WmDcD',
#  'spotify:artist:2cGwlqi3k18jFpUyTrsR84',
#  'spotify:artist:6RZUqkomCmb8zCRqc9eznB',
#  'spotify:artist:5UqTO8smerMvxHYA5xsXb6',
#  'spotify:artist:40Yq4vzPs9VNUrIBG5Jr2i',
#  'spotify:artist:0sHeX8oQ6o7xic3wMf4NBU',
#  'spotify:artist:2Jv5eshHtLycR6R8KQCdc4',
#  'spotify:artist:38zTZcuN7nFvVJ6auhc6V3',
#  'spotify:artist:432R46LaYsJZV2Gmc4jUV5',
#  'spotify:artist:3inCNiUr4R6XQ3W43s9Aqi',
#  'spotify:artist:3vbKDsSS70ZX9D2OcvbZmS',
#  'spotify:artist:72X6FHxaShda0XeQw3vbeF']

# %%
def getRelatedTracks(uris):
    related_tracks = []
    for uri in uris:
        artist_top_tracks = sp.artist_top_tracks(uri)
        related_tracks.append(artist_top_tracks)

    return related_tracks

# %%
related_tracks = getRelatedTracks(uris)
related_tracks
# Out:
# [{'tracks': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7HvIrSkKGJCzd8AKyjTJ6Q'},
#      'href': 'https://api.spotify.com/v1/albums/7HvIrSkKGJCzd8AKyjTJ6Q',
#      'id': '7HvIrSkKGJCzd8AKyjTJ6Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d99d0823b831a78b50379100',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d99d0823b831a78b50379100',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d99d0823b831a78b50379100',
#        'width': 64}],
#      'name': 'Blur [Special Edition]',
#      'release_date': '1997-02-10',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:7HvIrSkKGJCzd8AKyjTJ6Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 121160,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200348'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1FTSo4v6BOZH9QxKc3MbVM'},
#     'href': 'https://api.spotify.com/v1/tracks/1FTSo4v6BOZH9QxKc3MbVM',
#     'id': '1FTSo4v6BOZH9QxKc3MbVM',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Song 2 - 2012 Remaster',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/183c0855e94b58dcb267e2b0721d4a3c99260acf?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1FTSo4v6BOZH9QxKc3MbVM'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1bgkxe4t0HNeLn9rhrx79x'},
#      'href': 'https://api.spotify.com/v1/albums/1bgkxe4t0HNeLn9rhrx79x',
#      'id': '1bgkxe4t0HNeLn9rhrx79x',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736eba1a0996d9e69ad20ec88b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026eba1a0996d9e69ad20ec88b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516eba1a0996d9e69ad20ec88b',
#        'width': 64}],
#      'name': 'Blur: The Best Of',
#      'release_date': '2000-10-23',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1bgkxe4t0HNeLn9rhrx79x'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 259386,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9400144'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CeL9C3bsoe4yzYS1Qz8cw'},
#     'href': 'https://api.spotify.com/v1/tracks/5CeL9C3bsoe4yzYS1Qz8cw',
#     'id': '5CeL9C3bsoe4yzYS1Qz8cw',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Girls and Boys',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e6fe3a8d487412f67de6e731c1cea650cde07055?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5CeL9C3bsoe4yzYS1Qz8cw'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YuZ4DjvtZBywtIbHIqtGJ'},
#      'href': 'https://api.spotify.com/v1/albums/5YuZ4DjvtZBywtIbHIqtGJ',
#      'id': '5YuZ4DjvtZBywtIbHIqtGJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf2d790a9c0db632cbadbf4b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf2d790a9c0db632cbadbf4b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf2d790a9c0db632cbadbf4b',
#        'width': 64}],
#      'name': '13',
#      'release_date': '1998-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5YuZ4DjvtZBywtIbHIqtGJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 358773,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9900133'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5eSllZgRWCIJsDTAqFRwQw'},
#     'href': 'https://api.spotify.com/v1/tracks/5eSllZgRWCIJsDTAqFRwQw',
#     'id': '5eSllZgRWCIJsDTAqFRwQw',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Coffee and TV',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/91936c94d51d132cd0aea95903130de0321e8af7?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5eSllZgRWCIJsDTAqFRwQw'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YuZ4DjvtZBywtIbHIqtGJ'},
#      'href': 'https://api.spotify.com/v1/albums/5YuZ4DjvtZBywtIbHIqtGJ',
#      'id': '5YuZ4DjvtZBywtIbHIqtGJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bf2d790a9c0db632cbadbf4b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bf2d790a9c0db632cbadbf4b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bf2d790a9c0db632cbadbf4b',
#        'width': 64}],
#      'name': '13',
#      'release_date': '1998-03-15',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5YuZ4DjvtZBywtIbHIqtGJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 461946,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE9900131'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/42cxPm9jgbaxIVN77XA1m6'},
#     'href': 'https://api.spotify.com/v1/tracks/42cxPm9jgbaxIVN77XA1m6',
#     'id': '42cxPm9jgbaxIVN77XA1m6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Tender',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/86f00165c56a20a7c5839a91728a969d0fdbdb18?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:42cxPm9jgbaxIVN77XA1m6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0nSzBICzQHea8grwfqa5Gb'},
#      'href': 'https://api.spotify.com/v1/albums/0nSzBICzQHea8grwfqa5Gb',
#      'id': '0nSzBICzQHea8grwfqa5Gb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739602bb7b128f2469cf60f27d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029602bb7b128f2469cf60f27d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519602bb7b128f2469cf60f27d',
#        'width': 64}],
#      'name': 'The Magic Whip',
#      'release_date': '2015-04-24',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0nSzBICzQHea8grwfqa5Gb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 299133,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1500264'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/61JDaStnXY3vbaEjliB5WA'},
#     'href': 'https://api.spotify.com/v1/tracks/61JDaStnXY3vbaEjliB5WA',
#     'id': '61JDaStnXY3vbaEjliB5WA',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Ghost Ship',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1fe5cce5d1954acf245b2c073b0edd858fd4b7e8?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:61JDaStnXY3vbaEjliB5WA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DBkFC6739trhCoVreZyds'},
#      'href': 'https://api.spotify.com/v1/albums/0DBkFC6739trhCoVreZyds',
#      'id': '0DBkFC6739trhCoVreZyds',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273feb7a3ba7fdc8d9e7031281f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02feb7a3ba7fdc8d9e7031281f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851feb7a3ba7fdc8d9e7031281f',
#        'width': 64}],
#      'name': 'Parklife [Special Edition]',
#      'release_date': '1994-04-25',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:0DBkFC6739trhCoVreZyds'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 185093,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200577'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7FSzJQV6thyoQptFCUTV9c'},
#     'href': 'https://api.spotify.com/v1/tracks/7FSzJQV6thyoQptFCUTV9c',
#     'id': '7FSzJQV6thyoQptFCUTV9c',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Parklife - 2012 Remaster',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/093413c02db355cef98a3684d6bf112da392a30b?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7FSzJQV6thyoQptFCUTV9c'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7HvIrSkKGJCzd8AKyjTJ6Q'},
#      'href': 'https://api.spotify.com/v1/albums/7HvIrSkKGJCzd8AKyjTJ6Q',
#      'id': '7HvIrSkKGJCzd8AKyjTJ6Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d99d0823b831a78b50379100',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d99d0823b831a78b50379100',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d99d0823b831a78b50379100',
#        'width': 64}],
#      'name': 'Blur [Special Edition]',
#      'release_date': '1997-02-10',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:7HvIrSkKGJCzd8AKyjTJ6Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 305213,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200347'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4OHVCeQYPncEwZOtNAJZZx'},
#     'href': 'https://api.spotify.com/v1/tracks/4OHVCeQYPncEwZOtNAJZZx',
#     'id': '4OHVCeQYPncEwZOtNAJZZx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Beetlebum - 2012 Remaster',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/28ba45b522401cb7363bbf0467cc8ea551dca8b5?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4OHVCeQYPncEwZOtNAJZZx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7BiMMjtvTX0OiB8Yi7CFB1'},
#      'href': 'https://api.spotify.com/v1/albums/7BiMMjtvTX0OiB8Yi7CFB1',
#      'id': '7BiMMjtvTX0OiB8Yi7CFB1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d49fa291b86802641d551ba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d49fa291b86802641d551ba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d49fa291b86802641d551ba',
#        'width': 64}],
#      'name': 'The Great Escape [Special Edition]',
#      'release_date': '1995-09-11',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:7BiMMjtvTX0OiB8Yi7CFB1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 236960,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200528'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6L4fEE9awoUnSEy1bmQebb'},
#     'href': 'https://api.spotify.com/v1/tracks/6L4fEE9awoUnSEy1bmQebb',
#     'id': '6L4fEE9awoUnSEy1bmQebb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Country House - 2012 Remaster',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/15180508679197159d17008a406311ac2fd8bf9a?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6L4fEE9awoUnSEy1bmQebb'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7BiMMjtvTX0OiB8Yi7CFB1'},
#      'href': 'https://api.spotify.com/v1/albums/7BiMMjtvTX0OiB8Yi7CFB1',
#      'id': '7BiMMjtvTX0OiB8Yi7CFB1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d49fa291b86802641d551ba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d49fa291b86802641d551ba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d49fa291b86802641d551ba',
#        'width': 64}],
#      'name': 'The Great Escape [Special Edition]',
#      'release_date': '1995-09-11',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:7BiMMjtvTX0OiB8Yi7CFB1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 238520,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200533'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/63G27PTar9LZQgKU2BKjx9'},
#     'href': 'https://api.spotify.com/v1/tracks/63G27PTar9LZQgKU2BKjx9',
#     'id': '63G27PTar9LZQgKU2BKjx9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Universal - 2012 Remaster',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/01ef264678fdfe76578392fb7ed2437d2a785538?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:63G27PTar9LZQgKU2BKjx9'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#        'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#        'id': '7MhMgCo0Bl0Kukl93PZbYS',
#        'name': 'Blur',
#        'type': 'artist',
#        'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DBkFC6739trhCoVreZyds'},
#      'href': 'https://api.spotify.com/v1/albums/0DBkFC6739trhCoVreZyds',
#      'id': '0DBkFC6739trhCoVreZyds',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273feb7a3ba7fdc8d9e7031281f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02feb7a3ba7fdc8d9e7031281f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851feb7a3ba7fdc8d9e7031281f',
#        'width': 64}],
#      'name': 'Parklife [Special Edition]',
#      'release_date': '1994-04-25',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:0DBkFC6739trhCoVreZyds'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7MhMgCo0Bl0Kukl93PZbYS'},
#       'href': 'https://api.spotify.com/v1/artists/7MhMgCo0Bl0Kukl93PZbYS',
#       'id': '7MhMgCo0Bl0Kukl93PZbYS',
#       'name': 'Blur',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MhMgCo0Bl0Kukl93PZbYS'}],
#     'disc_number': 1,
#     'duration_ms': 291200,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE1200574'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2qrL1YF9aA865b6SKhLZ78'},
#     'href': 'https://api.spotify.com/v1/tracks/2qrL1YF9aA865b6SKhLZ78',
#     'id': '2qrL1YF9aA865b6SKhLZ78',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Girls and Boys - 2012 Remaster',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/567ec258bd4efde229902cfe823414d9b73eee33?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2qrL1YF9aA865b6SKhLZ78'}]},
#  {'tracks': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0nZg85VbGkPcr7zQ6EsJKa'},
#      'href': 'https://api.spotify.com/v1/albums/0nZg85VbGkPcr7zQ6EsJKa',
#      'id': '0nZg85VbGkPcr7zQ6EsJKa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324d34e800313040a1001e590',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224d34e800313040a1001e590',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124d34e800313040a1001e590',
#        'width': 64}],
#      'name': 'Suspiria (Music for the Luca Guadagnino Film)',
#      'release_date': '2018-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:0nZg85VbGkPcr7zQ6EsJKa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 201768,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1800147'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0rlfGg5Ym6J9AA97ah7voH'},
#     'href': 'https://api.spotify.com/v1/tracks/0rlfGg5Ym6J9AA97ah7voH',
#     'id': '0rlfGg5Ym6J9AA97ah7voH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Suspirium',
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a2c0291e3918f95db144c4230c1447451b4bb848?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0rlfGg5Ym6J9AA97ah7voH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1g4vEVvVVFvFju0gS0DMbh'},
#      'href': 'https://api.spotify.com/v1/albums/1g4vEVvVVFvFju0gS0DMbh',
#      'id': '1g4vEVvVVFvFju0gS0DMbh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a1fd2fef30236c8efe0efc86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a1fd2fef30236c8efe0efc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a1fd2fef30236c8efe0efc86',
#        'width': 64}],
#      'name': 'ANIMA',
#      'release_date': '2019-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1g4vEVvVVFvFju0gS0DMbh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 323080,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1900213'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Ype94Pq1fdg0zogE05AfQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6Ype94Pq1fdg0zogE05AfQ',
#     'id': '6Ype94Pq1fdg0zogE05AfQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Dawn Chorus',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d25e845dd4a633e9c4ee094e2b47e887b3c80a44?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:6Ype94Pq1fdg0zogE05AfQ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QSIeDnAnGag2YZ5DjB2eB'},
#      'href': 'https://api.spotify.com/v1/albums/4QSIeDnAnGag2YZ5DjB2eB',
#      'id': '4QSIeDnAnGag2YZ5DjB2eB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273132e1996896c6bd1ac4e51e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02132e1996896c6bd1ac4e51e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851132e1996896c6bd1ac4e51e8',
#        'width': 64}],
#      'name': 'The Eraser',
#      'release_date': '2006-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4QSIeDnAnGag2YZ5DjB2eB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 289826,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBBKS0600030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4VbV8Zyjuu1qz0QteX1wVC'},
#     'href': 'https://api.spotify.com/v1/tracks/4VbV8Zyjuu1qz0QteX1wVC',
#     'id': '4VbV8Zyjuu1qz0QteX1wVC',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Black Swan',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e3f6b0b10a152710904b6135012cedd9c2af552a?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4VbV8Zyjuu1qz0QteX1wVC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0nZg85VbGkPcr7zQ6EsJKa'},
#      'href': 'https://api.spotify.com/v1/albums/0nZg85VbGkPcr7zQ6EsJKa',
#      'id': '0nZg85VbGkPcr7zQ6EsJKa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27324d34e800313040a1001e590',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0224d34e800313040a1001e590',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485124d34e800313040a1001e590',
#        'width': 64}],
#      'name': 'Suspiria (Music for the Luca Guadagnino Film)',
#      'release_date': '2018-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:0nZg85VbGkPcr7zQ6EsJKa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 267454,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1800157'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Cs3xZgZCL2vRwKTBnoAG8'},
#     'href': 'https://api.spotify.com/v1/tracks/3Cs3xZgZCL2vRwKTBnoAG8',
#     'id': '3Cs3xZgZCL2vRwKTBnoAG8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Unmade',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0c09bc01007fa4f4b8e14e9e46f13aa0a7fc8aea?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3Cs3xZgZCL2vRwKTBnoAG8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yCyupuozJqbksvEg2A5Zi'},
#        'href': 'https://api.spotify.com/v1/artists/0yCyupuozJqbksvEg2A5Zi',
#        'id': '0yCyupuozJqbksvEg2A5Zi',
#        'name': 'Flea',
#        'type': 'artist',
#        'uri': 'spotify:artist:0yCyupuozJqbksvEg2A5Zi'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/375zxMmh2cSgUzFFnva0O7'},
#        'href': 'https://api.spotify.com/v1/artists/375zxMmh2cSgUzFFnva0O7',
#        'id': '375zxMmh2cSgUzFFnva0O7',
#        'name': 'Wynton Marsalis',
#        'type': 'artist',
#        'uri': 'spotify:artist:375zxMmh2cSgUzFFnva0O7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6EqM2rlOCixg83ma0o4uDB'},
#      'href': 'https://api.spotify.com/v1/albums/6EqM2rlOCixg83ma0o4uDB',
#      'id': '6EqM2rlOCixg83ma0o4uDB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/3e557fe0578f678144aa3bc8134b31eb283cb8d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/8bac47b0bc4cf6d4bcc315ca8faa5b83567425cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/49dbd512262ec3d842fc848385674132c782c621',
#        'width': 64}],
#      'name': 'Daily Battles (From Motherless Brooklyn: Original Motion Picture Soundtrack)',
#      'release_date': '2019-08-21',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:6EqM2rlOCixg83ma0o4uDB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yCyupuozJqbksvEg2A5Zi'},
#       'href': 'https://api.spotify.com/v1/artists/0yCyupuozJqbksvEg2A5Zi',
#       'id': '0yCyupuozJqbksvEg2A5Zi',
#       'name': 'Flea',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yCyupuozJqbksvEg2A5Zi'}],
#     'disc_number': 1,
#     'duration_ms': 173461,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1900375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6xCBiZLbhAFAolDGkiinUF'},
#     'href': 'https://api.spotify.com/v1/tracks/6xCBiZLbhAFAolDGkiinUF',
#     'id': '6xCBiZLbhAFAolDGkiinUF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daily Battles',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4a37cedaeee097517dd32c9dd2d4b86fa23416f6?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6xCBiZLbhAFAolDGkiinUF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1g4vEVvVVFvFju0gS0DMbh'},
#      'href': 'https://api.spotify.com/v1/albums/1g4vEVvVVFvFju0gS0DMbh',
#      'id': '1g4vEVvVVFvFju0gS0DMbh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a1fd2fef30236c8efe0efc86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a1fd2fef30236c8efe0efc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a1fd2fef30236c8efe0efc86',
#        'width': 64}],
#      'name': 'ANIMA',
#      'release_date': '2019-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1g4vEVvVVFvFju0gS0DMbh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 317986,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1900210'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1nEDT4DsoaTfexrz8D9zt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1nEDT4DsoaTfexrz8D9zt1',
#     'id': '1nEDT4DsoaTfexrz8D9zt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Traffic',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5cf854d12c97804103ff88cb436f9405f5c9df4d?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1nEDT4DsoaTfexrz8D9zt1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1g4vEVvVVFvFju0gS0DMbh'},
#      'href': 'https://api.spotify.com/v1/albums/1g4vEVvVVFvFju0gS0DMbh',
#      'id': '1g4vEVvVVFvFju0gS0DMbh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a1fd2fef30236c8efe0efc86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a1fd2fef30236c8efe0efc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a1fd2fef30236c8efe0efc86',
#        'width': 64}],
#      'name': 'ANIMA',
#      'release_date': '2019-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1g4vEVvVVFvFju0gS0DMbh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 237040,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1900215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ypjELqhyUT3BBCws8kzKN'},
#     'href': 'https://api.spotify.com/v1/tracks/7ypjELqhyUT3BBCws8kzKN',
#     'id': '7ypjELqhyUT3BBCws8kzKN',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Not The News',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4c8368b7e472a2df412a9680c73c84770c767246?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7ypjELqhyUT3BBCws8kzKN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1g4vEVvVVFvFju0gS0DMbh'},
#      'href': 'https://api.spotify.com/v1/albums/1g4vEVvVVFvFju0gS0DMbh',
#      'id': '1g4vEVvVVFvFju0gS0DMbh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a1fd2fef30236c8efe0efc86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a1fd2fef30236c8efe0efc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a1fd2fef30236c8efe0efc86',
#        'width': 64}],
#      'name': 'ANIMA',
#      'release_date': '2019-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1g4vEVvVVFvFju0gS0DMbh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 423173,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1900212'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/36IJNDHIljR94apizT5Iks'},
#     'href': 'https://api.spotify.com/v1/tracks/36IJNDHIljR94apizT5Iks',
#     'id': '36IJNDHIljR94apizT5Iks',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Twist',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fa50f7568b14fb0f4db17e28dd3cb414850d880f?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:36IJNDHIljR94apizT5Iks'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QSIeDnAnGag2YZ5DjB2eB'},
#      'href': 'https://api.spotify.com/v1/albums/4QSIeDnAnGag2YZ5DjB2eB',
#      'id': '4QSIeDnAnGag2YZ5DjB2eB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273132e1996896c6bd1ac4e51e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02132e1996896c6bd1ac4e51e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851132e1996896c6bd1ac4e51e8',
#        'width': 64}],
#      'name': 'The Eraser',
#      'release_date': '2006-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4QSIeDnAnGag2YZ5DjB2eB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 295866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKS0600027'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0WxzsZHbXcny0WhexO2MCa'},
#     'href': 'https://api.spotify.com/v1/tracks/0WxzsZHbXcny0WhexO2MCa',
#     'id': '0WxzsZHbXcny0WhexO2MCa',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Eraser',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f251ab848685f68f04c5e608bc8b936c7dde42f4?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0WxzsZHbXcny0WhexO2MCa'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#        'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#        'id': '4CvTDPKA6W06DRfBnZKrau',
#        'name': 'Thom Yorke',
#        'type': 'artist',
#        'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1g4vEVvVVFvFju0gS0DMbh'},
#      'href': 'https://api.spotify.com/v1/albums/1g4vEVvVVFvFju0gS0DMbh',
#      'id': '1g4vEVvVVFvFju0gS0DMbh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a1fd2fef30236c8efe0efc86',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a1fd2fef30236c8efe0efc86',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a1fd2fef30236c8efe0efc86',
#        'width': 64}],
#      'name': 'ANIMA',
#      'release_date': '2019-06-27',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:1g4vEVvVVFvFju0gS0DMbh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CvTDPKA6W06DRfBnZKrau'},
#       'href': 'https://api.spotify.com/v1/artists/4CvTDPKA6W06DRfBnZKrau',
#       'id': '4CvTDPKA6W06DRfBnZKrau',
#       'name': 'Thom Yorke',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CvTDPKA6W06DRfBnZKrau'}],
#     'disc_number': 1,
#     'duration_ms': 306760,
#     'explicit': False,
#     'external_ids': {'isrc': 'GB4YG1900211'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4IlK4zPx09Dtpx72hxM4uL'},
#     'href': 'https://api.spotify.com/v1/tracks/4IlK4zPx09Dtpx72hxM4uL',
#     'id': '4IlK4zPx09Dtpx72hxM4uL',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Last I Heard (...He Was Circling the Drain)',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9ef086857b74ef1ddf2bfd6f896a20023c5d365c?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4IlK4zPx09Dtpx72hxM4uL'}]},
#  {'tracks': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#        'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#        'id': '6zvul52xwTWzilBZl6BUbT',
#        'name': 'Pixies',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2l7RPWC3E6eStJJLBsUeCI'},
#      'href': 'https://api.spotify.com/v1/albums/2l7RPWC3E6eStJJLBsUeCI',
#      'id': '2l7RPWC3E6eStJJLBsUeCI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a3903c1aa8122f7720f5d71',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a3903c1aa8122f7720f5d71',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a3903c1aa8122f7720f5d71',
#        'width': 64}],
#      'name': 'Surfer Rosa (Remastered)',
#      'release_date': '1988',
#      'release_date_precision': 'year',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2l7RPWC3E6eStJJLBsUeCI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#       'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#       'id': '6zvul52xwTWzilBZl6BUbT',
#       'name': 'Pixies',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#     'disc_number': 1,
#     'duration_ms': 236973,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL0700145'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6mcxQ1Y3uQRU0IHsvdNLH1'},
#     'href': 'https://api.spotify.com/v1/tracks/6mcxQ1Y3uQRU0IHsvdNLH1',
#     'id': '6mcxQ1Y3uQRU0IHsvdNLH1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Where Is My Mind?',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4a375a9c19d4ea8083658b58402926d6990499b?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6mcxQ1Y3uQRU0IHsvdNLH1'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#        'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#        'id': '6zvul52xwTWzilBZl6BUbT',
#        'name': 'Pixies',
#        'type': 'artist',
#        'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ymZBbRSmzAvoSGmwAFoxm'},
#      'href': 'https://api.spotify.com/v1/albums/6ymZBbRSmzAvoSGmwAFoxm',
#      'id': '6ymZBbRSmzAvoSGmwAFoxm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d27159df96ec159cc7d70080',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d27159df96ec159cc7d70080',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d27159df96ec159cc7d70080',
#        'width': 64}],
#      'name': 'Doolittle',
#      'release_date': '1989-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6ymZBbRSmzAvoSGmwAFoxm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6zvul52xwTWzilBZl6BUbT'},
#       'href': 'https://api.spotify.com/v1/artists/6zvul52xwTWzilBZl6BUbT',
#       'id': '6zvul52xwTWzilBZl6BUbT',
#       'name': 'Pixies',
#       'type': 'artist',
#       'uri': 'spotify:artist:6zvul52xwTWzilBZl6BUbT'}],
#     'disc_number': 1,
#     'duration_ms': 201693,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL9700090'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0cs671lxX2eoDzr2KMuo3N'},
#     'href': 'https://api.spotify.com/v1/tracks/0cs671lxX2eoDzr2KMuo3N',
#     'id': '0cs671lxX2eoDzr2KMuo3N',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Here Comes Your Man',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/189379bc8ea66d101c86f66244dfcd9b13cfbc8b?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0cs671lxX2eoDzr2KMuo3N'},
#    {'album': {'album_type': 'album',
# ...
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 413171,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6smJCC2En1iEuN3b9ZQnLX'},
#     'href': 'https://api.spotify.com/v1/tracks/6smJCC2En1iEuN3b9ZQnLX',
#     'id': '6smJCC2En1iEuN3b9ZQnLX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Slomo',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4945f47624337446626a56c91f50918aa0e10b40?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6smJCC2En1iEuN3b9ZQnLX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53eHm1f3sFiSzWMaKOl98Z'},
#      'href': 'https://api.spotify.com/v1/albums/53eHm1f3sFiSzWMaKOl98Z',
#      'id': '53eHm1f3sFiSzWMaKOl98Z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f6e31941d10e4819d290af41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f6e31941d10e4819d290af41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f6e31941d10e4819d290af41',
#        'width': 64}],
#      'name': 'Souvlaki',
#      'release_date': '1993',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:53eHm1f3sFiSzWMaKOl98Z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 285906,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBQY0400041'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0oxYB9GoOIDrdzniNdKC44'},
#     'href': 'https://api.spotify.com/v1/tracks/0oxYB9GoOIDrdzniNdKC44',
#     'id': '0oxYB9GoOIDrdzniNdKC44',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'When the Sun Hits',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83ace5c7fa9b5d6881dddfde9460f7d8a5105666?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0oxYB9GoOIDrdzniNdKC44'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4nSWX5A4xVomzrOEGDKLQ6'},
#      'href': 'https://api.spotify.com/v1/albums/4nSWX5A4xVomzrOEGDKLQ6',
#      'id': '4nSWX5A4xVomzrOEGDKLQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d08dfce0cb20cf7ed9da031',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d08dfce0cb20cf7ed9da031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d08dfce0cb20cf7ed9da031',
#        'width': 64}],
#      'name': 'Slowdive',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 338869,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713202'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6oeABvJGU7Oztzd3CiSv0l'},
#     'href': 'https://api.spotify.com/v1/tracks/6oeABvJGU7Oztzd3CiSv0l',
#     'id': '6oeABvJGU7Oztzd3CiSv0l',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Star Roving',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ce1dea6a5b20956bf00471ccdef25afcdeb0f323?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6oeABvJGU7Oztzd3CiSv0l'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4nSWX5A4xVomzrOEGDKLQ6'},
#      'href': 'https://api.spotify.com/v1/albums/4nSWX5A4xVomzrOEGDKLQ6',
#      'id': '4nSWX5A4xVomzrOEGDKLQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d08dfce0cb20cf7ed9da031',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d08dfce0cb20cf7ed9da031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d08dfce0cb20cf7ed9da031',
#        'width': 64}],
#      'name': 'Slowdive',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 348107,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713206'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4kAflSfOBf6Wv5ZD5abUvZ'},
#     'href': 'https://api.spotify.com/v1/tracks/4kAflSfOBf6Wv5ZD5abUvZ',
#     'id': '4kAflSfOBf6Wv5ZD5abUvZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Longer Making Time',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66cd3e1bd692050344927f588438aa4bb1e754be?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4kAflSfOBf6Wv5ZD5abUvZ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/53eHm1f3sFiSzWMaKOl98Z'},
#      'href': 'https://api.spotify.com/v1/albums/53eHm1f3sFiSzWMaKOl98Z',
#      'id': '53eHm1f3sFiSzWMaKOl98Z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f6e31941d10e4819d290af41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f6e31941d10e4819d290af41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f6e31941d10e4819d290af41',
#        'width': 64}],
#      'name': 'Souvlaki',
#      'release_date': '1993',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:53eHm1f3sFiSzWMaKOl98Z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 357373,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBQY0400040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/76JhicgPtW4zbN72tpnMyA'},
#     'href': 'https://api.spotify.com/v1/tracks/76JhicgPtW4zbN72tpnMyA',
#     'id': '76JhicgPtW4zbN72tpnMyA',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Souvlaki Space Station',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cc8ac4a4f6518d4ceff8fdc775df3fb7e3137cf9?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:76JhicgPtW4zbN72tpnMyA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4nSWX5A4xVomzrOEGDKLQ6'},
#      'href': 'https://api.spotify.com/v1/albums/4nSWX5A4xVomzrOEGDKLQ6',
#      'id': '4nSWX5A4xVomzrOEGDKLQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d08dfce0cb20cf7ed9da031',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d08dfce0cb20cf7ed9da031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d08dfce0cb20cf7ed9da031',
#        'width': 64}],
#      'name': 'Slowdive',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 276959,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713203'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0UjQAt7u0DvcU4dnbKtB9k'},
#     'href': 'https://api.spotify.com/v1/tracks/0UjQAt7u0DvcU4dnbKtB9k',
#     'id': '0UjQAt7u0DvcU4dnbKtB9k',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Don't Know Why",
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/692ee635d39e8c4b0a5bf0e18b1304a5d2479c09?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0UjQAt7u0DvcU4dnbKtB9k'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4nSWX5A4xVomzrOEGDKLQ6'},
#      'href': 'https://api.spotify.com/v1/albums/4nSWX5A4xVomzrOEGDKLQ6',
#      'id': '4nSWX5A4xVomzrOEGDKLQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d08dfce0cb20cf7ed9da031',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d08dfce0cb20cf7ed9da031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d08dfce0cb20cf7ed9da031',
#        'width': 64}],
#      'name': 'Slowdive',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 480758,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713208'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Zr0mt1HdVUwTEdMwqPXsC'},
#     'href': 'https://api.spotify.com/v1/tracks/6Zr0mt1HdVUwTEdMwqPXsC',
#     'id': '6Zr0mt1HdVUwTEdMwqPXsC',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Falling Ashes',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/189834cc84403c2550a71bd598d4ab41cf9a8d8d?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6Zr0mt1HdVUwTEdMwqPXsC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#        'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#        'id': '72X6FHxaShda0XeQw3vbeF',
#        'name': 'Slowdive',
#        'type': 'artist',
#        'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4nSWX5A4xVomzrOEGDKLQ6'},
#      'href': 'https://api.spotify.com/v1/albums/4nSWX5A4xVomzrOEGDKLQ6',
#      'id': '4nSWX5A4xVomzrOEGDKLQ6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d08dfce0cb20cf7ed9da031',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d08dfce0cb20cf7ed9da031',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d08dfce0cb20cf7ed9da031',
#        'width': 64}],
#      'name': 'Slowdive',
#      'release_date': '2017-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:4nSWX5A4xVomzrOEGDKLQ6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/72X6FHxaShda0XeQw3vbeF'},
#       'href': 'https://api.spotify.com/v1/artists/72X6FHxaShda0XeQw3vbeF',
#       'id': '72X6FHxaShda0XeQw3vbeF',
#       'name': 'Slowdive',
#       'type': 'artist',
#       'uri': 'spotify:artist:72X6FHxaShda0XeQw3vbeF'}],
#     'disc_number': 1,
#     'duration_ms': 262056,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJ5G1713205'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5gCMldzBtCPajx3JNLtVB6'},
#     'href': 'https://api.spotify.com/v1/tracks/5gCMldzBtCPajx3JNLtVB6',
#     'id': '5gCMldzBtCPajx3JNLtVB6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Everyone Knows',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2f142e9f9e1eed76fc31c59b7177cfff4e3c357e?cid=57493e4e2f704e7a8e0aa0e010ef8fc8',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:5gCMldzBtCPajx3JNLtVB6'}]}]

# %%
def getRelatedTracksIds(related_tracks):
    ids = []
    for i in range(len(related_tracks)):
        ids.append([related_tracks[i]['tracks'][j]['id'] for j in range(len(related_tracks[i]['tracks']))])
    return ids

# %%
related_tracks_ids = getRelatedTracksIds(related_tracks)
related_tracks_ids
# Out:
# [['1FTSo4v6BOZH9QxKc3MbVM',
#   '5CeL9C3bsoe4yzYS1Qz8cw',
#   '5eSllZgRWCIJsDTAqFRwQw',
#   '42cxPm9jgbaxIVN77XA1m6',
#   '61JDaStnXY3vbaEjliB5WA',
#   '7FSzJQV6thyoQptFCUTV9c',
#   '4OHVCeQYPncEwZOtNAJZZx',
#   '6L4fEE9awoUnSEy1bmQebb',
#   '63G27PTar9LZQgKU2BKjx9',
#   '2qrL1YF9aA865b6SKhLZ78'],
#  ['0rlfGg5Ym6J9AA97ah7voH',
#   '6Ype94Pq1fdg0zogE05AfQ',
#   '4VbV8Zyjuu1qz0QteX1wVC',
#   '3Cs3xZgZCL2vRwKTBnoAG8',
#   '6xCBiZLbhAFAolDGkiinUF',
#   '1nEDT4DsoaTfexrz8D9zt1',
#   '7ypjELqhyUT3BBCws8kzKN',
#   '36IJNDHIljR94apizT5Iks',
#   '0WxzsZHbXcny0WhexO2MCa',
#   '4IlK4zPx09Dtpx72hxM4uL'],
#  ['6mcxQ1Y3uQRU0IHsvdNLH1',
#   '0cs671lxX2eoDzr2KMuo3N',
#   '2Aqc48sn8He26hmTvQ2BMj',
#   '3FzKPS0oVknVlCW3PhxIHl',
#   '1lFC3sMgOcDrVzNh8zXRnl',
#   '2KSSbWLAWSzaso01DEP32W',
#   '3oqJ3POeLfa2TJh6BFLhPM',
#   '1yJiE307EBIzOB9kqH1deb',
#   '1YZDkJOFT8xlAXDi8lneb3',
#   '1ZaK63rgqJk8xxbks5ilUc'],
#  ['2VbOnf4BivY15wG1GS5Vtv',
#   '6B182GP3TvEfmgUoIMVUSJ',
#   '7wvtiQ3o8ELEmk2NjSSPpX',
#   '7h4RBE1rGeHMoU7722HGVY',
#   '1RTk31cNoWdx1HBRbkc02a',
#   '1PAlCnDz8T0k9f2LRuQ6Wn',
#   '41g3tCnqP8yTauiPQPndVO',
#   '0mF7YNgURDkBQaxa9YRc47',
#   '3KmMRXOT5ENF1ZaovgGnJW',
#   '0XZajNIa2tdOUfCoCewcni'],
#  ['3Ty7OTBNSigGEpeW2PqcsC',
#   '2sW8fmnISifQTRgnRrQTYW',
#   '6vTtCOimcPs5H1Jr9d0Aep',
#   '5KX2DSPC6aCA0pdDidTmBC',
#   '7h14W1uQK7sjpVI1oVTobt',
#   '785Qya5mtMUwBQtuypVqrx',
#   '2O6X9nPVVQSefg3xOQAo5u',
#   '7lR743VxfubUw5m9dpnR9x',
#   '1cpnpMvnvmdy3hzYgd5oo9',
#   '6pW8YspamPCxUwgvYttTSc'],
#  ['2DFRFqWNahKtFD112H2iEZ',
#   '0ccCwNzXvr1Yoz91vKz31Z',
#   '1dJuteDIOkGfDSN7zPkzNv',
#   '1RZlGlz8eXT1KmJYpqFRzH',
#   '0ScgmigVOJr2mFsAtwFQmz',
#   '6YeR95fvPNXuOKbJfcvqBk',
#   '4yYKWN3FtoRxdlJBqIn8Rh',
#   '12X8MvZMLdpPbkXMoXPDU8',
#   '4ou3f7jaB41isbJkt6CF2b',
#   '2SsrjDZM8ZIvKaUssqPs4o'],
#  ['3pRaLNL3b8x5uBOcsgvdqM',
#   '6Jv7kjGkhY2fT4yuBF3aTz',
#   '0y5CnV2idm2KkQEudDjfDT',
#   '64SIlhd3BaHCCMSfajXG7l',
#   '1StXVL5gClph4z4XzanYko',
#   '4yg2qSpnVAbQLPjCJTWwtY',
#   '7qdbu6JlWG3Dfjo3MqlMdF',
#   '2bcvooA6HEmVUneEGJnNZD',
#   '1nd2JEHXbUuQFDiQzCBpsv',
#   '6UuVONmxXwTKN1ISepuAoQ'],
#  ['2UWdUez9MB9yzL7Y81Mcip',
#   '6Hmj7SrLRbreLVfVS7mV1S',
#   '7KsZHCfOitA5V9oQYVdltG',
#   '0xOeB16JDbBJBJKSdHbElT',
#   '0U0p8weaMIbIFMJ0CPlvHV',
#   '01wsKcJ8ptqUmatpJlEGYj',
#   '0SaEmR2rdtfsZawPjMYkWg',
#   '1rOlTL4pKQ9Y1fURua4AJR',
#   '0WZZJ0mDKIkLfL0710ssZt',
#   '2voWPWlDfIthC6GUjaIQyV'],
#  ['2fXKyAyPrEa24c6PJyqznF',
#   '2aC8wwfrM0YeTAzzk8hxqC',
#   '4j3obTRIyR7QzvdeQz9vaO',
#   '0txLC5NA64M8siGn3mnET0',
#   '05FgZdqxXg40X0WG8MmWMA',
#   '1so0qYkfkiZNNcvJN02qdo',
#   '3DYnqG3jqB1bijSKsJzuzG',
#   '5pcDlqgygjWQ75QYLM7mdL',
#   '6OiWR0dBoVnd0NpD0kCijF',
#   '3Z9d7g8Pn4S4ivwlziwcf6'],
#  ['57iDDD9N9tTWe75x6qhStw',
#   '2mxPSHEwjJWOQS7lGw6btF',
#   '15kLz0zNFdtsaJdXKSGmTU',
#   '6OgWHP8rRXiq7VMaryVaVo',
#   '52p8lRbIrKYjzwDMXgBVFO',
#   '6ypCu5xx6kJp2hnQ8zncqQ',
#   '5LLNmbRzBCT3cfrmHg6jR7',
#   '0Sr9uJqXFAvqHcgwg3UjY5',
#   '3dPSPaolTvtOvSCKo1ProN',
#   '5MFO9lwRDQy2Z85AvdwsL3'],
#  ['3tRv4ZYZimrL27flnjgeR6',
#   '3WBPiogtVDBSXK7uOpxJ6m',
#   '6RHHbAbyIcPpvS1dP3KUGq',
#   '2h0HkReHGCQPOEDZXEMcTO',
#   '1TqmZVIyeD4aN4Wa0wbnfy',
#   '5he7AYCR3MGloRnuWEMroT',
#   '2DO7ywgu9cdNqXf7Cukys9',
#   '63peVCtLTPd0aM9x5j97sB',
#   '5fVTi3rIiLvsEVYp0cRvaI',
#   '1ZOeXUr9ieWw80zs1T6pkp'],
#  ['0WIbzDVEpmOyBnqqdtqIL9',
#   '5Ext9ObPEi7wIcv5AiQWJy',
#   '1ZozGivTAYsOwhy6LVHsPX',
#   '0lDoG5fQ9cmpvpenwR7Jln',
#   '6q03mlzKsM1m3TLpi6T6Cw',
#   '22t3vCXfjQhIiXzGVSZNOz',
#   '5ZNdRdZ2inm4ksA8keadDs',
#   '6px1KhTqAfxdcF6A1JGSpx',
#   '5bNpYsNWgvF3kLC54vplp8',
#   '5X9c0LL84kJN8Ok2UC6B6w'],
#  ['5QLHGv0DfpeXLNFo7SFEy1',
#   '6GtX0jaNL8IjVQfrDBx81z',
#   '7bu0znpSbTks0O6I98ij0W',
#   '6YIggUJW3ttAAPRdnki8RM',
#   '3ow0TQVttXQF8rLckmXgRx',
#   '4YFcGTdgmEuw8xTO4XrxbB',
#   '0u5aO1GYsIhAWCPuXdwnak',
#   '3eMYc6FK9XvyauIaxcJtRS',
#   '6N7JMoaUYgo4pwPgsnSobr',
#   '1XPta4VLT78HQnVFd1hlsK'],
#  ['5xC8uOesnn0udeXAYlAnoY',
#   '0kAFTd3dWytNQPVF18jCIv',
#   '1Xo5IcDLNOEpcB1RM4mBNF',
#   '55QdsyZaO7av9MaA8seJoT',
#   '0mIZErjrNQzOTDtn4UYflo',
#   '5lzLhFRsmQ7oOgbMOnbMmb',
#   '4f7cClJdOkHK4PWD2AQMDG',
#   '0iAcyO7WLhnC7WOTOpjGv1',
#   '3p0rnbnQc8WPJjcMyUsglj',
#   '1pdiygifNlOrZzSj9SWAve'],
#  ['0iTpQYzJnYgh7kIxyq8A2O',
#   '5cf1ZfI16kHp3S1ySpQ36G',
#   '2ZRvcRcKdwQBjTAqj2XNJN',
#   '0szSOfZVM3G5mWI1ogQjr7',
#   '202QyrB6Q3Kimsr7KqJut3',
#   '0IvQCuL8N4158edtz98LCL',
#   '4BmtCb6sdMqECAItGmFDvU',
#   '1qCSMWPJBlak9Uz03IHfvE',
#   '02KGkBz8Tyc9TB2RqCd9Z5',
#   '7EMtXthSsYKASqvqqBrFX0'],
#  ['6ZXoX3GiljGiuQpGCjWJI3',
#   '3jZ0GKAZiDMya0dZPrw8zq',
#   '6cqXhzuVIH4Hm2CkF7ZN21',
#   '30wvVTkqA4Fp5ZCG0xGof7',
#   '3ISC0OWlikS5VyvQNIttlK',
#   '2SpHd4lGMrJMIQDf92V6VP',
#   '7dLIBLyWAsbXDhcZFMzKVv',
#   '1hmSATuFIvmaJN4OKfbAU0',
#   '066nVSMAHBa3UxtE1m4c2j',
#   '6wYTcgNMqPZw2hybRMTEQf'],
#  ['1r8oPEXqnhUVgkUkJNqEuF',
#   '38wCbVfMreML5ZhF5iQuKA',
#   '49G0Rj1qpt75vdgiOo8QAE',
#   '79CfK2gMGf0svanec6LJOj',
#   '5UPnBgnylUCjtAPtAH4tJY',
#   '5EclH1u6hKzOV3m1I3LAc3',
#   '5kDqGHyvDEvHgMRjQImFNq',
#   '3KN1A4XVt5lYudW7M6gD9T',
#   '5MtnbY0fACKCYyMAsSPmSf',
#   '1EVNonxYblRjEkhecLhd3W'],
#  ['4tggZyGJMNJMooWuRbvN5q',
#   '6lAZ7xfP9su2ZvGk1rRc3R',
#   '13YxuRQZdU7snOfDI3nft2',
#   '3QuzslMgjJGsw6wC1E9eRi',
#   '71m8TLglSP4Naj0CVPd9pc',
#   '6CAAtj6NsktcBydmDjrXaR',
#   '6bIC75pQuTldLZPgSmlu1I',
#   '05l9N6SnERhSdH8XQR5TjK',
#   '0AKzN2r2bqEAzxYZFklLEw',
#   '60EKD91CV7bLdEWkyMqMQg'],
#  ['5PntSbMHC1ud6Vvl8x56qd',
#   '0wSmZykDgah7GfaUNZUZCb',
#   '28AgTOIZke8nitD0NNeb3G',
#   '14zhqtMI5xHrfCFCLhFcsn',
#   '7Lflb7ssXJ6hCcoMf5U1Wb',
#   '11cSjtt6z6VqPg9DqxvgV7',
#   '6aLmvz0CPeCNHCXK2H5QIC',
#   '1vlkeO1XsX11gdo1tYgslg',
#   '10bSPg0ThnU22WhTp3OsbF',
#   '65tH2GPMFCt8JtM2PM3MiX'],
#  ['0GN3fXUdsTHeUg50xfDS0V',
#   '33HRECrmuelZxOpid6XTNX',
#   '6smJCC2En1iEuN3b9ZQnLX',
#   '0oxYB9GoOIDrdzniNdKC44',
#   '6oeABvJGU7Oztzd3CiSv0l',
#   '4kAflSfOBf6Wv5ZD5abUvZ',
#   '76JhicgPtW4zbN72tpnMyA',
#   '0UjQAt7u0DvcU4dnbKtB9k',
#   '6Zr0mt1HdVUwTEdMwqPXsC',
#   '5gCMldzBtCPajx3JNLtVB6']]

# %%
df = pd.DataFrame(related_tracks_ids[])
ids = df.values.flatten()

# %%
features_batch_1 = sp.audio_features(ids[:100])
features_batch_2 = sp.audio_features(ids[100:])
features_batch_1
# Out:
# [{'danceability': 0.674,
#   'energy': 0.789,
#   'key': 8,
#   'loudness': -6.903,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.00178,
#   'instrumentalness': 0.0071,
#   'liveness': 0.0754,
#   'valence': 0.918,
#   'tempo': 129.804,
#   'type': 'audio_features',
#   'id': '1FTSo4v6BOZH9QxKc3MbVM',
#   'uri': 'spotify:track:1FTSo4v6BOZH9QxKc3MbVM',
#   'track_href': 'https://api.spotify.com/v1/tracks/1FTSo4v6BOZH9QxKc3MbVM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FTSo4v6BOZH9QxKc3MbVM',
#   'duration_ms': 121160,
#   'time_signature': 4},
#  {'danceability': 0.693,
#   'energy': 0.875,
#   'key': 7,
#   'loudness': -8.354,
#   'mode': 0,
#   'speechiness': 0.0315,
#   'acousticness': 0.00971,
#   'instrumentalness': 0,
#   'liveness': 0.0601,
#   'valence': 0.901,
#   'tempo': 120.048,
#   'type': 'audio_features',
#   'id': '5CeL9C3bsoe4yzYS1Qz8cw',
#   'uri': 'spotify:track:5CeL9C3bsoe4yzYS1Qz8cw',
#   'track_href': 'https://api.spotify.com/v1/tracks/5CeL9C3bsoe4yzYS1Qz8cw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CeL9C3bsoe4yzYS1Qz8cw',
#   'duration_ms': 259387,
#   'time_signature': 4},
#  {'danceability': 0.743,
#   'energy': 0.743,
#   'key': 2,
#   'loudness': -10.117,
#   'mode': 1,
#   'speechiness': 0.0367,
#   'acousticness': 0.0511,
#   'instrumentalness': 0.233,
#   'liveness': 0.0987,
#   'valence': 0.707,
#   'tempo': 121.604,
#   'type': 'audio_features',
#   'id': '5eSllZgRWCIJsDTAqFRwQw',
#   'uri': 'spotify:track:5eSllZgRWCIJsDTAqFRwQw',
#   'track_href': 'https://api.spotify.com/v1/tracks/5eSllZgRWCIJsDTAqFRwQw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eSllZgRWCIJsDTAqFRwQw',
#   'duration_ms': 358773,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.566,
#   'key': 9,
#   'loudness': -9.932,
#   'mode': 1,
#   'speechiness': 0.0276,
#   'acousticness': 0.47,
#   'instrumentalness': 0,
#   'liveness': 0.0644,
#   'valence': 0.529,
#   'tempo': 76.054,
#   'type': 'audio_features',
#   'id': '42cxPm9jgbaxIVN77XA1m6',
#   'uri': 'spotify:track:42cxPm9jgbaxIVN77XA1m6',
#   'track_href': 'https://api.spotify.com/v1/tracks/42cxPm9jgbaxIVN77XA1m6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42cxPm9jgbaxIVN77XA1m6',
#   'duration_ms': 461947,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.722,
#   'key': 2,
#   'loudness': -6.421,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.0324,
#   'instrumentalness': 0.00264,
#   'liveness': 0.0763,
#   'valence': 0.857,
#   'tempo': 139.981,
#   'type': 'audio_features',
#   'id': '61JDaStnXY3vbaEjliB5WA',
#   'uri': 'spotify:track:61JDaStnXY3vbaEjliB5WA',
#   'track_href': 'https://api.spotify.com/v1/tracks/61JDaStnXY3vbaEjliB5WA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61JDaStnXY3vbaEjliB5WA',
#   'duration_ms': 299133,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.891,
#   'key': 4,
#   'loudness': -6.094,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.281,
#   'valence': 0.722,
#   'tempo': 138.79,
#   'type': 'audio_features',
#   'id': '7FSzJQV6thyoQptFCUTV9c',
#   'uri': 'spotify:track:7FSzJQV6thyoQptFCUTV9c',
#   'track_href': 'https://api.spotify.com/v1/tracks/7FSzJQV6thyoQptFCUTV9c',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7FSzJQV6thyoQptFCUTV9c',
#   'duration_ms': 185093,
#   'time_signature': 4},
#  {'danceability': 0.542,
#   'energy': 0.626,
#   'key': 0,
#   'loudness': -7.105,
#   'mode': 1,
#   'speechiness': 0.0242,
#   'acousticness': 0.0789,
#   'instrumentalness': 0.000508,
#   'liveness': 0.277,
#   'valence': 0.813,
#   'tempo': 89.734,
#   'type': 'audio_features',
#   'id': '4OHVCeQYPncEwZOtNAJZZx',
#   'uri': 'spotify:track:4OHVCeQYPncEwZOtNAJZZx',
#   'track_href': 'https://api.spotify.com/v1/tracks/4OHVCeQYPncEwZOtNAJZZx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4OHVCeQYPncEwZOtNAJZZx',
#   'duration_ms': 305213,
#   'time_signature': 4},
#  {'danceability': 0.331,
#   'energy': 0.885,
#   'key': 9,
#   'loudness': -6.606,
#   'mode': 1,
#   'speechiness': 0.0924,
#   'acousticness': 0.205,
#   'instrumentalness': 0,
#   'liveness': 0.123,
#   'valence': 0.589,
#   'tempo': 175.294,
#   'type': 'audio_features',
#   'id': '6L4fEE9awoUnSEy1bmQebb',
#   'uri': 'spotify:track:6L4fEE9awoUnSEy1bmQebb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6L4fEE9awoUnSEy1bmQebb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6L4fEE9awoUnSEy1bmQebb',
#   'duration_ms': 236960,
#   'time_signature': 4},
#  {'danceability': 0.335,
#   'energy': 0.546,
#   'key': 9,
#   'loudness': -8.33,
#   'mode': 1,
#   'speechiness': 0.0272,
#   'acousticness': 0.181,
#   'instrumentalness': 1.98e-06,
#   'liveness': 0.0928,
#   'valence': 0.266,
#   'tempo': 163.511,
#   'type': 'audio_features',
#   'id': '63G27PTar9LZQgKU2BKjx9',
#   'uri': 'spotify:track:63G27PTar9LZQgKU2BKjx9',
#   'track_href': 'https://api.spotify.com/v1/tracks/63G27PTar9LZQgKU2BKjx9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63G27PTar9LZQgKU2BKjx9',
#   'duration_ms': 238520,
#   'time_signature': 3},
#  {'danceability': 0.688,
#   'energy': 0.936,
#   'key': 7,
#   'loudness': -6.658,
#   'mode': 0,
#   'speechiness': 0.0377,
#   'acousticness': 0.0138,
#   'instrumentalness': 0,
#   'liveness': 0.068,
#   'valence': 0.924,
#   'tempo': 120.135,
#   'type': 'audio_features',
#   'id': '2qrL1YF9aA865b6SKhLZ78',
#   'uri': 'spotify:track:2qrL1YF9aA865b6SKhLZ78',
#   'track_href': 'https://api.spotify.com/v1/tracks/2qrL1YF9aA865b6SKhLZ78',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2qrL1YF9aA865b6SKhLZ78',
#   'duration_ms': 291200,
#   'time_signature': 4},
#  {'danceability': 0.473,
#   'energy': 0.217,
#   'key': 1,
#   'loudness': -15.662,
#   'mode': 0,
#   'speechiness': 0.032,
#   'acousticness': 0.989,
#   'instrumentalness': 0.905,
#   'liveness': 0.134,
#   'valence': 0.441,
#   'tempo': 151.002,
#   'type': 'audio_features',
#   'id': '0rlfGg5Ym6J9AA97ah7voH',
#   'uri': 'spotify:track:0rlfGg5Ym6J9AA97ah7voH',
#   'track_href': 'https://api.spotify.com/v1/tracks/0rlfGg5Ym6J9AA97ah7voH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rlfGg5Ym6J9AA97ah7voH',
#   'duration_ms': 201768,
#   'time_signature': 3},
#  {'danceability': 0.261,
#   'energy': 0.174,
#   'key': 7,
#   'loudness': -16.161,
#   'mode': 1,
#   'speechiness': 0.0346,
#   'acousticness': 0.854,
#   'instrumentalness': 0.893,
#   'liveness': 0.169,
#   'valence': 0.0393,
#   'tempo': 138.999,
#   'type': 'audio_features',
#   'id': '6Ype94Pq1fdg0zogE05AfQ',
#   'uri': 'spotify:track:6Ype94Pq1fdg0zogE05AfQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Ype94Pq1fdg0zogE05AfQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Ype94Pq1fdg0zogE05AfQ',
#   'duration_ms': 323080,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.791,
#   'key': 0,
#   'loudness': -7.293,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0469,
#   'instrumentalness': 0.708,
#   'liveness': 0.128,
#   'valence': 0.509,
#   'tempo': 101.066,
#   'type': 'audio_features',
#   'id': '4VbV8Zyjuu1qz0QteX1wVC',
#   'uri': 'spotify:track:4VbV8Zyjuu1qz0QteX1wVC',
#   'track_href': 'https://api.spotify.com/v1/tracks/4VbV8Zyjuu1qz0QteX1wVC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VbV8Zyjuu1qz0QteX1wVC',
#   'duration_ms': 289827,
#   'time_signature': 4},
#  {'danceability': 0.186,
#   'energy': 0.3,
#   'key': 9,
#   'loudness': -12.141,
#   'mode': 0,
#   'speechiness': 0.0368,
#   'acousticness': 0.974,
#   'instrumentalness': 0.924,
#   'liveness': 0.0672,
#   'valence': 0.0877,
#   'tempo': 96.563,
#   'type': 'audio_features',
#   'id': '3Cs3xZgZCL2vRwKTBnoAG8',
#   'uri': 'spotify:track:3Cs3xZgZCL2vRwKTBnoAG8',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Cs3xZgZCL2vRwKTBnoAG8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Cs3xZgZCL2vRwKTBnoAG8',
#   'duration_ms': 267455,
#   'time_signature': 3},
#  {'danceability': 0.306,
#   'energy': 0.0849,
#   'key': 2,
#   'loudness': -18.843,
#   'mode': 0,
#   'speechiness': 0.0348,
#   'acousticness': 0.971,
#   'instrumentalness': 0.788,
#   'liveness': 0.111,
#   'valence': 0.11,
#   'tempo': 110.3,
#   'type': 'audio_features',
#   'id': '6xCBiZLbhAFAolDGkiinUF',
#   'uri': 'spotify:track:6xCBiZLbhAFAolDGkiinUF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xCBiZLbhAFAolDGkiinUF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xCBiZLbhAFAolDGkiinUF',
#   'duration_ms': 173461,
#   'time_signature': 3},
#  {'danceability': 0.768,
#   'energy': 0.42,
#   'key': 5,
#   'loudness': -8.55,
#   'mode': 0,
#   'speechiness': 0.0546,
#   'acousticness': 0.0705,
#   'instrumentalness': 0.899,
#   'liveness': 0.0937,
#   'valence': 0.202,
#   'tempo': 129.016,
#   'type': 'audio_features',
#   'id': '1nEDT4DsoaTfexrz8D9zt1',
#   'uri': 'spotify:track:1nEDT4DsoaTfexrz8D9zt1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nEDT4DsoaTfexrz8D9zt1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nEDT4DsoaTfexrz8D9zt1',
#   'duration_ms': 317987,
#   'time_signature': 4},
#  {'danceability': 0.558,
#   'energy': 0.813,
#   'key': 0,
#   'loudness': -8.919,
#   'mode': 1,
#   'speechiness': 0.045,
#   'acousticness': 0.00219,
#   'instrumentalness': 0.124,
#   'liveness': 0.533,
#   'valence': 0.28,
#   'tempo': 124.03,
#   'type': 'audio_features',
#   'id': '7ypjELqhyUT3BBCws8kzKN',
#   'uri': 'spotify:track:7ypjELqhyUT3BBCws8kzKN',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ypjELqhyUT3BBCws8kzKN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ypjELqhyUT3BBCws8kzKN',
#   'duration_ms': 237040,
#   'time_signature': 4},
#  {'danceability': 0.424,
#   'energy': 0.751,
#   'key': 1,
#   'loudness': -11.647,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 0.589,
#   'instrumentalness': 0.9,
#   'liveness': 0.569,
#   'valence': 0.0786,
#   'tempo': 116.664,
#   'type': 'audio_features',
#   'id': '36IJNDHIljR94apizT5Iks',
#   'uri': 'spotify:track:36IJNDHIljR94apizT5Iks',
#   'track_href': 'https://api.spotify.com/v1/tracks/36IJNDHIljR94apizT5Iks',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/36IJNDHIljR94apizT5Iks',
#   'duration_ms': 423173,
#   'time_signature': 4},
#  {'danceability': 0.629,
#   'energy': 0.583,
#   'key': 4,
#   'loudness': -11.235,
#   'mode': 0,
#   'speechiness': 0.0445,
#   'acousticness': 0.881,
#   'instrumentalness': 0.499,
#   'liveness': 0.104,
#   'valence': 0.261,
#   'tempo': 119.078,
#   'type': 'audio_features',
#   'id': '0WxzsZHbXcny0WhexO2MCa',
#   'uri': 'spotify:track:0WxzsZHbXcny0WhexO2MCa',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WxzsZHbXcny0WhexO2MCa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WxzsZHbXcny0WhexO2MCa',
#   'duration_ms': 295867,
#   'time_signature': 4},
#  {'danceability': 0.295,
#   'energy': 0.658,
#   'key': 9,
#   'loudness': -10.588,
#   'mode': 0,
#   'speechiness': 0.0501,
#   'acousticness': 0.842,
#   'instrumentalness': 0.736,
#   'liveness': 0.108,
#   'valence': 0.0665,
#   'tempo': 127.009,
#   'type': 'audio_features',
#   'id': '4IlK4zPx09Dtpx72hxM4uL',
#   'uri': 'spotify:track:4IlK4zPx09Dtpx72hxM4uL',
#   'track_href': 'https://api.spotify.com/v1/tracks/4IlK4zPx09Dtpx72hxM4uL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IlK4zPx09Dtpx72hxM4uL',
#   'duration_ms': 306760,
#   'time_signature': 4},
#  {'danceability': 0.518,
#   'energy': 0.436,
#   'key': 4,
#   'loudness': -14.134,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.0157,
#   'instrumentalness': 0.000621,
#   'liveness': 0.079,
#   'valence': 0.27,
#   'tempo': 80.88,
#   'type': 'audio_features',
#   'id': '6mcxQ1Y3uQRU0IHsvdNLH1',
#   'uri': 'spotify:track:6mcxQ1Y3uQRU0IHsvdNLH1',
#   'track_href': 'https://api.spotify.com/v1/tracks/6mcxQ1Y3uQRU0IHsvdNLH1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6mcxQ1Y3uQRU0IHsvdNLH1',
#   'duration_ms': 236973,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.783,
#   'key': 2,
#   'loudness': -12.302,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.0475,
#   'instrumentalness': 0.0296,
#   'liveness': 0.115,
#   'valence': 0.896,
#   'tempo': 124.518,
#   'type': 'audio_features',
#   'id': '0cs671lxX2eoDzr2KMuo3N',
#   'uri': 'spotify:track:0cs671lxX2eoDzr2KMuo3N',
#   'track_href': 'https://api.spotify.com/v1/tracks/0cs671lxX2eoDzr2KMuo3N',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0cs671lxX2eoDzr2KMuo3N',
#   'duration_ms': 201693,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.317,
#   'key': 7,
#   'loudness': -15.014,
#   'mode': 1,
#   'speechiness': 0.0307,
#   'acousticness': 0.000877,
#   'instrumentalness': 0.000867,
#   'liveness': 0.0745,
#   'valence': 0.33,
#   'tempo': 99.81,
#   'type': 'audio_features',
#   'id': '2Aqc48sn8He26hmTvQ2BMj',
#   'uri': 'spotify:track:2Aqc48sn8He26hmTvQ2BMj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Aqc48sn8He26hmTvQ2BMj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Aqc48sn8He26hmTvQ2BMj',
#   'duration_ms': 211440,
#   'time_signature': 4},
#  {'danceability': 0.487,
#   'energy': 0.885,
#   'key': 5,
#   'loudness': -12.005,
#   'mode': 1,
#   'speechiness': 0.0427,
#   'acousticness': 0.000397,
#   'instrumentalness': 0.347,
#   'liveness': 0.0973,
#   'valence': 0.579,
#   'tempo': 135.516,
#   'type': 'audio_features',
#   'id': '3FzKPS0oVknVlCW3PhxIHl',
#   'uri': 'spotify:track:3FzKPS0oVknVlCW3PhxIHl',
#   'track_href': 'https://api.spotify.com/v1/tracks/3FzKPS0oVknVlCW3PhxIHl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3FzKPS0oVknVlCW3PhxIHl',
#   'duration_ms': 173173,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.388,
#   'key': 6,
#   'loudness': -12.029,
#   'mode': 0,
#   'speechiness': 0.0302,
#   'acousticness': 0.0167,
#   'instrumentalness': 0.00076,
#   'liveness': 0.32,
#   'valence': 0.595,
#   'tempo': 116.433,
#   'type': 'audio_features',
#   'id': '1lFC3sMgOcDrVzNh8zXRnl',
#   'uri': 'spotify:track:1lFC3sMgOcDrVzNh8zXRnl',
#   'track_href': 'https://api.spotify.com/v1/tracks/1lFC3sMgOcDrVzNh8zXRnl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1lFC3sMgOcDrVzNh8zXRnl',
#   'duration_ms': 177467,
#   'time_signature': 4},
#  {'danceability': 0.642,
#   'energy': 0.355,
#   'key': 5,
#   'loudness': -14.196,
#   'mode': 1,
#   'speechiness': 0.0328,
#   'acousticness': 0.094,
#   'instrumentalness': 3.42e-05,
#   'liveness': 0.0865,
#   'valence': 0.724,
#   'tempo': 180.258,
#   'type': 'audio_features',
#   'id': '2KSSbWLAWSzaso01DEP32W',
#   'uri': 'spotify:track:2KSSbWLAWSzaso01DEP32W',
#   'track_href': 'https://api.spotify.com/v1/tracks/2KSSbWLAWSzaso01DEP32W',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2KSSbWLAWSzaso01DEP32W',
#   'duration_ms': 180133,
#   'time_signature': 4},
#  {'danceability': 0.385,
#   'energy': 0.707,
#   'key': 7,
#   'loudness': -11.825,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'acousticness': 0.00225,
#   'instrumentalness': 0.418,
#   'liveness': 0.0763,
#   'valence': 0.786,
#   'tempo': 115.174,
#   'type': 'audio_features',
#   'id': '3oqJ3POeLfa2TJh6BFLhPM',
#   'uri': 'spotify:track:3oqJ3POeLfa2TJh6BFLhPM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3oqJ3POeLfa2TJh6BFLhPM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3oqJ3POeLfa2TJh6BFLhPM',
#   'duration_ms': 237707,
#   'time_signature': 4},
#  {'danceability': 0.59,
#   'energy': 0.77,
#   'key': 10,
#   'loudness': -12.147,
#   'mode': 1,
#   'speechiness': 0.0346,
#   'acousticness': 0.000272,
#   'instrumentalness': 0.411,
#   'liveness': 0.0811,
#   'valence': 0.737,
#   'tempo': 132.613,
#   'type': 'audio_features',
#   'id': '1yJiE307EBIzOB9kqH1deb',
#   'uri': 'spotify:track:1yJiE307EBIzOB9kqH1deb',
#   'track_href': 'https://api.spotify.com/v1/tracks/1yJiE307EBIzOB9kqH1deb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yJiE307EBIzOB9kqH1deb',
#   'duration_ms': 124773,
#   'time_signature': 4},
#  {'danceability': 0.661,
#   'energy': 0.407,
#   'key': 4,
#   'loudness': -14.111,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.00164,
#   'instrumentalness': 0.0241,
#   'liveness': 0.0987,
#   'valence': 0.497,
#   'tempo': 125.644,
#   'type': 'audio_features',
#   'id': '1YZDkJOFT8xlAXDi8lneb3',
#   'uri': 'spotify:track:1YZDkJOFT8xlAXDi8lneb3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1YZDkJOFT8xlAXDi8lneb3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YZDkJOFT8xlAXDi8lneb3',
#   'duration_ms': 165067,
#   'time_signature': 4},
#  {'danceability': 0.356,
#   'energy': 0.931,
#   'key': 9,
#   'loudness': -5.184,
#   'mode': 1,
#   'speechiness': 0.0575,
#   'acousticness': 1.28e-05,
#   'instrumentalness': 0.133,
#   'liveness': 0.0827,
#   'valence': 0.602,
#   'tempo': 139.014,
#   'type': 'audio_features',
#   'id': '1ZaK63rgqJk8xxbks5ilUc',
#   'uri': 'spotify:track:1ZaK63rgqJk8xxbks5ilUc',
#   'track_href': 'https://api.spotify.com/v1/tracks/1ZaK63rgqJk8xxbks5ilUc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZaK63rgqJk8xxbks5ilUc',
#   'duration_ms': 81600,
#   'time_signature': 4},
#  {'danceability': 0.47,
#   'energy': 0.878,
#   'key': 11,
#   'loudness': -5.576,
#   'mode': 0,
#   'speechiness': 0.0377,
#   'acousticness': 0.0185,
#   'instrumentalness': 0.0839,
#   'liveness': 0.276,
#   'valence': 0.423,
#   'tempo': 150.093,
#   'type': 'audio_features',
#   'id': '2VbOnf4BivY15wG1GS5Vtv',
#   'uri': 'spotify:track:2VbOnf4BivY15wG1GS5Vtv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2VbOnf4BivY15wG1GS5Vtv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VbOnf4BivY15wG1GS5Vtv',
#   'duration_ms': 301093,
#   'time_signature': 4},
#  {'danceability': 0.497,
#   'energy': 0.738,
#   'key': 5,
#   'loudness': -4.09,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'acousticness': 0.00128,
#   'instrumentalness': 0.653,
#   'liveness': 0.0725,
#   'valence': 0.599,
#   'tempo': 129.078,
#   'type': 'audio_features',
#   'id': '6B182GP3TvEfmgUoIMVUSJ',
#   'uri': 'spotify:track:6B182GP3TvEfmgUoIMVUSJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6B182GP3TvEfmgUoIMVUSJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6B182GP3TvEfmgUoIMVUSJ',
#   'duration_ms': 215827,
#   'time_signature': 4},
#  {'danceability': 0.371,
#   'energy': 0.941,
#   'key': 5,
#   'loudness': -4.783,
#   'mode': 1,
#   'speechiness': 0.0602,
#   'acousticness': 5.21e-05,
#   'instrumentalness': 0.676,
#   'liveness': 0.0732,
#   'valence': 0.386,
#   'tempo': 120.499,
#   'type': 'audio_features',
#   'id': '7wvtiQ3o8ELEmk2NjSSPpX',
#   'uri': 'spotify:track:7wvtiQ3o8ELEmk2NjSSPpX',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wvtiQ3o8ELEmk2NjSSPpX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wvtiQ3o8ELEmk2NjSSPpX',
#   'duration_ms': 251547,
#   'time_signature': 4},
#  {'danceability': 0.427,
#   'energy': 0.906,
#   'key': 9,
#   'loudness': -3.488,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 6.36e-06,
#   'instrumentalness': 0.81,
#   'liveness': 0.169,
#   'valence': 0.539,
#   'tempo': 133.926,
#   'type': 'audio_features',
#   'id': '7h4RBE1rGeHMoU7722HGVY',
#   'uri': 'spotify:track:7h4RBE1rGeHMoU7722HGVY',
#   'track_href': 'https://api.spotify.com/v1/tracks/7h4RBE1rGeHMoU7722HGVY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7h4RBE1rGeHMoU7722HGVY',
#   'duration_ms': 265640,
#   'time_signature': 4},
#  {'danceability': 0.189,
#   'energy': 0.893,
#   'key': 7,
#   'loudness': -3.107,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'acousticness': 3.64e-05,
#   'instrumentalness': 0.539,
#   'liveness': 0.183,
#   'valence': 0.599,
#   'tempo': 198.468,
#   'type': 'audio_features',
#   'id': '1RTk31cNoWdx1HBRbkc02a',
#   'uri': 'spotify:track:1RTk31cNoWdx1HBRbkc02a',
#   'track_href': 'https://api.spotify.com/v1/tracks/1RTk31cNoWdx1HBRbkc02a',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RTk31cNoWdx1HBRbkc02a',
#   'duration_ms': 217693,
#   'time_signature': 4},
#  {'danceability': 0.403,
#   'energy': 0.936,
#   'key': 2,
#   'loudness': -3.986,
#   'mode': 0,
#   'speechiness': 0.0409,
#   'acousticness': 8.18e-05,
#   'instrumentalness': 0.133,
#   'liveness': 0.0613,
#   'valence': 0.703,
#   'tempo': 125.357,
#   'type': 'audio_features',
#   'id': '1PAlCnDz8T0k9f2LRuQ6Wn',
#   'uri': 'spotify:track:1PAlCnDz8T0k9f2LRuQ6Wn',
#   'track_href': 'https://api.spotify.com/v1/tracks/1PAlCnDz8T0k9f2LRuQ6Wn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PAlCnDz8T0k9f2LRuQ6Wn',
#   'duration_ms': 191173,
#   'time_signature': 4},
#  {'danceability': 0.288,
#   'energy': 0.907,
#   'key': 7,
#   'loudness': -5.753,
#   'mode': 1,
#   'speechiness': 0.0576,
#   'acousticness': 4.2e-05,
#   'instrumentalness': 0.579,
#   'liveness': 0.277,
#   'valence': 0.349,
#   'tempo': 84.483,
#   'type': 'audio_features',
#   'id': '41g3tCnqP8yTauiPQPndVO',
#   'uri': 'spotify:track:41g3tCnqP8yTauiPQPndVO',
#   'track_href': 'https://api.spotify.com/v1/tracks/41g3tCnqP8yTauiPQPndVO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41g3tCnqP8yTauiPQPndVO',
#   'duration_ms': 262427,
#   'time_signature': 4},
#  {'danceability': 0.243,
#   'energy': 0.969,
#   'key': 11,
#   'loudness': -3.134,
#   'mode': 0,
#   'speechiness': 0.0509,
#   'acousticness': 0.000371,
#   'instrumentalness': 0.6,
#   'liveness': 0.364,
#   'valence': 0.68,
#   'tempo': 141.934,
#   'type': 'audio_features',
#   'id': '0mF7YNgURDkBQaxa9YRc47',
#   'uri': 'spotify:track:0mF7YNgURDkBQaxa9YRc47',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mF7YNgURDkBQaxa9YRc47',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mF7YNgURDkBQaxa9YRc47',
#   'duration_ms': 183973,
#   'time_signature': 4},
#  {'danceability': 0.506,
#   'energy': 0.99,
#   'key': 4,
#   'loudness': -3.857,
#   'mode': 0,
#   'speechiness': 0.0841,
#   'acousticness': 7.3e-05,
#   'instrumentalness': 0.0138,
#   'liveness': 0.665,
#   'valence': 0.48,
#   'tempo': 136.967,
#   'type': 'audio_features',
#   'id': '3KmMRXOT5ENF1ZaovgGnJW',
#   'uri': 'spotify:track:3KmMRXOT5ENF1ZaovgGnJW',
#   'track_href': 'https://api.spotify.com/v1/tracks/3KmMRXOT5ENF1ZaovgGnJW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3KmMRXOT5ENF1ZaovgGnJW',
#   'duration_ms': 208413,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.908,
#   'key': 0,
#   'loudness': -3.883,
#   'mode': 1,
#   'speechiness': 0.0667,
#   'acousticness': 0.0101,
#   'instrumentalness': 0.0402,
#   'liveness': 0.109,
#   'valence': 0.167,
#   'tempo': 120.0,
#   'type': 'audio_features',
#   'id': '0XZajNIa2tdOUfCoCewcni',
#   'uri': 'spotify:track:0XZajNIa2tdOUfCoCewcni',
#   'track_href': 'https://api.spotify.com/v1/tracks/0XZajNIa2tdOUfCoCewcni',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0XZajNIa2tdOUfCoCewcni',
#   'duration_ms': 231533,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.434,
#   'key': 1,
#   'loudness': -10.004,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.177,
#   'instrumentalness': 0.516,
#   'liveness': 0.0603,
#   'valence': 0.207,
#   'tempo': 119.695,
#   'type': 'audio_features',
#   'id': '3Ty7OTBNSigGEpeW2PqcsC',
#   'uri': 'spotify:track:3Ty7OTBNSigGEpeW2PqcsC',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Ty7OTBNSigGEpeW2PqcsC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ty7OTBNSigGEpeW2PqcsC',
#   'duration_ms': 308627,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.294,
#   'key': 5,
#   'loudness': -11.836,
#   'mode': 1,
#   'speechiness': 0.0764,
#   'acousticness': 0.778,
#   'instrumentalness': 0.162,
#   'liveness': 0.106,
#   'valence': 0.192,
#   'tempo': 76.083,
#   'type': 'audio_features',
#   'id': '2sW8fmnISifQTRgnRrQTYW',
#   'uri': 'spotify:track:2sW8fmnISifQTRgnRrQTYW',
#   'track_href': 'https://api.spotify.com/v1/tracks/2sW8fmnISifQTRgnRrQTYW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2sW8fmnISifQTRgnRrQTYW',
#   'duration_ms': 303973,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.633,
#   'key': 8,
#   'loudness': -6.68,
#   'mode': 0,
#   'speechiness': 0.0406,
#   'acousticness': 0.0508,
#   'instrumentalness': 0.272,
#   'liveness': 0.264,
#   'valence': 0.55,
#   'tempo': 94.085,
#   'type': 'audio_features',
#   'id': '6vTtCOimcPs5H1Jr9d0Aep',
#   'uri': 'spotify:track:6vTtCOimcPs5H1Jr9d0Aep',
#   'track_href': 'https://api.spotify.com/v1/tracks/6vTtCOimcPs5H1Jr9d0Aep',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vTtCOimcPs5H1Jr9d0Aep',
#   'duration_ms': 252267,
#   'time_signature': 4},
#  {'danceability': 0.471,
#   'energy': 0.484,
#   'key': 9,
#   'loudness': -9.414,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.925,
#   'instrumentalness': 0.499,
#   'liveness': 0.0987,
#   'valence': 0.236,
#   'tempo': 74.982,
#   'type': 'audio_features',
#   'id': '5KX2DSPC6aCA0pdDidTmBC',
#   'uri': 'spotify:track:5KX2DSPC6aCA0pdDidTmBC',
#   'track_href': 'https://api.spotify.com/v1/tracks/5KX2DSPC6aCA0pdDidTmBC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KX2DSPC6aCA0pdDidTmBC',
#   'duration_ms': 270947,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.37,
#   'key': 6,
#   'loudness': -10.883,
#   'mode': 1,
#   'speechiness': 0.0723,
#   'acousticness': 0.504,
#   'instrumentalness': 0.587,
#   'liveness': 0.117,
#   'valence': 0.707,
#   'tempo': 80.152,
#   'type': 'audio_features',
#   'id': '7h14W1uQK7sjpVI1oVTobt',
#   'uri': 'spotify:track:7h14W1uQK7sjpVI1oVTobt',
#   'track_href': 'https://api.spotify.com/v1/tracks/7h14W1uQK7sjpVI1oVTobt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7h14W1uQK7sjpVI1oVTobt',
#   'duration_ms': 293200,
#   'time_signature': 4},
#  {'danceability': 0.601,
#   'energy': 0.656,
#   'key': 8,
#   'loudness': -2.692,
#   'mode': 0,
#   'speechiness': 0.0403,
#   'acousticness': 0.11,
#   'instrumentalness': 0.0148,
#   'liveness': 0.103,
#   'valence': 0.342,
#   'tempo': 60.161,
#   'type': 'audio_features',
#   'id': '785Qya5mtMUwBQtuypVqrx',
#   'uri': 'spotify:track:785Qya5mtMUwBQtuypVqrx',
#   'track_href': 'https://api.spotify.com/v1/tracks/785Qya5mtMUwBQtuypVqrx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/785Qya5mtMUwBQtuypVqrx',
#   'duration_ms': 240640,
#   'time_signature': 4},
#  {'danceability': 0.657,
#   'energy': 0.498,
#   'key': 11,
#   'loudness': -11.529,
#   'mode': 1,
#   'speechiness': 0.262,
#   'acousticness': 0.405,
#   'instrumentalness': 0.000479,
#   'liveness': 0.107,
#   'valence': 0.46,
#   'tempo': 164.25,
#   'type': 'audio_features',
#   'id': '2O6X9nPVVQSefg3xOQAo5u',
#   'uri': 'spotify:track:2O6X9nPVVQSefg3xOQAo5u',
#   'track_href': 'https://api.spotify.com/v1/tracks/2O6X9nPVVQSefg3xOQAo5u',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O6X9nPVVQSefg3xOQAo5u',
#   'duration_ms': 305240,
#   'time_signature': 4},
#  {'danceability': 0.326,
#   'energy': 0.447,
#   'key': 6,
#   'loudness': -6.11,
#   'mode': 1,
#   'speechiness': 0.0356,
#   'acousticness': 0.056,
#   'instrumentalness': 1.8e-05,
#   'liveness': 0.0812,
#   'valence': 0.22,
#   'tempo': 78.052,
#   'type': 'audio_features',
#   'id': '7lR743VxfubUw5m9dpnR9x',
#   'uri': 'spotify:track:7lR743VxfubUw5m9dpnR9x',
#   'track_href': 'https://api.spotify.com/v1/tracks/7lR743VxfubUw5m9dpnR9x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7lR743VxfubUw5m9dpnR9x',
#   'duration_ms': 235800,
#   'time_signature': 4},
#  {'danceability': 0.668,
#   'energy': 0.52,
#   'key': 9,
#   'loudness': -11.098,
#   'mode': 1,
#   'speechiness': 0.0444,
#   'acousticness': 0.698,
#   'instrumentalness': 0.0165,
#   'liveness': 0.13,
#   'valence': 0.556,
#   'tempo': 153.963,
#   'type': 'audio_features',
#   'id': '1cpnpMvnvmdy3hzYgd5oo9',
#   'uri': 'spotify:track:1cpnpMvnvmdy3hzYgd5oo9',
#   'track_href': 'https://api.spotify.com/v1/tracks/1cpnpMvnvmdy3hzYgd5oo9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cpnpMvnvmdy3hzYgd5oo9',
#   'duration_ms': 257160,
#   'time_signature': 4},
#  {'danceability': 0.659,
#   'energy': 0.617,
#   'key': 6,
#   'loudness': -6.157,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.0355,
#   'instrumentalness': 0.16,
#   'liveness': 0.185,
#   'valence': 0.25,
#   'tempo': 84.078,
#   'type': 'audio_features',
#   'id': '6pW8YspamPCxUwgvYttTSc',
#   'uri': 'spotify:track:6pW8YspamPCxUwgvYttTSc',
#   'track_href': 'https://api.spotify.com/v1/tracks/6pW8YspamPCxUwgvYttTSc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pW8YspamPCxUwgvYttTSc',
#   'duration_ms': 237600,
#   'time_signature': 4},
#  {'danceability': 0.464,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -5.244,
#   'mode': 1,
#   'speechiness': 0.0333,
#   'acousticness': 0.006,
#   'instrumentalness': 0.000304,
#   'liveness': 0.392,
#   'valence': 0.547,
#   'tempo': 129.964,
#   'type': 'audio_features',
#   'id': '2DFRFqWNahKtFD112H2iEZ',
#   'uri': 'spotify:track:2DFRFqWNahKtFD112H2iEZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2DFRFqWNahKtFD112H2iEZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DFRFqWNahKtFD112H2iEZ',
#   'duration_ms': 213173,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.902,
#   'key': 0,
#   'loudness': -7.918,
#   'mode': 1,
#   'speechiness': 0.0958,
#   'acousticness': 0.337,
#   'instrumentalness': 0,
#   'liveness': 0.152,
#   'valence': 0.62,
#   'tempo': 156.108,
#   'type': 'audio_features',
#   'id': '0ccCwNzXvr1Yoz91vKz31Z',
#   'uri': 'spotify:track:0ccCwNzXvr1Yoz91vKz31Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ccCwNzXvr1Yoz91vKz31Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ccCwNzXvr1Yoz91vKz31Z',
#   'duration_ms': 287507,
#   'time_signature': 4},
#  {'danceability': 0.33,
#   'energy': 0.556,
#   'key': 7,
#   'loudness': -11.494,
#   'mode': 1,
#   'speechiness': 0.0796,
#   'acousticness': 0.207,
#   'instrumentalness': 4.39e-05,
#   'liveness': 0.315,
#   'valence': 0.506,
#   'tempo': 173.828,
#   'type': 'audio_features',
#   'id': '1dJuteDIOkGfDSN7zPkzNv',
#   'uri': 'spotify:track:1dJuteDIOkGfDSN7zPkzNv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1dJuteDIOkGfDSN7zPkzNv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dJuteDIOkGfDSN7zPkzNv',
#   'duration_ms': 222279,
#   'time_signature': 4},
#  {'danceability': 0.326,
#   'energy': 0.841,
#   'key': 0,
#   'loudness': -7.14,
#   'mode': 1,
#   'speechiness': 0.0858,
#   'acousticness': 4.56e-05,
#   'instrumentalness': 0.028,
#   'liveness': 0.251,
#   'valence': 0.449,
#   'tempo': 130.723,
#   'type': 'audio_features',
#   'id': '1RZlGlz8eXT1KmJYpqFRzH',
#   'uri': 'spotify:track:1RZlGlz8eXT1KmJYpqFRzH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1RZlGlz8eXT1KmJYpqFRzH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RZlGlz8eXT1KmJYpqFRzH',
#   'duration_ms': 258912,
#   'time_signature': 4},
#  {'danceability': 0.49,
#   'energy': 0.985,
#   'key': 9,
#   'loudness': -2.386,
#   'mode': 1,
#   'speechiness': 0.0639,
#   'acousticness': 0.0404,
#   'instrumentalness': 1.77e-05,
#   'liveness': 0.304,
#   'valence': 0.886,
#   'tempo': 82.043,
#   'type': 'audio_features',
#   'id': '0ScgmigVOJr2mFsAtwFQmz',
#   'uri': 'spotify:track:0ScgmigVOJr2mFsAtwFQmz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ScgmigVOJr2mFsAtwFQmz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ScgmigVOJr2mFsAtwFQmz',
#   'duration_ms': 256720,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.924,
#   'key': 4,
#   'loudness': -5.338,
#   'mode': 0,
#   'speechiness': 0.0473,
#   'acousticness': 0.00387,
#   'instrumentalness': 0,
#   'liveness': 0.662,
#   'valence': 0.245,
#   'tempo': 115.014,
#   'type': 'audio_features',
#   'id': '6YeR95fvPNXuOKbJfcvqBk',
#   'uri': 'spotify:track:6YeR95fvPNXuOKbJfcvqBk',
#   'track_href': 'https://api.spotify.com/v1/tracks/6YeR95fvPNXuOKbJfcvqBk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YeR95fvPNXuOKbJfcvqBk',
#   'duration_ms': 211967,
#   'time_signature': 4},
#  {'danceability': 0.394,
#   'energy': 0.77,
#   'key': 2,
#   'loudness': -6.081,
#   'mode': 0,
#   'speechiness': 0.0431,
#   'acousticness': 0.129,
#   'instrumentalness': 0.00463,
#   'liveness': 0.23,
#   'valence': 0.268,
#   'tempo': 159.886,
#   'type': 'audio_features',
#   'id': '4yYKWN3FtoRxdlJBqIn8Rh',
#   'uri': 'spotify:track:4yYKWN3FtoRxdlJBqIn8Rh',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yYKWN3FtoRxdlJBqIn8Rh',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yYKWN3FtoRxdlJBqIn8Rh',
#   'duration_ms': 238973,
#   'time_signature': 4},
#  {'danceability': 0.517,
#   'energy': 0.7,
#   'key': 7,
#   'loudness': -5.019,
#   'mode': 1,
#   'speechiness': 0.0372,
#   'acousticness': 0.125,
#   'instrumentalness': 5.33e-06,
#   'liveness': 0.208,
#   'valence': 0.57,
#   'tempo': 92.568,
#   'type': 'audio_features',
#   'id': '12X8MvZMLdpPbkXMoXPDU8',
#   'uri': 'spotify:track:12X8MvZMLdpPbkXMoXPDU8',
#   'track_href': 'https://api.spotify.com/v1/tracks/12X8MvZMLdpPbkXMoXPDU8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12X8MvZMLdpPbkXMoXPDU8',
#   'duration_ms': 220721,
#   'time_signature': 4},
#  {'danceability': 0.297,
#   'energy': 0.728,
#   'key': 0,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0347,
#   'acousticness': 0.231,
#   'instrumentalness': 0.124,
#   'liveness': 0.666,
#   'valence': 0.37,
#   'tempo': 134.186,
#   'type': 'audio_features',
#   'id': '4ou3f7jaB41isbJkt6CF2b',
#   'uri': 'spotify:track:4ou3f7jaB41isbJkt6CF2b',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ou3f7jaB41isbJkt6CF2b',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ou3f7jaB41isbJkt6CF2b',
#   'duration_ms': 379240,
#   'time_signature': 4},
#  {'danceability': 0.636,
#   'energy': 0.887,
#   'key': 4,
#   'loudness': -4.354,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.00257,
#   'instrumentalness': 5.18e-05,
#   'liveness': 0.293,
#   'valence': 0.35,
#   'tempo': 107.984,
#   'type': 'audio_features',
#   'id': '2SsrjDZM8ZIvKaUssqPs4o',
#   'uri': 'spotify:track:2SsrjDZM8ZIvKaUssqPs4o',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SsrjDZM8ZIvKaUssqPs4o',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SsrjDZM8ZIvKaUssqPs4o',
#   'duration_ms': 232520,
#   'time_signature': 4},
#  {'danceability': 0.323,
#   'energy': 0.136,
#   'key': 0,
#   'loudness': -10.33,
#   'mode': 1,
#   'speechiness': 0.0318,
#   'acousticness': 0.931,
#   'instrumentalness': 0.00119,
#   'liveness': 0.176,
#   'valence': 0.0828,
#   'tempo': 96.88,
#   'type': 'audio_features',
#   'id': '3pRaLNL3b8x5uBOcsgvdqM',
#   'uri': 'spotify:track:3pRaLNL3b8x5uBOcsgvdqM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pRaLNL3b8x5uBOcsgvdqM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pRaLNL3b8x5uBOcsgvdqM',
#   'duration_ms': 413827,
#   'time_signature': 3},
#  {'danceability': 0.385,
#   'energy': 0.595,
#   'key': 2,
#   'loudness': -5.67,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.361,
#   'instrumentalness': 1.09e-05,
#   'liveness': 0.174,
#   'valence': 0.152,
#   'tempo': 119.38,
#   'type': 'audio_features',
#   'id': '6Jv7kjGkhY2fT4yuBF3aTz',
#   'uri': 'spotify:track:6Jv7kjGkhY2fT4yuBF3aTz',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Jv7kjGkhY2fT4yuBF3aTz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Jv7kjGkhY2fT4yuBF3aTz',
#   'duration_ms': 404213,
#   'time_signature': 3},
#  {'danceability': 0.541,
#   'energy': 0.829,
#   'key': 2,
#   'loudness': -5.045,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.0256,
#   'instrumentalness': 0.000432,
#   'liveness': 0.233,
#   'valence': 0.516,
#   'tempo': 86.934,
#   'type': 'audio_features',
#   'id': '0y5CnV2idm2KkQEudDjfDT',
#   'uri': 'spotify:track:0y5CnV2idm2KkQEudDjfDT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0y5CnV2idm2KkQEudDjfDT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0y5CnV2idm2KkQEudDjfDT',
#   'duration_ms': 275720,
#   'time_signature': 4},
#  {'danceability': 0.545,
#   'energy': 0.867,
#   'key': 11,
#   'loudness': -4.235,
#   'mode': 0,
#   'speechiness': 0.0354,
#   'acousticness': 0.0253,
#   'instrumentalness': 0.000225,
#   'liveness': 0.221,
#   'valence': 0.188,
#   'tempo': 127.873,
#   'type': 'audio_features',
#   'id': '64SIlhd3BaHCCMSfajXG7l',
#   'uri': 'spotify:track:64SIlhd3BaHCCMSfajXG7l',
#   'track_href': 'https://api.spotify.com/v1/tracks/64SIlhd3BaHCCMSfajXG7l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64SIlhd3BaHCCMSfajXG7l',
#   'duration_ms': 322040,
#   'time_signature': 4},
#  {'danceability': 0.312,
#   'energy': 0.0849,
#   'key': 7,
#   'loudness': -16.414,
#   'mode': 1,
#   'speechiness': 0.0374,
#   'acousticness': 0.827,
#   'instrumentalness': 5.36e-05,
#   'liveness': 0.0938,
#   'valence': 0.0673,
#   'tempo': 96.039,
#   'type': 'audio_features',
#   'id': '1StXVL5gClph4z4XzanYko',
#   'uri': 'spotify:track:1StXVL5gClph4z4XzanYko',
#   'track_href': 'https://api.spotify.com/v1/tracks/1StXVL5gClph4z4XzanYko',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1StXVL5gClph4z4XzanYko',
#   'duration_ms': 272920,
#   'time_signature': 3},
#  {'danceability': 0.367,
#   'energy': 0.0527,
#   'key': 0,
#   'loudness': -17.684,
#   'mode': 1,
#   'speechiness': 0.0468,
#   'acousticness': 0.962,
#   'instrumentalness': 0.00679,
#   'liveness': 0.109,
#   'valence': 0.108,
#   'tempo': 170.124,
#   'type': 'audio_features',
#   'id': '4yg2qSpnVAbQLPjCJTWwtY',
#   'uri': 'spotify:track:4yg2qSpnVAbQLPjCJTWwtY',
#   'track_href': 'https://api.spotify.com/v1/tracks/4yg2qSpnVAbQLPjCJTWwtY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yg2qSpnVAbQLPjCJTWwtY',
#   'duration_ms': 205587,
#   'time_signature': 1},
#  {'danceability': 0.434,
#   'energy': 0.028,
#   'key': 9,
#   'loudness': -17.724,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.932,
#   'instrumentalness': 3.75e-05,
#   'liveness': 0.111,
#   'valence': 0.137,
#   'tempo': 90.275,
#   'type': 'audio_features',
#   'id': '7qdbu6JlWG3Dfjo3MqlMdF',
#   'uri': 'spotify:track:7qdbu6JlWG3Dfjo3MqlMdF',
#   'track_href': 'https://api.spotify.com/v1/tracks/7qdbu6JlWG3Dfjo3MqlMdF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qdbu6JlWG3Dfjo3MqlMdF',
#   'duration_ms': 359600,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.387,
#   'key': 9,
#   'loudness': -7.359,
#   'mode': 0,
#   'speechiness': 0.0368,
#   'acousticness': 0.527,
#   'instrumentalness': 0.00013,
#   'liveness': 0.0982,
#   'valence': 0.606,
#   'tempo': 120.689,
#   'type': 'audio_features',
#   'id': '2bcvooA6HEmVUneEGJnNZD',
#   'uri': 'spotify:track:2bcvooA6HEmVUneEGJnNZD',
#   'track_href': 'https://api.spotify.com/v1/tracks/2bcvooA6HEmVUneEGJnNZD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2bcvooA6HEmVUneEGJnNZD',
#   'duration_ms': 286707,
#   'time_signature': 4},
#  {'danceability': 0.274,
#   'energy': 0.0637,
#   'key': 8,
#   'loudness': -23.926,
#   'mode': 1,
#   'speechiness': 0.0446,
#   'acousticness': 0.896,
#   'instrumentalness': 0.00105,
#   'liveness': 0.818,
#   'valence': 0.124,
#   'tempo': 173.515,
#   'type': 'audio_features',
#   'id': '1nd2JEHXbUuQFDiQzCBpsv',
#   'uri': 'spotify:track:1nd2JEHXbUuQFDiQzCBpsv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1nd2JEHXbUuQFDiQzCBpsv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1nd2JEHXbUuQFDiQzCBpsv',
#   'duration_ms': 268493,
#   'time_signature': 3},
#  {'danceability': 0.427,
#   'energy': 0.563,
#   'key': 9,
#   'loudness': -5.251,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.0987,
#   'instrumentalness': 9.64e-05,
#   'liveness': 0.221,
#   'valence': 0.282,
#   'tempo': 182.664,
#   'type': 'audio_features',
#   'id': '6UuVONmxXwTKN1ISepuAoQ',
#   'uri': 'spotify:track:6UuVONmxXwTKN1ISepuAoQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6UuVONmxXwTKN1ISepuAoQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UuVONmxXwTKN1ISepuAoQ',
#   'duration_ms': 312213,
#   'time_signature': 3},
#  {'danceability': 0.616,
#   'energy': 0.682,
#   'key': 6,
#   'loudness': -6.148,
#   'mode': 0,
#   'speechiness': 0.0265,
#   'acousticness': 0.0578,
#   'instrumentalness': 0.0241,
#   'liveness': 0.342,
#   'valence': 0.528,
#   'tempo': 117.78,
#   'type': 'audio_features',
#   'id': '2UWdUez9MB9yzL7Y81Mcip',
#   'uri': 'spotify:track:2UWdUez9MB9yzL7Y81Mcip',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UWdUez9MB9yzL7Y81Mcip',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UWdUez9MB9yzL7Y81Mcip',
#   'duration_ms': 315200,
#   'time_signature': 4},
#  {'danceability': 0.252,
#   'energy': 0.8,
#   'key': 0,
#   'loudness': -4.845,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.12,
#   'instrumentalness': 0.0538,
#   'liveness': 0.118,
#   'valence': 0.29,
#   'tempo': 139.361,
#   'type': 'audio_features',
#   'id': '6Hmj7SrLRbreLVfVS7mV1S',
#   'uri': 'spotify:track:6Hmj7SrLRbreLVfVS7mV1S',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Hmj7SrLRbreLVfVS7mV1S',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Hmj7SrLRbreLVfVS7mV1S',
#   'duration_ms': 335333,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.865,
#   'key': 0,
#   'loudness': -5.325,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.00171,
#   'instrumentalness': 0.000449,
#   'liveness': 0.457,
#   'valence': 0.61,
#   'tempo': 116.046,
#   'type': 'audio_features',
#   'id': '7KsZHCfOitA5V9oQYVdltG',
#   'uri': 'spotify:track:7KsZHCfOitA5V9oQYVdltG',
#   'track_href': 'https://api.spotify.com/v1/tracks/7KsZHCfOitA5V9oQYVdltG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7KsZHCfOitA5V9oQYVdltG',
#   'duration_ms': 303013,
#   'time_signature': 4},
#  {'danceability': 0.401,
#   'energy': 0.933,
#   'key': 8,
#   'loudness': -5.682,
#   'mode': 1,
#   'speechiness': 0.0344,
#   'acousticness': 0.00744,
#   'instrumentalness': 0.627,
#   'liveness': 0.318,
#   'valence': 0.734,
#   'tempo': 127.193,
#   'type': 'audio_features',
#   'id': '0xOeB16JDbBJBJKSdHbElT',
#   'uri': 'spotify:track:0xOeB16JDbBJBJKSdHbElT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xOeB16JDbBJBJKSdHbElT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xOeB16JDbBJBJKSdHbElT',
#   'duration_ms': 310893,
#   'time_signature': 4},
#  {'danceability': 0.518,
#   'energy': 0.81,
#   'key': 8,
#   'loudness': -6.445,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.016,
#   'instrumentalness': 0.0013,
#   'liveness': 0.115,
#   'valence': 0.179,
#   'tempo': 99.968,
#   'type': 'audio_features',
#   'id': '0U0p8weaMIbIFMJ0CPlvHV',
#   'uri': 'spotify:track:0U0p8weaMIbIFMJ0CPlvHV',
#   'track_href': 'https://api.spotify.com/v1/tracks/0U0p8weaMIbIFMJ0CPlvHV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0U0p8weaMIbIFMJ0CPlvHV',
#   'duration_ms': 325547,
#   'time_signature': 4},
#  {'danceability': 0.282,
#   'energy': 0.932,
#   'key': 9,
#   'loudness': -4.701,
#   'mode': 1,
#   'speechiness': 0.0387,
#   'acousticness': 0.12,
#   'instrumentalness': 0.0335,
#   'liveness': 0.0692,
#   'valence': 0.536,
#   'tempo': 190.08,
#   'type': 'audio_features',
#   'id': '01wsKcJ8ptqUmatpJlEGYj',
#   'uri': 'spotify:track:01wsKcJ8ptqUmatpJlEGYj',
#   'track_href': 'https://api.spotify.com/v1/tracks/01wsKcJ8ptqUmatpJlEGYj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01wsKcJ8ptqUmatpJlEGYj',
#   'duration_ms': 255893,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.768,
#   'key': 7,
#   'loudness': -6.484,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.541,
#   'instrumentalness': 0.0201,
#   'liveness': 0.752,
#   'valence': 0.645,
#   'tempo': 123.067,
#   'type': 'audio_features',
#   'id': '0SaEmR2rdtfsZawPjMYkWg',
#   'uri': 'spotify:track:0SaEmR2rdtfsZawPjMYkWg',
#   'track_href': 'https://api.spotify.com/v1/tracks/0SaEmR2rdtfsZawPjMYkWg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SaEmR2rdtfsZawPjMYkWg',
#   'duration_ms': 353240,
#   'time_signature': 4},
#  {'danceability': 0.296,
#   'energy': 0.502,
#   'key': 0,
#   'loudness': -8.653,
#   'mode': 0,
#   'speechiness': 0.0336,
#   'acousticness': 0.315,
#   'instrumentalness': 0.0551,
#   'liveness': 0.229,
#   'valence': 0.313,
#   'tempo': 81.045,
#   'type': 'audio_features',
#   'id': '1rOlTL4pKQ9Y1fURua4AJR',
#   'uri': 'spotify:track:1rOlTL4pKQ9Y1fURua4AJR',
#   'track_href': 'https://api.spotify.com/v1/tracks/1rOlTL4pKQ9Y1fURua4AJR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1rOlTL4pKQ9Y1fURua4AJR',
#   'duration_ms': 287240,
#   'time_signature': 4},
#  {'danceability': 0.282,
#   'energy': 0.738,
#   'key': 0,
#   'loudness': -5.566,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.0647,
#   'instrumentalness': 0.0142,
#   'liveness': 0.29,
#   'valence': 0.211,
#   'tempo': 126.914,
#   'type': 'audio_features',
#   'id': '0WZZJ0mDKIkLfL0710ssZt',
#   'uri': 'spotify:track:0WZZJ0mDKIkLfL0710ssZt',
#   'track_href': 'https://api.spotify.com/v1/tracks/0WZZJ0mDKIkLfL0710ssZt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0WZZJ0mDKIkLfL0710ssZt',
#   'duration_ms': 288333,
#   'time_signature': 4},
#  {'danceability': 0.423,
#   'energy': 0.949,
#   'key': 11,
#   'loudness': -4.097,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.0181,
#   'instrumentalness': 0.00355,
#   'liveness': 0.292,
#   'valence': 0.278,
#   'tempo': 189.976,
#   'type': 'audio_features',
#   'id': '2voWPWlDfIthC6GUjaIQyV',
#   'uri': 'spotify:track:2voWPWlDfIthC6GUjaIQyV',
#   'track_href': 'https://api.spotify.com/v1/tracks/2voWPWlDfIthC6GUjaIQyV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2voWPWlDfIthC6GUjaIQyV',
#   'duration_ms': 283507,
#   'time_signature': 4},
#  {'danceability': 0.314,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -9.026,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.0057,
#   'instrumentalness': 5.59e-05,
#   'liveness': 0.0718,
#   'valence': 0.569,
#   'tempo': 145.393,
#   'type': 'audio_features',
#   'id': '2fXKyAyPrEa24c6PJyqznF',
#   'uri': 'spotify:track:2fXKyAyPrEa24c6PJyqznF',
#   'track_href': 'https://api.spotify.com/v1/tracks/2fXKyAyPrEa24c6PJyqznF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2fXKyAyPrEa24c6PJyqznF',
#   'duration_ms': 351627,
#   'time_signature': 4},
#  {'danceability': 0.565,
#   'energy': 0.902,
#   'key': 7,
#   'loudness': -7.579,
#   'mode': 0,
#   'speechiness': 0.0725,
#   'acousticness': 0.0132,
#   'instrumentalness': 0,
#   'liveness': 0.0561,
#   'valence': 0.544,
#   'tempo': 133.11,
#   'type': 'audio_features',
#   'id': '2aC8wwfrM0YeTAzzk8hxqC',
#   'uri': 'spotify:track:2aC8wwfrM0YeTAzzk8hxqC',
#   'track_href': 'https://api.spotify.com/v1/tracks/2aC8wwfrM0YeTAzzk8hxqC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2aC8wwfrM0YeTAzzk8hxqC',
#   'duration_ms': 273573,
#   'time_signature': 4},
#  {'danceability': 0.302,
#   'energy': 0.854,
#   'key': 2,
#   'loudness': -6.619,
#   'mode': 1,
#   'speechiness': 0.0757,
#   'acousticness': 0.102,
#   'instrumentalness': 1.45e-06,
#   'liveness': 0.0835,
#   'valence': 0.589,
#   'tempo': 156.278,
#   'type': 'audio_features',
#   'id': '4j3obTRIyR7QzvdeQz9vaO',
#   'uri': 'spotify:track:4j3obTRIyR7QzvdeQz9vaO',
#   'track_href': 'https://api.spotify.com/v1/tracks/4j3obTRIyR7QzvdeQz9vaO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4j3obTRIyR7QzvdeQz9vaO',
#   'duration_ms': 244827,
#   'time_signature': 4},
#  {'danceability': 0.404,
#   'energy': 0.902,
#   'key': 7,
#   'loudness': -5.685,
#   'mode': 0,
#   'speechiness': 0.0468,
#   'acousticness': 0.0431,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.231,
#   'tempo': 131.894,
#   'type': 'audio_features',
#   'id': '0txLC5NA64M8siGn3mnET0',
#   'uri': 'spotify:track:0txLC5NA64M8siGn3mnET0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0txLC5NA64M8siGn3mnET0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0txLC5NA64M8siGn3mnET0',
#   'duration_ms': 262827,
#   'time_signature': 4},
#  {'danceability': 0.537,
#   'energy': 0.675,
#   'key': 7,
#   'loudness': -8.332,
#   'mode': 1,
#   'speechiness': 0.0309,
#   'acousticness': 0.0226,
#   'instrumentalness': 0.0188,
#   'liveness': 0.355,
#   'valence': 0.384,
#   'tempo': 120.543,
#   'type': 'audio_features',
#   'id': '05FgZdqxXg40X0WG8MmWMA',
#   'uri': 'spotify:track:05FgZdqxXg40X0WG8MmWMA',
#   'track_href': 'https://api.spotify.com/v1/tracks/05FgZdqxXg40X0WG8MmWMA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05FgZdqxXg40X0WG8MmWMA',
#   'duration_ms': 198573,
#   'time_signature': 4},
#  {'danceability': 0.336,
#   'energy': 0.511,
#   'key': 9,
#   'loudness': -7.839,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'acousticness': 0.00532,
#   'instrumentalness': 0.00062,
#   'liveness': 0.159,
#   'valence': 0.112,
#   'tempo': 153.954,
#   'type': 'audio_features',
#   'id': '1so0qYkfkiZNNcvJN02qdo',
#   'uri': 'spotify:track:1so0qYkfkiZNNcvJN02qdo',
#   'track_href': 'https://api.spotify.com/v1/tracks/1so0qYkfkiZNNcvJN02qdo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1so0qYkfkiZNNcvJN02qdo',
#   'duration_ms': 383733,
#   'time_signature': 4},
#  {'danceability': 0.605,
#   'energy': 0.775,
#   'key': 5,
#   'loudness': -8.909,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.141,
#   'instrumentalness': 0.000472,
#   'liveness': 0.0918,
#   'valence': 0.406,
#   'tempo': 98.361,
#   'type': 'audio_features',
#   'id': '3DYnqG3jqB1bijSKsJzuzG',
#   'uri': 'spotify:track:3DYnqG3jqB1bijSKsJzuzG',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DYnqG3jqB1bijSKsJzuzG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DYnqG3jqB1bijSKsJzuzG',
#   'duration_ms': 270800,
#   'time_signature': 4},
#  {'danceability': 0.279,
#   'energy': 0.627,
#   'key': 9,
#   'loudness': -9.419,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.0991,
#   'instrumentalness': 2.09e-06,
#   'liveness': 0.11,
#   'valence': 0.214,
#   'tempo': 97.051,
#   'type': 'audio_features',
#   'id': '5pcDlqgygjWQ75QYLM7mdL',
#   'uri': 'spotify:track:5pcDlqgygjWQ75QYLM7mdL',
#   'track_href': 'https://api.spotify.com/v1/tracks/5pcDlqgygjWQ75QYLM7mdL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pcDlqgygjWQ75QYLM7mdL',
#   'duration_ms': 246187,
#   'time_signature': 4},
#  {'danceability': 0.373,
#   'energy': 0.768,
#   'key': 0,
#   'loudness': -9.39,
#   'mode': 1,
#   'speechiness': 0.0637,
#   'acousticness': 0.272,
#   'instrumentalness': 3.14e-06,
#   'liveness': 0.361,
#   'valence': 0.527,
#   'tempo': 91.783,
#   'type': 'audio_features',
#   'id': '6OiWR0dBoVnd0NpD0kCijF',
#   'uri': 'spotify:track:6OiWR0dBoVnd0NpD0kCijF',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OiWR0dBoVnd0NpD0kCijF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OiWR0dBoVnd0NpD0kCijF',
#   'duration_ms': 227827,
#   'time_signature': 4},
#  {'danceability': 0.322,
#   'energy': 0.656,
#   'key': 5,
#   'loudness': -7.748,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.000816,
#   'instrumentalness': 0.00259,
#   'liveness': 0.306,
#   'valence': 0.315,
#   'tempo': 118.467,
#   'type': 'audio_features',
#   'id': '3Z9d7g8Pn4S4ivwlziwcf6',
#   'uri': 'spotify:track:3Z9d7g8Pn4S4ivwlziwcf6',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Z9d7g8Pn4S4ivwlziwcf6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Z9d7g8Pn4S4ivwlziwcf6',
#   'duration_ms': 237447,
#   'time_signature': 4},
#  {'danceability': 0.356,
#   'energy': 0.917,
#   'key': 9,
#   'loudness': -6.006,
#   'mode': 1,
#   'speechiness': 0.0479,
#   'acousticness': 0.0335,
#   'instrumentalness': 0,
#   'liveness': 0.406,
#   'valence': 0.518,
#   'tempo': 171.176,
#   'type': 'audio_features',
#   'id': '57iDDD9N9tTWe75x6qhStw',
#   'uri': 'spotify:track:57iDDD9N9tTWe75x6qhStw',
#   'track_href': 'https://api.spotify.com/v1/tracks/57iDDD9N9tTWe75x6qhStw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57iDDD9N9tTWe75x6qhStw',
#   'duration_ms': 357267,
#   'time_signature': 4},
#  {'danceability': 0.407,
#   'energy': 0.663,
#   'key': 2,
#   'loudness': -7.591,
#   'mode': 1,
#   'speechiness': 0.0305,
#   'acousticness': 0.255,
#   'instrumentalness': 0.000166,
#   'liveness': 0.0913,
#   'valence': 0.211,
#   'tempo': 75.989,
#   'type': 'audio_features',
#   'id': '2mxPSHEwjJWOQS7lGw6btF',
#   'uri': 'spotify:track:2mxPSHEwjJWOQS7lGw6btF',
#   'track_href': 'https://api.spotify.com/v1/tracks/2mxPSHEwjJWOQS7lGw6btF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mxPSHEwjJWOQS7lGw6btF',
#   'duration_ms': 293587,
#   'time_signature': 4},
#  {'danceability': 0.442,
#   'energy': 0.52,
#   'key': 0,
#   'loudness': -8.648,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.184,
#   'instrumentalness': 0,
#   'liveness': 0.154,
#   'valence': 0.177,
#   'tempo': 77.437,
#   'type': 'audio_features',
#   'id': '15kLz0zNFdtsaJdXKSGmTU',
#   'uri': 'spotify:track:15kLz0zNFdtsaJdXKSGmTU',
#   'track_href': 'https://api.spotify.com/v1/tracks/15kLz0zNFdtsaJdXKSGmTU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15kLz0zNFdtsaJdXKSGmTU',
#   'duration_ms': 304880,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.725,
#   'key': 0,
#   'loudness': -7.296,
#   'mode': 1,
#   'speechiness': 0.0244,
#   'acousticness': 0.12,
#   'instrumentalness': 4.34e-05,
#   'liveness': 0.225,
#   'valence': 0.376,
#   'tempo': 89.059,
#   'type': 'audio_features',
#   'id': '6OgWHP8rRXiq7VMaryVaVo',
#   'uri': 'spotify:track:6OgWHP8rRXiq7VMaryVaVo',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OgWHP8rRXiq7VMaryVaVo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OgWHP8rRXiq7VMaryVaVo',
#   'duration_ms': 261360,
#   'time_signature': 4},
#  {'danceability': 0.338,
#   'energy': 0.638,
#   'key': 2,
#   'loudness': -7.989,
#   'mode': 1,
#   'speechiness': 0.0332,
#   'acousticness': 0.105,
#   'instrumentalness': 0,
#   'liveness': 0.102,
#   'valence': 0.113,
#   'tempo': 133.99,
#   'type': 'audio_features',
#   'id': '52p8lRbIrKYjzwDMXgBVFO',
#   'uri': 'spotify:track:52p8lRbIrKYjzwDMXgBVFO',
#   'track_href': 'https://api.spotify.com/v1/tracks/52p8lRbIrKYjzwDMXgBVFO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52p8lRbIrKYjzwDMXgBVFO',
#   'duration_ms': 326093,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.865,
#   'key': 7,
#   'loudness': -4.153,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.000472,
#   'instrumentalness': 0,
#   'liveness': 0.385,
#   'valence': 0.311,
#   'tempo': 123.06,
#   'type': 'audio_features',
#   'id': '6ypCu5xx6kJp2hnQ8zncqQ',
#   'uri': 'spotify:track:6ypCu5xx6kJp2hnQ8zncqQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ypCu5xx6kJp2hnQ8zncqQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ypCu5xx6kJp2hnQ8zncqQ',
#   'duration_ms': 327960,
#   'time_signature': 4},
#  {'danceability': 0.21,
#   'energy': 0.723,
#   'key': 2,
#   'loudness': -8.803,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'acousticness': 0.0419,
#   'instrumentalness': 0.00457,
#   'liveness': 0.138,
#   'valence': 0.326,
#   'tempo': 165.495,
#   'type': 'audio_features',
#   'id': '5LLNmbRzBCT3cfrmHg6jR7',
#   'uri': 'spotify:track:5LLNmbRzBCT3cfrmHg6jR7',
#   'track_href': 'https://api.spotify.com/v1/tracks/5LLNmbRzBCT3cfrmHg6jR7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5LLNmbRzBCT3cfrmHg6jR7',
#   'duration_ms': 336640,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.635,
#   'key': 2,
#   'loudness': -7.566,
#   'mode': 1,
#   'speechiness': 0.032,
#   'acousticness': 0.017,
#   'instrumentalness': 0.323,
#   'liveness': 0.0769,
#   'valence': 0.221,
#   'tempo': 150.1,
#   'type': 'audio_features',
#   'id': '0Sr9uJqXFAvqHcgwg3UjY5',
#   'uri': 'spotify:track:0Sr9uJqXFAvqHcgwg3UjY5',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Sr9uJqXFAvqHcgwg3UjY5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Sr9uJqXFAvqHcgwg3UjY5',
#   'duration_ms': 243453,
#   'time_signature': 4},
#  {'danceability': 0.195,
#   'energy': 0.937,
#   'key': 7,
#   'loudness': -6.814,
#   'mode': 1,
#   'speechiness': 0.0927,
#   'acousticness': 0.0204,
#   'instrumentalness': 0.000875,
#   'liveness': 0.356,
#   'valence': 0.436,
#   'tempo': 164.739,
#   'type': 'audio_features',
#   'id': '3dPSPaolTvtOvSCKo1ProN',
#   'uri': 'spotify:track:3dPSPaolTvtOvSCKo1ProN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3dPSPaolTvtOvSCKo1ProN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dPSPaolTvtOvSCKo1ProN',
#   'duration_ms': 421893,
#   'time_signature': 4},
#  {'danceability': 0.323,
#   'energy': 0.749,
#   'key': 4,
#   'loudness': -6.833,
#   'mode': 0,
#   'speechiness': 0.0304,
#   'acousticness': 0.00878,
#   'instrumentalness': 0.000412,
#   'liveness': 0.0655,
#   'valence': 0.459,
#   'tempo': 152.088,
#   'type': 'audio_features',
#   'id': '5MFO9lwRDQy2Z85AvdwsL3',
#   'uri': 'spotify:track:5MFO9lwRDQy2Z85AvdwsL3',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MFO9lwRDQy2Z85AvdwsL3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MFO9lwRDQy2Z85AvdwsL3',
#   'duration_ms': 289907,
#   'time_signature': 4}]

# %%
batch_1 = pd.DataFrame(features_batch_1)
batch_2 = pd.DataFrame(features_batch_2)
df = pd.concat([batch_1, batch_2]).head()

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.674   0.789    8    -6.903     1       0.0676       0.00178
# 1         0.693   0.875    7    -8.354     0       0.0315       0.00971
# 2         0.743   0.743    2   -10.117     1       0.0367       0.05110
# 3         0.587   0.566    9    -9.932     1       0.0276       0.47000
# 4         0.803   0.722    2    -6.421     1       0.0377       0.03240
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00710    0.0754    0.918  129.804  audio_features
# 1           0.00000    0.0601    0.901  120.048  audio_features
# 2           0.23300    0.0987    0.707  121.604  audio_features
# 3           0.00000    0.0644    0.529   76.054  audio_features
# 4           0.00264    0.0763    0.857  139.981  audio_features
#
#                        id                                   uri  \
# 0  1FTSo4v6BOZH9QxKc3MbVM  spotify:track:1FTSo4v6BOZH9QxKc3MbVM
# 1  5CeL9C3bsoe4yzYS1Qz8cw  spotify:track:5CeL9C3bsoe4yzYS1Qz8cw
# 2  5eSllZgRWCIJsDTAqFRwQw  spotify:track:5eSllZgRWCIJsDTAqFRwQw
# 3  42cxPm9jgbaxIVN77XA1m6  spotify:track:42cxPm9jgbaxIVN77XA1m6
# 4  61JDaStnXY3vbaEjliB5WA  spotify:track:61JDaStnXY3vbaEjliB5WA
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1FTSo4v6BOZH...
# 1  https://api.spotify.com/v1/tracks/5CeL9C3bsoe4...
# 2  https://api.spotify.com/v1/tracks/5eSllZgRWCIJ...
# 3  https://api.spotify.com/v1/tracks/42cxPm9jgbax...
# 4  https://api.spotify.com/v1/tracks/61JDaStnXY3v...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1FTS...       121160
# 1  https://api.spotify.com/v1/audio-analysis/5CeL...       259387
# 2  https://api.spotify.com/v1/audio-analysis/5eSl...       358773
# 3  https://api.spotify.com/v1/audio-analysis/42cx...       461947
# 4  https://api.spotify.com/v1/audio-analysis/61JD...       299133
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
